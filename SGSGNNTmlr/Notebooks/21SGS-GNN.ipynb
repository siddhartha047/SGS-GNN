# %%
# %pip install torch_geometric
# %pip install pyg_lib torch_scatter torch_sparse torch_cluster torch_spline_conv -f https://data.pyg.org/whl/torch-2.4.0+cu121.html

# %%
import DeviceDir

DIR, RESULTS_DIR = DeviceDir.get_directory()
device, NUM_PROCESSORS = DeviceDir.get_device()

# %%
import os
import torch
import random
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.datasets import Planetoid, Reddit
from torch_geometric.nn import GCNConv
from torch_geometric.loader import ClusterData, ClusterLoader
from sklearn.metrics import f1_score
import numpy as np
import matplotlib.pyplot as plt
import time
from torch_geometric.datasets import WikipediaNetwork
from sklearn.model_selection import train_test_split
from torch_geometric.typing import Adj, SparseTensor
from ogb.nodeproppred import Evaluator, PygNodePropPredDataset
from torch_geometric.utils import scatter
from torch_geometric.datasets import Reddit, Reddit2, Flickr, Yelp, AmazonProducts, PPI,  OGB_MAG,  FakeDataset, Amazon,Coauthor,HeterophilousGraphDataset, CitationFull
from torch_geometric.utils import homophily
from torch_geometric.utils import negative_sampling
from torch_geometric.utils import add_random_edge

def fix_seeds(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

fix_seeds()

# %%
def train_val_test_mask(data, train=0.4, val=0.3, test=0.3, random_state=False):

    if isinstance(data.x, SparseTensor):
        N = data.x.size(0)
        data.num_nodes = N
    else:
        N = data.x.shape[0]

    indexs = list(range(N))

    if random_state:
        train_index, test_index = train_test_split(indexs, test_size=val+test)
        val_index, test_index = train_test_split(test_index, test_size=test/(val+test))
    else:
        train_index, test_index = train_test_split(indexs, test_size=val+test, random_state=1)
        val_index, test_index = train_test_split(test_index, test_size=test/(val+test), random_state=1)



    train_mask = torch.zeros(N, dtype=bool)
    train_mask[train_index]=True
    val_mask = torch.zeros(N, dtype=bool)
    val_mask[val_index]=True
    test_mask = torch.zeros(N, dtype=bool)
    test_mask[test_index]=True

    data.train_mask = train_mask
    data.val_mask = val_mask
    data.test_mask = test_mask

    return data

# %%
# from torch_geometric.datasets import LINKXDataset
# dataset_name = 'Roman-empire'
# dataset = HeterophilousGraphDataset('/tmp/Cora', DATASET_NAME)
# DATASET_NAME = dataset_name
# data = dataset[0]
# print(data)

# %%
from torch_geometric.datasets import KarateClub, Reddit, Reddit2, Flickr, Yelp, AmazonProducts, PPI,  OGB_MAG,  FakeDataset, Amazon,Coauthor,HeterophilousGraphDataset,LINKXDataset

def load_dataset(dataset_name):
    if dataset_name == "karate":
        dataset = KarateClub()
    elif dataset_name == "moon":
        from ipynb.fs.full.Moon import MoonDataset
        dataset = MoonDataset(n_samples=1000, degree=4, train=0.2, h = 0.2)
    elif dataset_name == "SmallCora":
        dataset = Planetoid(root=DIR+'/tmp/Cora', name='Cora')
    elif dataset_name in ["Cora", "Cora_ML", "CiteSeer", "DBLP", "PubMed"]:
        dataset = CitationFull(root=DIR+'/tmp/Citation/'+dataset_name, name=dataset_name)
    elif dataset_name == 'Amazon-ratings':
        dataset = HeterophilousGraphDataset(root=DIR+'/tmp/amazon_ratings', name = dataset_name)
#     elif dataset_name == 'Roman-empire':
#         from torch_geometric.datasets import LINKXDataset
#         dataset = LINKXDataset(DIR+'/tmp/Roman_empire', dataset_name)
    elif dataset_name == "Reddit":
        dataset = Reddit(root=DIR+'/tmp/Reddit')
    elif dataset_name == 'penn94':
        from torch_geometric.datasets import LINKXDataset
        dataset = LINKXDataset(root=DIR+'/tmp/LINKX', name=dataset_name)
    elif dataset_name == 'wiki':
        from torch_geometric.datasets import WikiCS
        dataset = WikiCS(root=DIR+'/tmp/WikiCS')
    elif dataset_name == 'Photo':
        dataset = Amazon(root=DIR+'/tmp/Photo', name='Photo')
    elif dataset_name == 'CiteSeer':
        dataset = Planetoid(root=DIR+'/tmp/CiteSeer', name=DATASET_NAME)
    elif dataset_name == 'CS':
        dataset = Coauthor(root=DIR+'/tmp/CS', name = DATASET_NAME)
    elif dataset_name == 'Physics':
        dataset = Coauthor(root=DIR+'/tmp/Physics', name = DATASET_NAME)
    elif dataset_name == 'Minesweeper':
        dataset   = HeterophilousGraphDataset(root=DIR+'/tmp/Mine',name=dataset_name)
#     elif dataset_name == 'pokec':
#         print("HELLOWROLD ")
    elif dataset_name == 'ogbn-proteins':
        dataset = PygNodePropPredDataset(name='ogbn-proteins', root=DIR+'/tmp/ogbn-proteins')
        data = dataset[0]
        data.node_species = None
        data.y = data.y.to(torch.float)

        # Initialize features of nodes by aggregating edge features.
        row, col = data.edge_index
        data.x = scatter(data.edge_attr, col, dim_size=data.num_nodes, reduce='sum')
        labels = data.y.argmax(dim=1)
        data.y = labels
        
        return dataset, data
    elif dataset_name == 'squirrel':
        dataset = WikipediaNetwork(root=DIR+'/tmp/squirrel', name='Squirrel')
    elif dataset_name == 'AmazonProducts':
        dataset = AmazonProducts(root=DIR+'/tmp/AmazonProducts')
    else:        
        from ipynb.fs.full.Dataset import get_data
        data, dataset = get_data(dataset_name, log=False, h_score = False, split_no = 0)
        
        return dataset, data
    
    print(dataset)
    data = dataset[0]
    print(data)
        
    return dataset, data

# Example usage
dataset_name = "SmallCora"
DATASET_NAME = dataset_name
dataset, data = load_dataset(dataset_name)

try:
    if "val_mask" not in data.__dict__['_store']:    
        data = train_val_test_mask(data, train=0.2, val=0.4, test=0.4)
except:    
    try:
        if "val_mask" not in data.__dict__['data']:
            data = train_val_test_mask(data, train=0.2, val=0.4, test=0.4)            
    except:
        None

if len(data.train_mask.shape) > 1 and len(data.val_mask.shape) > 1 and len(data.test_mask.shape) > 1:    
    try:
        split_index = 2
        data.train_mask = data.train_mask[:,split_index]
        data.val_mask = data.val_mask[:,split_index]
        data.test_mask = data.test_mask[:,split_index]

    except:        
        data = train_val_test_mask(data, train=0.2, val=0.4, test=0.4)
        

        
num_classes = int(max(data.y)+1)

print("""Stats.....""")
print(f'Dataset: {dataset}:')
print('======================')
print(f'Number of graphs: {len(dataset)}')
print(f'Number of features: {dataset.num_features}')
print(f'Number of classes: {num_classes}')
print()
print(data)
print('===========================================================================================================')

# Gather some statistics about the graph.
print(f'Number of nodes: {data.num_nodes}')
print(f'Number of edges: {data.num_edges}')
print(f'Average node degree: {data.num_edges / data.num_nodes:.2f}')
print(f'Number of training nodes: {data.train_mask.sum()}')
print(f'Training node label rate: {int(data.train_mask.sum()) / data.num_nodes:.2f}')
print(f'Has isolated nodes: {data.has_isolated_nodes()}')
print(f'Has self-loops: {data.has_self_loops()}')
print(f'Is undirected: {data.is_undirected()}')
# Out:
# Downloading https://github.com/yandex-research/heterophilous-graphs/raw/main/data/amazon_ratings.npz
# Processing...
# HeterophilousGraphDataset(name=amazon_ratings)
# Data(x=[24492, 300], edge_index=[2, 93050], y=[24492], train_mask=[24492, 10], val_mask=[24492, 10], test_mask=[24492, 10])
# Stats.....
# Dataset: HeterophilousGraphDataset(name=amazon_ratings):
# ======================
# Number of graphs: 1
# Number of features: 300
# Number of classes: 5
#
# Data(x=[24492, 300], edge_index=[2, 93050], y=[24492], train_mask=[24492], val_mask=[24492], test_mask=[24492])
# ===========================================================================================================
# Number of nodes: 24492
# Number of edges: 93050
# Average node degree: 3.80
# Number of training nodes: 12246
# Training node label rate: 0.50
# Has isolated nodes: False
# Has self-loops: False
# Is undirected: False
# Done!

# %%
# dataset_name = 'Roman-empire'
# DATASET_NAME = dataset_name
# dataset   = HeterophilousGraphDataset(root='/tmp/roman',name=dataset_name)
# print(data)

# %%
He = homophily(data.edge_index, data.y, method='edge')
print("Edge Homophily: ", He)
# Out:
# Edge Homophily:  0.3803761303424835

# %%
# Define the MLP for edge probability with dropout
class EdgeProbMLP(nn.Module):
    def __init__(self, in_channels, hidden_dim, dropout_prob=0.2):
        super(EdgeProbMLP, self).__init__()
        self.gcn1 = GCNConv(in_channels, hidden_dim)
        self.dropout = nn.Dropout(dropout_prob)
        self.gcn2 = GCNConv(hidden_dim, hidden_dim)
        self.fc1 = nn.Linear(2 * hidden_dim, hidden_dim)
        # self.fc_residual = nn.Linear(2 * hidden_dim, hidden_dim)  # For residual connection
        #self.fc1 = nn.Linear(2 * in_channels, hidden_dim) #if straightforward link
        self.dropout = nn.Dropout(dropout_prob)
        self.fc2 = nn.Linear(hidden_dim, 1)

    def forward(self, node_features, edge_index):

        #x = node_features[edge_index[0]]
        #y = node_features[edge_index[1]]
        
        out = F.relu(self.gcn1(node_features, edge_index))
        out = self.dropout(out)
        out = self.gcn2(out, edge_index)
        
        x = out[edge_index[0]]
        y = out[edge_index[1]]
        
        edge_features = torch.cat([x*y,x-y], dim=1) #x*y|x-y
        x = F.relu(self.fc1(edge_features))
        # x = x + self.fc_residual(edge_features) #  # Add residual connection
        x = self.dropout(x)
        prob = torch.sigmoid(self.fc2(x))
        # prob.requires_grad_(True)
        return prob
    
# class EdgeProbMLP(nn.Module):
#     def __init__(self, in_channels, hidden_dim):
#         super(EdgeProbMLP, self).__init__()
#         self.fc1 = nn.Linear(2 * in_channels, hidden_dim)
#         self.fc2 = nn.Linear(hidden_dim, 1)

#     def forward(self, node_features, edge_index):
#         edge_features = torch.cat([node_features[edge_index[0]], node_features[edge_index[1]]], dim=1)
#         x = F.relu(self.fc1(edge_features))
#         prob = torch.sigmoid(self.fc2(x))
#         #prob = F.softmax(self.fc2(x),dim=0)
#         #prob = F.relu(self.fc2(x))
#         return prob
    
#     def reset_parameters(self):
#         self.fc1.reset_parameters()
#         self.fc2.reset_parameters()

# Define the overall model with Edge Probabilities and GCNConv (GNN) with dropout
class GNNModel(nn.Module):
    def __init__(self, in_channels, hidden_dim, out_channels, num_classes, dropout_prob=0.3):
        super(GNNModel, self).__init__()
        self.edge_prob_mlp = EdgeProbMLP(in_channels, hidden_dim, dropout_prob)
        # self.edge_prob_mlp = EdgeProbMLP(in_channels, hidden_dim)
        self.gcn1 = GCNConv(in_channels, hidden_dim)
        self.dropout = nn.Dropout(dropout_prob)
        self.gcn2 = GCNConv(hidden_dim, num_classes)

    def forward(self, data, edge_index, edge_weight=None):
        x = F.relu(self.gcn1(data.x, edge_index, edge_weight))
        x = self.dropout(x)
        out = self.gcn2(x, edge_index, edge_weight)
        return out

# %%
def plot_probs(edge_probs,sampling_probs):
    ep = edge_probs.detach().cpu().numpy()
    sp = sampling_probs.detach().cpu().numpy()
    
    plt.figure(figsize=(20, 6))    
    plt.subplot(2, 1, 1)

    #plt.plot(ep)
    plt.scatter(range(len(ep)), ep, s=2)
    plt.title('Curve of Edge Probs')
    plt.xlabel('Index')
    plt.ylabel('Value')
    plt.grid(True)

    plt.subplot(2, 1, 2)
    #plt.plot(sp)
    plt.scatter(range(len(sp)), sp, s=2)
    plt.title('Curve of Samples Probs')
    plt.xlabel('Index')
    plt.ylabel('Probability')
    plt.grid(True)

    plt.tight_layout()
    plt.show()
    
    
def plot_hist(edge_probs,sampling_probs, ep_select, sp_select):
    ep = edge_probs.detach().cpu().numpy()
    sp = sampling_probs.detach().cpu().numpy()
    ep_select = ep_select.detach().cpu().numpy()
    sp_select = sp_select.detach().cpu().numpy()
    
    plt.figure(figsize=(20, 15))    
    plt.subplot(4, 1, 1)

    #plt.plot(ep)
    plt.hist(ep, bins= 30, edgecolor='black')
    plt.title('Histogram of Edge Probs')
    plt.xlabel('Index')
    plt.ylabel('Value')
    plt.grid(True)

    plt.subplot(4, 1, 2)
    #plt.plot(sp)
    plt.hist(sp, bins= 30, edgecolor='black')
    plt.title('histogram of Samples Probs')
    plt.xlabel('Index')
    plt.ylabel('Probability')
    plt.grid(True)

    plt.subplot(4, 1, 3)
    #plt.plot(sp)
    plt.hist(ep_select, bins= 30, edgecolor='black')
    plt.title('histogram of selected Edge Probs')
    plt.xlabel('Index')
    plt.ylabel('Probability')
    plt.grid(True)
    
    plt.subplot(4, 1, 4)
    #plt.plot(sp)
    plt.hist(sp_select, bins= 30, edgecolor='black')
    plt.title('histogram of selected sampled Probs')
    plt.xlabel('Index')
    plt.ylabel('Probability')
    plt.grid(True)

    
    
    plt.tight_layout()
    plt.show()

# %%
from torch_geometric.utils import to_scipy_sparse_matrix
import scipy.sparse as sp

# %%
# Gumbel-Softmax trick for edge sampling
def gumbel_softmax_sampling(batch, edge_probs, edge_index, q=500, temperature=1.0, log=False, istest=False, epoch=-1):
        
    if istest:
        # samples = torch.exp(edge_probs)/torch.exp(edge_probs).sum()
        samples = edge_probs/edge_probs.sum()
        samples = 0.7 * samples + 0.3*batch.prob #temporary
        top_k_values, sampled_edges = torch.topk(samples, q, dim=-1, largest=True, sorted=True)
        #sampled_edges = torch.multinomial(samples, q, replacement=False) #nothing
        
        # samples = F.softmax(edge_probs/temperature, dim=-1)
        #top_k_values, sampled_edges = torch.topk(edge_probs, q, dim=-1, largest=True, sorted=True)
        # edge_gradients = edge_probs.grad
        # sampled_edges = torch.topk(edge_gradients.abs(),k=q)
    else:
        # warmup_epochs = 20  # Number of epochs for the warm-up phase
        # if epoch< warmup_epochs:
            # samples = F.softmax(batch.prob, dim=-1)
            # sampled_edges = torch.multinomial(samples, q, replacement=False) #nothing               
        # else:
        # samples = torch.exp(edge_probs)/torch.exp(edge_probs).sum()
        # edge_probs += torch.ones_like(edge_probs)/len(edge_probs)
        samples =  edge_probs/edge_probs.sum()
        # samples = F.softmax(edge_probs/temperature, dim=-1)
        # samples = 0.1*samples + 0.9*torch.rand_like(samples)
        samples = 0.7 * samples + 0.3*batch.prob
        sampled_edges = torch.multinomial(samples, q, replacement=False) #nothing
#         gumbels = -torch.empty_like(edge_probs).exponential_().log()
#         gumbels = (gumbels - gumbels.min()) / (gumbels.max() - gumbels.min())
        
#         #noise = 1.0 + (epoch/100)*9.0
#         noise = 1.0
        
#         gumbels = gumbels/noise
        
    
# #         gumbels = 0

#         logits = (edge_probs + gumbels) / temperature    
#         samples = F.softmax(logits, dim=-1)

        #top_k_values, sampled_edges = torch.topk(samples, q, dim=-1, largest=True, sorted=True) # 50       
        
    
        #print(f'{torch.mean(samples).item():.4f}, {torch.var(samples).item():.4f}, {torch.std(samples).item():.4f}')    
        #print("EP: ",torch.mean(edge_probs).item(), torch.var(edge_probs).item())
        #print("SP: ",torch.mean(samples).item(), torch.var(samples).item())
    
    # if epoch%10 == 0:
    
#     print("Test" if istest == True else "Train")
#     print(edge_probs)
#     print(samples)   
        #plot_probs(edge_probs, samples)
#         plot_hist(edge_probs, samples, edge_probs[sampled_edges],samples[sampled_edges])
    
#     adj = to_scipy_sparse_matrix(data.edge_index[:,sampled_edges], num_nodes=data.num_nodes)
#     num_components, component = sp.csgraph.connected_components(adj, connection='weak')
#     print("Components: ", num_components)
    
#     sampled_edges = torch.multinomial(samples, q, replacement=False)
#     top_k_values, sampled_edges = torch.topk(edge_probs, q, dim=-1, largest=True, sorted=True)    

    
    one_hot = torch.zeros_like(samples)
    one_hot.scatter_(0, sampled_edges, 1.0)     
    
    indexs = (one_hot - samples).detach() + samples
    
    edge_probs = edge_probs*indexs
    indexs = indexs.bool()
    
    
#     if log:        
#         print("edge_probs: ",edge_probs)
# #         print("gumbels: ", gumbels)
# #         print("logits: ",logits)
#         print("samples: ",samples)
#         print("sampled_edges: ",sampled_edges)
#         print("One hot: ", one_hot)
#         print("Indexs: ",indexs)
#         print("edge_probs[indexs]:", edge_probs[indexs])

    
#     return indexs, edge_probs[indexs]
    
    return indexs, edge_probs[indexs]+0.01
    #return indexs, torch.clamp(edge_probs[indexs]+10, max=1.0)


# Random edge sampling
def random_edge_sampling(edge_index, q):
    num_edges = edge_index.shape[1]
    sampled_indices = torch.randperm(num_edges)[:q]
    sampled_edge_index = edge_index[:, sampled_indices]
    return sampled_edge_index

# F1 score calculation helper
def calculate_f1(logits, labels, mask):
    preds = logits[mask].argmax(dim=1)
    f1 = f1_score(labels[mask].cpu(), preds.cpu(), average='micro')
    return f1

# Training function with alternating updates
def train(epoch, max_epoch, model, optimizer_gnn, optimizer_edge_prob, optimizer, criterion, cluster_loader, device, q=500, mode='learned', alternate_frequency=1):
    model.train()
    total_loss = 0
    iteration = 0

    for batch in cluster_loader:
        if not batch.train_mask.any():
            continue

        batch = batch.to(device)
        
#         if alternate_frequency == 0:
#             update_gnn = True
#             update_edge_prob = True
#         else:            
#             # Decide if we are updating GNN or edge probability model
#             update_gnn = iteration % alternate_frequency == 0
#             update_edge_prob = not update_gnn
        # Zero gradients selectively        
#         if update_gnn:
#             optimizer_gnn.zero_grad()
#         if update_edge_prob:
#             optimizer_edge_prob.zero_grad()
        
        optimizer_edge_prob.zero_grad()
        optimizer_gnn.zero_grad()
        
        #optimizer.zero_grad()

        # Select edges based on mode
        if mode == 'learned':
            if batch.edge_index.shape[1] > q:
                edge_probs = model.edge_prob_mlp(batch.x, batch.edge_index).squeeze()   
                # edge_probs.retain_grad()
                # edge_probs.requires_grad = True                 
                # temperature = 2.0 - (epoch * (2 - 0.5) / max_epoch)
                # temperature = 1.0
                temperature = max(0.5, 0.7 - epoch*0.01) # Annealing (improves very little)
                #print(temperature)                
                sampled_edge_indices, sampled_edge_weight = gumbel_softmax_sampling(batch, edge_probs, batch.edge_index, q=q, temperature=temperature, log=(epoch==max_epoch-1),epoch=epoch)
                sampled_edge_index = batch.edge_index[:, sampled_edge_indices]      
                learned_out = model(batch, sampled_edge_index, sampled_edge_weight) 
                #out = model(batch, sampled_edge_index, None)     
                                                  
            else:
                learned_out = model(batch, batch.edge_index)
        
        
            # random_edge_index = random_edge_sampling(batch.edge_index,q)
            # random_out = model(batch,random_edge_index)
            
            with torch.no_grad():
                samples = F.softmax(batch.prob, dim=-1)
                edge_sample = torch.multinomial(samples, q, replacement=False) #nothing                
                sampled_edge_index = batch.edge_index[:,edge_sample]                
                random_out = model(batch,sampled_edge_index)

            # Calculate F1 scores for learned and random sampling
            learned_f1 = calculate_f1(learned_out, batch.y, batch.train_mask)
            random_f1 = calculate_f1(random_out, batch.y, batch.train_mask)
            # Compute loss for learned edges
            loss = criterion(learned_out[batch.train_mask], batch.y[batch.train_mask])
            
            # Compute node classification loss
            # loss = criterion(out[batch.train_mask], batch.y[batch.train_mask])
            # loss = loss + 0.001 * torch.sum(torch.square(edge_probs))

            #######---regularizer 1
            edge_labels = torch.full((batch.edge_index.size(1),), -1, dtype=torch.long, device=device)
            train_indices = torch.nonzero(batch.train_mask).squeeze()
            train_edge_mask = torch.isin(batch.edge_index[0], train_indices) & torch.isin(batch.edge_index[1], train_indices)

            # Assign labels based on the class of the endpoints
            same_class_mask = batch.y[batch.edge_index[0]] == batch.y[batch.edge_index[1]]
            edge_labels[train_edge_mask & same_class_mask] = 1
            edge_labels[train_edge_mask & ~same_class_mask] = 0

            # Filter out the edges with labels -1
            valid_edge_mask = edge_labels != -1
            valid_edge_probs = edge_probs[valid_edge_mask]
            valid_edge_labels = edge_labels[valid_edge_mask]
            
            #print(torch.sum(valid_edge_labels))
            if torch.sum(valid_edge_labels).item() > 1:            
                loss2 = F.binary_cross_entropy(valid_edge_probs, valid_edge_labels.float().to(device))
            else:
                loss2 = 0
                
            loss = loss+loss2

            
# #             ########---regularizer 2

#             train_indices = torch.nonzero(batch.train_mask).squeeze()            
#             num_nodes = train_indices.size(0)
#             #num_edges = min(num_nodes*num_nodes,q)  # Adjust the number of edges as needed
#             num_edges = num_nodes*num_nodes

#             # Generate random edges
#             src = torch.randint(0, num_nodes, (num_edges,))
#             dst = torch.randint(0, num_nodes, (num_edges,))

#             # Map to actual node indices
#             src_nodes = train_indices[src]
#             dst_nodes = train_indices[dst]

#             # Create edge_index tensor
#             reg_edge_index = torch.stack([src_nodes, dst_nodes], dim=0).to(device)
#             reg_edge_label = (batch.y[src_nodes] == batch.y[dst_nodes]).float().to(device)            
#             reg_edge_probs = model.edge_prob_mlp(batch.x, reg_edge_index).squeeze()
            
#             loss4 = F.binary_cross_entropy(reg_edge_probs, reg_edge_label)

#             #print(reg_edge_index)
#             #print(reg_edge_label)
            
#             loss = loss+loss4
                        

            if learned_f1 > random_f1:
                loss.backward()
                optimizer_edge_prob.step()
                optimizer_gnn.step()
                #optimizer.step()                
                #print("learned..")
            else:
                loss.backward()
                optimizer_gnn.step()
                #optimizer.zero_grad()
                #print("Ignored.."
                None
        
        # loss.backward()
        # importance_score = edge_probs.grad.abs().detach().cpu().numpy()

#         # Update parameters selectively
#         if update_gnn:
#             optimizer_gnn.step()
#         if update_edge_prob:
#             optimizer_edge_prob.step()

        # optimizer.step()
    
    
        elif mode == 'random':
            if batch.edge_index.shape[1] > q:
                sampled_edge_index = random_edge_sampling(batch.edge_index, q=q)
                
#                 adj = to_scipy_sparse_matrix(sampled_edge_index, num_nodes=data.num_nodes)
#                 num_components, component = sp.csgraph.connected_components(adj, connection='weak')
#                 print("Components in random: ", num_components)
                
                out = model(batch, sampled_edge_index)
            else:
                out = model(batch, batch.edge_index)
            
            loss = criterion(out[batch.train_mask], batch.y[batch.train_mask])
            loss.backward()
            optimizer.step()
                
        elif mode == 'edge':
            if batch.edge_index.shape[1] > q:
                
                samples = F.softmax(batch.prob, dim=-1)
                # samples = batch.prob/batch.prob.sum()
                edge_sample = torch.multinomial(samples, q, replacement=False) #nothing                
                sampled_edge_index = batch.edge_index[:,edge_sample]                
                #print(sampled_edge_index.shape)
                
#                 adj = to_scipy_sparse_matrix(sampled_edge_index, num_nodes=data.num_nodes)
#                 num_components, component = sp.csgraph.connected_components(adj, connection='weak')
#                 print("Components in edge: ", num_components)
                
                out = model(batch, sampled_edge_index)
            else:
                out = model(batch, batch.edge_index)
            
            loss = criterion(out[batch.train_mask], batch.y[batch.train_mask])
            loss.backward()
            optimizer.step()
            
        elif mode == 'full':
            out = model(batch, batch.edge_index)
            loss = criterion(out[batch.train_mask], batch.y[batch.train_mask])
            loss.backward()
            optimizer.step()
            
        else:
            raise ValueError("Invalid mode. Choose 'learned', 'random', or 'full'.")
        

        total_loss += loss.item()
        iteration += 1

    # return total_loss / len(cluster_loader), importance_score
    return total_loss / len(cluster_loader), None

# Evaluation function remains unchanged
def evaluate(model, cluster_loader, device, q=500, mode=None):
    model.eval()
    total_train_f1, total_val_f1, total_test_f1 = 0, 0, 0
    num_train_examples, num_val_examples, num_test_examples = 0, 0, 0

    with torch.no_grad():
        for batch in cluster_loader:
            batch = batch.to(device)
            if mode == 'learned':
                if batch.edge_index.shape[1] > q:
                    edge_probs = model.edge_prob_mlp(batch.x, batch.edge_index).squeeze()                    
                    sampled_edge_indices, sampled_edge_weight = gumbel_softmax_sampling(batch, edge_probs, batch.edge_index, q=q, istest=True)
                    sampled_edge_index = batch.edge_index[:, sampled_edge_indices]
                    out = model(batch, sampled_edge_index, sampled_edge_weight)                                        
                    #out = model(batch, sampled_edge_index, None)                                        
                else:
                    out = model(batch, batch.edge_index)
            elif mode == 'random':
                if batch.edge_index.shape[1] > q:
                    sampled_edge_index = random_edge_sampling(batch.edge_index, q=q)
                    out = model(batch, sampled_edge_index)
                else:
                    out = model(batch, batch.edge_index)
                    
            elif mode == 'edge':
                if batch.edge_index.shape[1] > q:
                    samples = F.softmax(batch.prob, dim=-1)
                    edge_sample = torch.multinomial(samples, q, replacement=False) #nothing                
                    sampled_edge_index = batch.edge_index[:,edge_sample]                
                    #print(sampled_edge_index.shape)
                    out = model(batch, sampled_edge_index)                
                else:
                    out = model(batch, batch.edge_index)
                    
            
            elif mode == 'full':
                out = model(batch, batch.edge_index)
            else:
                raise ValueError("Invalid mode. Choose 'learned', 'random', or 'full'.")

            # Calculate F1 scores for train, val, and test sets if masks are present
            if batch.train_mask.any():
                train_f1 = calculate_f1(out, batch.y, batch.train_mask)
                total_train_f1 += train_f1 * batch.train_mask.sum().item()
                num_train_examples += batch.train_mask.sum().item()

            if batch.val_mask.any():
                val_f1 = calculate_f1(out, batch.y, batch.val_mask)
                total_val_f1 += val_f1 * batch.val_mask.sum().item()
                num_val_examples += batch.val_mask.sum().item()

            if batch.test_mask.any():
                test_f1 = calculate_f1(out, batch.y, batch.test_mask)
                total_test_f1 += test_f1 * batch.test_mask.sum().item()
                num_test_examples += batch.test_mask.sum().item()

    avg_train_f1 = total_train_f1 / num_train_examples if num_train_examples > 0 else 0
    avg_val_f1 = total_val_f1 / num_val_examples if num_val_examples > 0 else 0
    avg_test_f1 = total_test_f1 / num_test_examples if num_test_examples > 0 else 0

    return avg_train_f1, avg_val_f1, avg_test_f1

# Evaluation function remains unchanged
def ensemble_evaluate(model, cluster_loader, device, q=500, mode=None):
    model.eval()
    total_train_f1, total_val_f1, total_test_f1 = 0, 0, 0
    num_train_examples, num_val_examples, num_test_examples = 0, 0, 0

    with torch.no_grad():
        for batch in cluster_loader:
            batch = batch.to(device)
            
            outs = []
            
            for i in range(11):                    
                if mode == 'learned':
                    if batch.edge_index.shape[1] > q:
                        edge_probs = model.edge_prob_mlp(batch.x, batch.edge_index).squeeze()                    
                        sampled_edge_indices, sampled_edge_weight = gumbel_softmax_sampling(batch, edge_probs, batch.edge_index, q=q, istest=True)
                        sampled_edge_index = batch.edge_index[:, sampled_edge_indices]
                        out = model(batch, sampled_edge_index, sampled_edge_weight)                                        
                        #out = model(batch, sampled_edge_index, None)                                        
                    else:
                        out = model(batch, batch.edge_index)
                elif mode == 'random':
                    if batch.edge_index.shape[1] > q:
                        sampled_edge_index = random_edge_sampling(batch.edge_index, q=q)
                        out = model(batch, sampled_edge_index)
                    else:
                        out = model(batch, batch.edge_index)

                elif mode == 'edge':
                    if batch.edge_index.shape[1] > q:
                        samples = F.softmax(batch.prob, dim=-1)
                        edge_sample = torch.multinomial(samples, q, replacement=False) #nothing                
                        sampled_edge_index = batch.edge_index[:,edge_sample]                
                        #print(sampled_edge_index.shape)
                        out = model(batch, sampled_edge_index)                
                    else:
                        out = model(batch, batch.edge_index)


                elif mode == 'full':
                    out = model(batch, batch.edge_index)
                else:
                    raise ValueError("Invalid mode. Choose 'learned', 'random', or 'full'.")
                    
                    
                outs.append(out)
            
            
#             #ensembel prediction
            
#             train_preds = []
#             val_preds = []
#             test_preds = []
            
#             for logits in outs:                   
#                 train_preds.append(logits[batch.train_mask].argmax(dim=1))
#                 val_preds.append(logits[batch.val_mask].argmax(dim=1))
#                 test_preds.append(logits[batch.test_mask].argmax(dim=1))
                
#             train_y, _ = torch.mode(torch.stack(train_preds), dim=0)
#             val_y, _ = torch.mode(torch.stack(val_preds), dim=0)
#             test_y, _ = torch.mode(torch.stack(test_preds), dim=0)
            
#             train_f1 = f1_score(batch.y[batch.train_mask].cpu(), train_y.cpu(), average='micro')
#             val_f1 = f1_score(batch.y[batch.val_mask].cpu(), val_y.cpu(), average='micro')
#             test_f1 = f1_score(batch.y[batch.test_mask].cpu(), test_y.cpu(), average='micro')
            
#             total_train_f1 += train_f1 * batch.train_mask.sum().item()
#             num_train_examples += batch.train_mask.sum().item()
            
#             total_val_f1 += val_f1 * batch.val_mask.sum().item()
#             num_val_examples += batch.val_mask.sum().item()
            
#             total_test_f1 += test_f1 * batch.test_mask.sum().item()
#             num_test_examples += batch.test_mask.sum().item()
            
            # average embedding prediction
            
            out = torch.mean(torch.stack(outs, dim=0), dim=0)                
                
            # Calculate F1 scores for train, val, and test sets if masks are present
            if batch.train_mask.any():
                train_f1 = calculate_f1(out, batch.y, batch.train_mask)
                total_train_f1 += train_f1 * batch.train_mask.sum().item()
                num_train_examples += batch.train_mask.sum().item()

            if batch.val_mask.any():
                val_f1 = calculate_f1(out, batch.y, batch.val_mask)
                total_val_f1 += val_f1 * batch.val_mask.sum().item()
                num_val_examples += batch.val_mask.sum().item()

            if batch.test_mask.any():
                test_f1 = calculate_f1(out, batch.y, batch.test_mask)
                total_test_f1 += test_f1 * batch.test_mask.sum().item()
                num_test_examples += batch.test_mask.sum().item()

        

    avg_train_f1 = total_train_f1 / num_train_examples if num_train_examples > 0 else 0
    avg_val_f1 = total_val_f1 / num_val_examples if num_val_examples > 0 else 0
    avg_test_f1 = total_test_f1 / num_test_examples if num_test_examples > 0 else 0

    return avg_train_f1, avg_val_f1, avg_test_f1

# %%
if "edge_weight" in data.__dict__['_store']:
    print("Edge weights given")
else:
    print("No edge weights")
# Out:
# No edge weights

# %%
from torch_geometric.typing import SparseTensor

N = data.num_nodes
E = data.num_edges

adj = SparseTensor(row=data.edge_index[0], col=data.edge_index[1],
            value=torch.arange(E, device=data.edge_index.device),sparse_sizes=(N, N))

row, col, _ = adj.coo()

deg_in = 1. / adj.storage.colcount()
deg_out = 1. / adj.storage.rowcount()
prob = (1. / deg_in[row]) + (1. / deg_out[col])

# %%
prob = 1. / (prob + 1e-10)
# prob = prob/torch.sum(prob)
data.prob = prob
data.deg_in = deg_in
data.deg_out = deg_out

# %%
adj = to_scipy_sparse_matrix(data.edge_index, num_nodes=data.num_nodes)
num_components, component = sp.csgraph.connected_components(adj, connection='weak')
print("Components: ", num_components)
# Out:
# Components:  1

# %%
# from sklearn.decomposition import TruncatedSVD

# def adj_feature(data):    
#     adj_mat = torch.zeros((data.num_nodes,data.num_nodes))
#     edges = data.edge_index.t()
#     adj_mat[edges[:,0], edges[:,1]] = 1
#     adj_mat[edges[:,1], edges[:,0]] = 1
    
# #     return adj_mat
    
# #     n_components = data.x.shape[1]
#     n_components = min(256, data.x.shape[1], data.num_nodes)

#     svd = TruncatedSVD(n_components=n_components)
#     x = svd.fit_transform(adj_mat)
    
#     x = torch.Tensor(x)
#     x.shape    
    
#     return x

# data.x = torch.cat((data.x, adj_feature(data)), dim=1)

# # data.x = adj_feature(data)
# # print(data.x.shape)
# # data.x

# %% [markdown]
# Main for multiple runs

# %%
# data = train_val_test_mask(data, train=0.2, val=0.4, test=0.4)
print(sum(data.train_mask))
data
# Out:
# tensor(12246)
# Data(x=[24492, 300], edge_index=[2, 93050], y=[24492], train_mask=[24492], val_mask=[24492], test_mask=[24492], prob=[93050], deg_in=[24492], deg_out=[24492])

# %%
# Configuration
RUNS = 5
NUM_EPOCHS = 500
best_test_f1s = []
log = True
mode = 'learned'  # available modes ['learned', 'random', 'full']
alternate_frequency = 0
sample_percent = 0.20
figure_log = False

# Check if partitioning is needed
use_metis = data.edge_index.shape[1]>=500000 # or data.num_nodes >= 20000

if use_metis:
    num_edges_per_partition = 500000
    num_parts = int(np.ceil(data.edge_index.shape[1] / num_edges_per_partition))    

#     num_parts = 1500
#     num_edges_per_partition = int(data.edge_index.shape[1] / num_parts)

    sample_size = int(num_edges_per_partition * sample_percent)
    print("Using METIS with num_parts:", num_parts, "avg edges per partition:", num_edges_per_partition, "sample size:", sample_size)
else:
    print("Graph has fewer than 10,000 nodes; don't do graph partition")
    sample_size = int(data.edge_index.shape[1] * sample_percent)

# Partition data using METIS clustering or load the entire graph as a single batch
if use_metis:
    start = time.time()
    cluster_dir = DIR + 'tmp/' + DATASET_NAME
    if not os.path.exists(cluster_dir):
        os.makedirs(cluster_dir)
    
    cluster_data = ClusterData(data, num_parts=num_parts, recursive=False, save_dir=cluster_dir, log=True)
    print("METIS Partition time:", time.time() - start)
    cluster_loader = ClusterLoader(cluster_data, batch_size=1, shuffle=True)
else:
    cluster_loader = [data]

# Training and evaluation loop
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_save_path = 'best_model.pth1'

train_figures = []

for run in range(RUNS):
    print("Run:", run)
    
    train_figures = []

    # Initialize model and optimizers
    model = GNNModel(in_channels=data.x.shape[1], hidden_dim=256, out_channels=128, num_classes=num_classes).to(device)
    optimizer_gnn = torch.optim.Adam([param for name, param in model.named_parameters() if 'gcn' in name], lr=0.001)
    optimizer_edge_prob = torch.optim.Adam([param for name, param in model.named_parameters() if 'edge_prob_mlp' in name], lr=0.001)    
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001,weight_decay=0.0005)
    
    criterion = nn.CrossEntropyLoss()

    # Initialize F1 score trackers
    train_f1_scores = np.zeros(NUM_EPOCHS)
    val_f1_scores = np.zeros(NUM_EPOCHS)
    test_f1_scores = np.zeros(NUM_EPOCHS)
    loss_scores = np.zeros(NUM_EPOCHS)
    
    best_test_f1 = 0
    best_val_f1 = 0

    # Training over epochs
    for epoch in range(NUM_EPOCHS):
        # Alternate training of GNN and edge probability model based on frequency
        loss, importance_score = train(
            epoch,
            NUM_EPOCHS,
            model,
            optimizer_gnn,
            optimizer_edge_prob,
            optimizer,
            criterion,
            cluster_loader,
            device,
            q=sample_size,
            mode=mode,
            alternate_frequency=alternate_frequency
        )
        # if epoch%10 == 0:
        #     plt.figure(figsize=(20, 6))    
        #     plt.subplot(1, 1, 1)

        #     #plt.plot(ep)
        #     plt.scatter(range(len(importance_score)), importance_score, s=2)
        #     plt.title('Importance score')
        #     plt.xlabel('Index')
        #     plt.ylabel('Score')
        #     plt.grid(True)
        #     plt.show()
        
        # Evaluate model performance on train, validation, and test sets
        train_f1, val_f1, test_f1 = evaluate(model, cluster_loader, device, q=int(sample_size), mode=mode)
        #train_f1, val_f1, test_f1 = ensemble_evaluate(model, cluster_loader, device, q=int(sample_size), mode=mode)

        # Store F1 scores
        train_f1_scores[epoch] = train_f1
        val_f1_scores[epoch] = val_f1
        test_f1_scores[epoch] = test_f1
        loss_scores[epoch] = loss

        # Save model if validation F1 improves
        if val_f1 >= best_val_f1:
            best_val_f1 = val_f1
            #best_test_f1 = test_f1
            torch.save(model.state_dict(), model_save_path)
            if log:
                print(f"*Epoch {epoch}, model saved with Loss: {loss:.4f}, Train F1: {train_f1:.4f}, Val F1: {val_f1:.4f}, Test F1: {test_f1:.4f}")

#          #Save model if test F1 improves
        if test_f1 > best_test_f1:
            best_test_f1 = test_f1
#             torch.save(model.state_dict(), model_save_path)
#             if log:
#                 print(f"*Epoch {epoch}, model saved with Train F1: {train_f1:.4f}, Val F1: {val_f1:.4f}, Test F1: {test_f1:.4f}")

        if log and epoch % 100 == 0:
            print(f'Epoch {epoch}, Loss: {loss:.4f}, Train F1: {train_f1:.4f}, Val F1: {val_f1:.4f}, Test F1: {test_f1:.4f}')
            
        if figure_log:
            train_figures.append(visualize(istest=False,show=False))

    # Load the best model for evaluation
    print(f'Best Test F1 throughout: {best_test_f1:.4f}')
    print(f'Loading best model for final evaluation...: {best_val_f1:.4f}')
    model.load_state_dict(torch.load(model_save_path))
    _, _, best_test_f1 = evaluate(model, cluster_loader, device, q=sample_size, mode=mode)
    #_, _, best_test_f1 = ensemble_evaluate(model, cluster_loader, device, q=sample_size, mode=mode)
    print(f'Best Test F1 after loading saved model: {best_test_f1:.4f}')
    best_test_f1s.append(best_test_f1)

# Report the mean and standard deviation of the best test F1 scores over runs
print(f'Mean Std of Test F1 Score: {np.mean(best_test_f1s):.4f} +/- {np.std(best_test_f1s):.4f}')
# Out:
# Graph has fewer than 10,000 nodes; don't do graph partition
# Run: 0
# *Epoch 0, model saved with Loss: 2.3063, Train F1: 0.3093, Val F1: 0.3095, Test F1: 0.3088
# Epoch 0, Loss: 2.3063, Train F1: 0.3093, Val F1: 0.3095, Test F1: 0.3088
# *Epoch 1, model saved with Loss: 2.2824, Train F1: 0.3408, Val F1: 0.3377, Test F1: 0.3386
# *Epoch 2, model saved with Loss: 2.2592, Train F1: 0.3551, Val F1: 0.3524, Test F1: 0.3578
# *Epoch 3, model saved with Loss: 2.2421, Train F1: 0.3635, Val F1: 0.3619, Test F1: 0.3639
# *Epoch 4, model saved with Loss: 2.2244, Train F1: 0.3689, Val F1: 0.3686, Test F1: 0.3684
# *Epoch 9, model saved with Loss: 2.1500, Train F1: 0.3708, Val F1: 0.3686, Test F1: 0.3683
# *Epoch 10, model saved with Loss: 2.1379, Train F1: 0.3704, Val F1: 0.3689, Test F1: 0.3678
# *Epoch 15, model saved with Loss: 2.0968, Train F1: 0.3709, Val F1: 0.3689, Test F1: 0.3678
# *Epoch 16, model saved with Loss: 2.0902, Train F1: 0.3707, Val F1: 0.3689, Test F1: 0.3680
# *Epoch 18, model saved with Loss: 2.0809, Train F1: 0.3708, Val F1: 0.3691, Test F1: 0.3701
# *Epoch 19, model saved with Loss: 2.0758, Train F1: 0.3726, Val F1: 0.3693, Test F1: 0.3709
# *Epoch 20, model saved with Loss: 2.0738, Train F1: 0.3744, Val F1: 0.3693, Test F1: 0.3714
# *Epoch 21, model saved with Loss: 2.0711, Train F1: 0.3750, Val F1: 0.3714, Test F1: 0.3714
# *Epoch 22, model saved with Loss: 2.0708, Train F1: 0.3761, Val F1: 0.3715, Test F1: 0.3720
# *Epoch 23, model saved with Loss: 2.0680, Train F1: 0.3760, Val F1: 0.3737, Test F1: 0.3714
# *Epoch 24, model saved with Loss: 2.0655, Train F1: 0.3765, Val F1: 0.3760, Test F1: 0.3727
# *Epoch 27, model saved with Loss: 2.0626, Train F1: 0.3787, Val F1: 0.3769, Test F1: 0.3732
# *Epoch 28, model saved with Loss: 2.0604, Train F1: 0.3800, Val F1: 0.3782, Test F1: 0.3737
# *Epoch 29, model saved with Loss: 2.0600, Train F1: 0.3807, Val F1: 0.3786, Test F1: 0.3745
# *Epoch 30, model saved with Loss: 2.0566, Train F1: 0.3803, Val F1: 0.3789, Test F1: 0.3747
# *Epoch 34, model saved with Loss: 2.0504, Train F1: 0.3827, Val F1: 0.3800, Test F1: 0.3768
# *Epoch 35, model saved with Loss: 2.0473, Train F1: 0.3841, Val F1: 0.3813, Test F1: 0.3781
# *Epoch 36, model saved with Loss: 2.0463, Train F1: 0.3847, Val F1: 0.3815, Test F1: 0.3800
# *Epoch 37, model saved with Loss: 2.0429, Train F1: 0.3849, Val F1: 0.3827, Test F1: 0.3805
# *Epoch 38, model saved with Loss: 2.0406, Train F1: 0.3858, Val F1: 0.3835, Test F1: 0.3804
# *Epoch 39, model saved with Loss: 2.0387, Train F1: 0.3865, Val F1: 0.3846, Test F1: 0.3815
# *Epoch 40, model saved with Loss: 2.0380, Train F1: 0.3854, Val F1: 0.3846, Test F1: 0.3830
# *Epoch 41, model saved with Loss: 2.0348, Train F1: 0.3864, Val F1: 0.3858, Test F1: 0.3828
# *Epoch 42, model saved with Loss: 2.0332, Train F1: 0.3874, Val F1: 0.3867, Test F1: 0.3833
# *Epoch 43, model saved with Loss: 2.0303, Train F1: 0.3876, Val F1: 0.3867, Test F1: 0.3830
# *Epoch 44, model saved with Loss: 2.0291, Train F1: 0.3892, Val F1: 0.3867, Test F1: 0.3827
# *Epoch 45, model saved with Loss: 2.0285, Train F1: 0.3900, Val F1: 0.3872, Test F1: 0.3830
# *Epoch 49, model saved with Loss: 2.0187, Train F1: 0.3939, Val F1: 0.3879, Test F1: 0.3845
# *Epoch 50, model saved with Loss: 2.0166, Train F1: 0.3951, Val F1: 0.3894, Test F1: 0.3841
# *Epoch 51, model saved with Loss: 2.0144, Train F1: 0.3963, Val F1: 0.3898, Test F1: 0.3853
# *Epoch 52, model saved with Loss: 2.0131, Train F1: 0.3969, Val F1: 0.3907, Test F1: 0.3862
# *Epoch 53, model saved with Loss: 2.0098, Train F1: 0.3979, Val F1: 0.3910, Test F1: 0.3866
# *Epoch 56, model saved with Loss: 2.0037, Train F1: 0.3999, Val F1: 0.3926, Test F1: 0.3889
# *Epoch 57, model saved with Loss: 2.0000, Train F1: 0.4009, Val F1: 0.3943, Test F1: 0.3895
# *Epoch 59, model saved with Loss: 1.9973, Train F1: 0.4022, Val F1: 0.3944, Test F1: 0.3895
# *Epoch 62, model saved with Loss: 1.9863, Train F1: 0.4043, Val F1: 0.3946, Test F1: 0.3898
# *Epoch 70, model saved with Loss: 1.9689, Train F1: 0.4095, Val F1: 0.3956, Test F1: 0.3923
# *Epoch 75, model saved with Loss: 1.9577, Train F1: 0.4125, Val F1: 0.3962, Test F1: 0.3926
# *Epoch 78, model saved with Loss: 1.9478, Train F1: 0.4131, Val F1: 0.3977, Test F1: 0.3936
# *Epoch 82, model saved with Loss: 1.9386, Train F1: 0.4146, Val F1: 0.3988, Test F1: 0.3933
# *Epoch 84, model saved with Loss: 1.9361, Train F1: 0.4153, Val F1: 0.3988, Test F1: 0.3939
# *Epoch 91, model saved with Loss: 1.9186, Train F1: 0.4179, Val F1: 0.3988, Test F1: 0.3925
# *Epoch 93, model saved with Loss: 1.9175, Train F1: 0.4195, Val F1: 0.3988, Test F1: 0.3902
# *Epoch 95, model saved with Loss: 1.9091, Train F1: 0.4207, Val F1: 0.4005, Test F1: 0.3889
# *Epoch 96, model saved with Loss: 1.9096, Train F1: 0.4217, Val F1: 0.4018, Test F1: 0.3897
# Epoch 100, Loss: 1.9047, Train F1: 0.4236, Val F1: 0.4008, Test F1: 0.3897
# *Epoch 102, model saved with Loss: 1.9013, Train F1: 0.4248, Val F1: 0.4019, Test F1: 0.3900
# *Epoch 104, model saved with Loss: 1.8938, Train F1: 0.4259, Val F1: 0.4024, Test F1: 0.3894
# *Epoch 129, model saved with Loss: 1.8532, Train F1: 0.4370, Val F1: 0.4026, Test F1: 0.3941
# *Epoch 130, model saved with Loss: 1.8480, Train F1: 0.4377, Val F1: 0.4031, Test F1: 0.3938
# *Epoch 133, model saved with Loss: 1.8438, Train F1: 0.4409, Val F1: 0.4042, Test F1: 0.3949
# *Epoch 151, model saved with Loss: 1.8273, Train F1: 0.4483, Val F1: 0.4042, Test F1: 0.3992
# *Epoch 152, model saved with Loss: 1.8243, Train F1: 0.4482, Val F1: 0.4047, Test F1: 0.3990
# *Epoch 154, model saved with Loss: 1.8136, Train F1: 0.4490, Val F1: 0.4052, Test F1: 0.3990
# *Epoch 158, model saved with Loss: 1.8112, Train F1: 0.4508, Val F1: 0.4052, Test F1: 0.3993
# *Epoch 163, model saved with Loss: 1.8056, Train F1: 0.4531, Val F1: 0.4055, Test F1: 0.3993
# *Epoch 168, model saved with Loss: 1.7950, Train F1: 0.4557, Val F1: 0.4060, Test F1: 0.4005
# *Epoch 169, model saved with Loss: 1.7921, Train F1: 0.4566, Val F1: 0.4060, Test F1: 0.3995
# *Epoch 170, model saved with Loss: 1.7923, Train F1: 0.4573, Val F1: 0.4063, Test F1: 0.4013
# *Epoch 172, model saved with Loss: 1.7896, Train F1: 0.4587, Val F1: 0.4070, Test F1: 0.3998
# *Epoch 175, model saved with Loss: 1.7891, Train F1: 0.4611, Val F1: 0.4070, Test F1: 0.4009
# *Epoch 176, model saved with Loss: 1.7922, Train F1: 0.4611, Val F1: 0.4078, Test F1: 0.4018
# *Epoch 183, model saved with Loss: 1.7781, Train F1: 0.4650, Val F1: 0.4081, Test F1: 0.4021
# *Epoch 184, model saved with Loss: 1.7737, Train F1: 0.4649, Val F1: 0.4083, Test F1: 0.4013
# *Epoch 186, model saved with Loss: 1.7740, Train F1: 0.4662, Val F1: 0.4088, Test F1: 0.4034
# *Epoch 191, model saved with Loss: 1.7692, Train F1: 0.4687, Val F1: 0.4089, Test F1: 0.4055
# *Epoch 192, model saved with Loss: 1.7659, Train F1: 0.4698, Val F1: 0.4094, Test F1: 0.4081
# *Epoch 196, model saved with Loss: 1.7622, Train F1: 0.4716, Val F1: 0.4096, Test F1: 0.4078
# *Epoch 197, model saved with Loss: 1.7547, Train F1: 0.4725, Val F1: 0.4101, Test F1: 0.4075
# *Epoch 198, model saved with Loss: 1.7572, Train F1: 0.4731, Val F1: 0.4104, Test F1: 0.4078
# Epoch 200, Loss: 1.7551, Train F1: 0.4737, Val F1: 0.4096, Test F1: 0.4075
# *Epoch 201, model saved with Loss: 1.7485, Train F1: 0.4739, Val F1: 0.4104, Test F1: 0.4073
# *Epoch 208, model saved with Loss: 1.7462, Train F1: 0.4775, Val F1: 0.4117, Test F1: 0.4093
# *Epoch 216, model saved with Loss: 1.7348, Train F1: 0.4820, Val F1: 0.4125, Test F1: 0.4075
# *Epoch 217, model saved with Loss: 1.7346, Train F1: 0.4853, Val F1: 0.4132, Test F1: 0.4080
# *Epoch 218, model saved with Loss: 1.7336, Train F1: 0.4851, Val F1: 0.4134, Test F1: 0.4072
# *Epoch 219, model saved with Loss: 1.7291, Train F1: 0.4857, Val F1: 0.4142, Test F1: 0.4075
# *Epoch 221, model saved with Loss: 1.7350, Train F1: 0.4866, Val F1: 0.4153, Test F1: 0.4096
# *Epoch 226, model saved with Loss: 1.7190, Train F1: 0.4894, Val F1: 0.4156, Test F1: 0.4112
# *Epoch 237, model saved with Loss: 1.7079, Train F1: 0.4944, Val F1: 0.4163, Test F1: 0.4089
# *Epoch 238, model saved with Loss: 1.7074, Train F1: 0.4961, Val F1: 0.4166, Test F1: 0.4104
# *Epoch 242, model saved with Loss: 1.7167, Train F1: 0.4966, Val F1: 0.4178, Test F1: 0.4124
# *Epoch 243, model saved with Loss: 1.6999, Train F1: 0.4984, Val F1: 0.4186, Test F1: 0.4117
# *Epoch 245, model saved with Loss: 1.7121, Train F1: 0.5000, Val F1: 0.4191, Test F1: 0.4111
# *Epoch 246, model saved with Loss: 1.7013, Train F1: 0.5011, Val F1: 0.4205, Test F1: 0.4107
# *Epoch 248, model saved with Loss: 1.6974, Train F1: 0.5019, Val F1: 0.4205, Test F1: 0.4121
# *Epoch 251, model saved with Loss: 1.6925, Train F1: 0.5033, Val F1: 0.4210, Test F1: 0.4165
# *Epoch 257, model saved with Loss: 1.6875, Train F1: 0.5071, Val F1: 0.4217, Test F1: 0.4125
# *Epoch 258, model saved with Loss: 1.6857, Train F1: 0.5078, Val F1: 0.4227, Test F1: 0.4140
# *Epoch 259, model saved with Loss: 1.6849, Train F1: 0.5089, Val F1: 0.4236, Test F1: 0.4143
# *Epoch 271, model saved with Loss: 1.6725, Train F1: 0.5159, Val F1: 0.4241, Test F1: 0.4170
# *Epoch 272, model saved with Loss: 1.6666, Train F1: 0.5159, Val F1: 0.4250, Test F1: 0.4156
# *Epoch 275, model saved with Loss: 1.6672, Train F1: 0.5152, Val F1: 0.4253, Test F1: 0.4155
# *Epoch 276, model saved with Loss: 1.6609, Train F1: 0.5172, Val F1: 0.4253, Test F1: 0.4148
# *Epoch 277, model saved with Loss: 1.6646, Train F1: 0.5180, Val F1: 0.4258, Test F1: 0.4155
# *Epoch 282, model saved with Loss: 1.6634, Train F1: 0.5194, Val F1: 0.4263, Test F1: 0.4137
# *Epoch 285, model saved with Loss: 1.6576, Train F1: 0.5223, Val F1: 0.4264, Test F1: 0.4155
# *Epoch 291, model saved with Loss: 1.6717, Train F1: 0.5261, Val F1: 0.4272, Test F1: 0.4194
# *Epoch 292, model saved with Loss: 1.6718, Train F1: 0.5264, Val F1: 0.4279, Test F1: 0.4178
# *Epoch 295, model saved with Loss: 1.6573, Train F1: 0.5292, Val F1: 0.4284, Test F1: 0.4184
# *Epoch 299, model saved with Loss: 1.6443, Train F1: 0.5285, Val F1: 0.4285, Test F1: 0.4210
# Epoch 300, Loss: 1.6415, Train F1: 0.5288, Val F1: 0.4281, Test F1: 0.4201
# *Epoch 301, model saved with Loss: 1.6437, Train F1: 0.5302, Val F1: 0.4295, Test F1: 0.4205
# *Epoch 302, model saved with Loss: 1.6324, Train F1: 0.5322, Val F1: 0.4305, Test F1: 0.4220
# *Epoch 306, model saved with Loss: 1.6290, Train F1: 0.5332, Val F1: 0.4308, Test F1: 0.4212
# *Epoch 320, model saved with Loss: 1.6205, Train F1: 0.5424, Val F1: 0.4326, Test F1: 0.4248
# *Epoch 321, model saved with Loss: 1.6198, Train F1: 0.5430, Val F1: 0.4331, Test F1: 0.4253
# *Epoch 335, model saved with Loss: 1.6058, Train F1: 0.5521, Val F1: 0.4334, Test F1: 0.4284
# *Epoch 336, model saved with Loss: 1.6073, Train F1: 0.5528, Val F1: 0.4346, Test F1: 0.4276
# *Epoch 337, model saved with Loss: 1.6000, Train F1: 0.5521, Val F1: 0.4361, Test F1: 0.4281
# *Epoch 344, model saved with Loss: 1.6020, Train F1: 0.5590, Val F1: 0.4361, Test F1: 0.4287
# *Epoch 350, model saved with Loss: 1.5949, Train F1: 0.5596, Val F1: 0.4367, Test F1: 0.4290
# *Epoch 351, model saved with Loss: 1.5836, Train F1: 0.5617, Val F1: 0.4369, Test F1: 0.4294
# *Epoch 363, model saved with Loss: 1.5726, Train F1: 0.5675, Val F1: 0.4375, Test F1: 0.4339
# *Epoch 368, model saved with Loss: 1.5661, Train F1: 0.5696, Val F1: 0.4383, Test F1: 0.4315
# *Epoch 369, model saved with Loss: 1.5736, Train F1: 0.5715, Val F1: 0.4383, Test F1: 0.4318
# *Epoch 370, model saved with Loss: 1.5711, Train F1: 0.5718, Val F1: 0.4385, Test F1: 0.4317
# *Epoch 371, model saved with Loss: 1.5687, Train F1: 0.5719, Val F1: 0.4388, Test F1: 0.4326
# *Epoch 372, model saved with Loss: 1.5631, Train F1: 0.5740, Val F1: 0.4388, Test F1: 0.4331
# *Epoch 374, model saved with Loss: 1.5582, Train F1: 0.5743, Val F1: 0.4388, Test F1: 0.4328
# *Epoch 375, model saved with Loss: 1.5571, Train F1: 0.5759, Val F1: 0.4397, Test F1: 0.4317
# *Epoch 376, model saved with Loss: 1.5542, Train F1: 0.5764, Val F1: 0.4397, Test F1: 0.4330
# *Epoch 379, model saved with Loss: 1.5565, Train F1: 0.5787, Val F1: 0.4397, Test F1: 0.4334
# *Epoch 380, model saved with Loss: 1.5592, Train F1: 0.5786, Val F1: 0.4413, Test F1: 0.4336
# *Epoch 398, model saved with Loss: 1.5369, Train F1: 0.5872, Val F1: 0.4413, Test F1: 0.4339
# Epoch 400, Loss: 1.5420, Train F1: 0.5875, Val F1: 0.4406, Test F1: 0.4344
# *Epoch 401, model saved with Loss: 1.5435, Train F1: 0.5861, Val F1: 0.4415, Test F1: 0.4339
# *Epoch 405, model saved with Loss: 1.5369, Train F1: 0.5917, Val F1: 0.4415, Test F1: 0.4357
# *Epoch 417, model saved with Loss: 1.5204, Train F1: 0.5990, Val F1: 0.4426, Test F1: 0.4375
# *Epoch 419, model saved with Loss: 1.5168, Train F1: 0.5977, Val F1: 0.4428, Test F1: 0.4377
# *Epoch 420, model saved with Loss: 1.5222, Train F1: 0.5995, Val F1: 0.4439, Test F1: 0.4388
# *Epoch 421, model saved with Loss: 1.5292, Train F1: 0.5976, Val F1: 0.4446, Test F1: 0.4385
# *Epoch 432, model saved with Loss: 1.5044, Train F1: 0.6053, Val F1: 0.4462, Test F1: 0.4385
# *Epoch 462, model saved with Loss: 1.4770, Train F1: 0.6172, Val F1: 0.4462, Test F1: 0.4418
# *Epoch 463, model saved with Loss: 1.4758, Train F1: 0.6176, Val F1: 0.4470, Test F1: 0.4411
# *Epoch 464, model saved with Loss: 1.4727, Train F1: 0.6181, Val F1: 0.4470, Test F1: 0.4419
# *Epoch 465, model saved with Loss: 1.4724, Train F1: 0.6213, Val F1: 0.4470, Test F1: 0.4429
# *Epoch 469, model saved with Loss: 1.4680, Train F1: 0.6203, Val F1: 0.4477, Test F1: 0.4452
# *Epoch 478, model saved with Loss: 1.4605, Train F1: 0.6237, Val F1: 0.4477, Test F1: 0.4437
# *Epoch 479, model saved with Loss: 1.4597, Train F1: 0.6253, Val F1: 0.4486, Test F1: 0.4447
# *Epoch 482, model saved with Loss: 1.4583, Train F1: 0.6271, Val F1: 0.4486, Test F1: 0.4449
# *Epoch 483, model saved with Loss: 1.4563, Train F1: 0.6259, Val F1: 0.4488, Test F1: 0.4454
# *Epoch 492, model saved with Loss: 1.4494, Train F1: 0.6330, Val F1: 0.4488, Test F1: 0.4460
# *Epoch 495, model saved with Loss: 1.4438, Train F1: 0.6333, Val F1: 0.4495, Test F1: 0.4452
# Best Test F1 throughout: 0.4460
# Loading best model for final evaluation...: 0.4495
# Best Test F1 after loading saved model: 0.4452
# Run: 1
# *Epoch 0, model saved with Loss: 2.2916, Train F1: 0.3254, Val F1: 0.3230, Test F1: 0.3209
# Epoch 0, Loss: 2.2916, Train F1: 0.3254, Val F1: 0.3230, Test F1: 0.3209
# *Epoch 1, model saved with Loss: 2.2722, Train F1: 0.3484, Val F1: 0.3451, Test F1: 0.3448
# *Epoch 2, model saved with Loss: 2.2544, Train F1: 0.3598, Val F1: 0.3526, Test F1: 0.3560
# *Epoch 3, model saved with Loss: 2.2336, Train F1: 0.3626, Val F1: 0.3603, Test F1: 0.3621
# *Epoch 4, model saved with Loss: 2.2145, Train F1: 0.3654, Val F1: 0.3632, Test F1: 0.3644
# *Epoch 5, model saved with Loss: 2.1979, Train F1: 0.3661, Val F1: 0.3650, Test F1: 0.3658
# *Epoch 7, model saved with Loss: 2.1705, Train F1: 0.3668, Val F1: 0.3660, Test F1: 0.3678
# *Epoch 8, model saved with Loss: 2.1582, Train F1: 0.3671, Val F1: 0.3663, Test F1: 0.3684
# *Epoch 9, model saved with Loss: 2.1461, Train F1: 0.3671, Val F1: 0.3667, Test F1: 0.3681
# *Epoch 10, model saved with Loss: 2.1323, Train F1: 0.3675, Val F1: 0.3670, Test F1: 0.3676
# *Epoch 12, model saved with Loss: 2.1135, Train F1: 0.3680, Val F1: 0.3673, Test F1: 0.3676
# *Epoch 15, model saved with Loss: 2.0932, Train F1: 0.3684, Val F1: 0.3675, Test F1: 0.3684
# *Epoch 16, model saved with Loss: 2.0860, Train F1: 0.3687, Val F1: 0.3678, Test F1: 0.3689
# *Epoch 18, model saved with Loss: 2.0789, Train F1: 0.3689, Val F1: 0.3678, Test F1: 0.3689
# *Epoch 19, model saved with Loss: 2.0757, Train F1: 0.3701, Val F1: 0.3688, Test F1: 0.3696
# *Epoch 20, model saved with Loss: 2.0746, Train F1: 0.3713, Val F1: 0.3704, Test F1: 0.3714
# *Epoch 21, model saved with Loss: 2.0734, Train F1: 0.3721, Val F1: 0.3709, Test F1: 0.3719
# *Epoch 28, model saved with Loss: 2.0656, Train F1: 0.3796, Val F1: 0.3714, Test F1: 0.3725
# *Epoch 29, model saved with Loss: 2.0633, Train F1: 0.3802, Val F1: 0.3717, Test F1: 0.3737
# *Epoch 31, model saved with Loss: 2.0594, Train F1: 0.3804, Val F1: 0.3730, Test F1: 0.3743
# *Epoch 32, model saved with Loss: 2.0552, Train F1: 0.3806, Val F1: 0.3740, Test F1: 0.3743
# *Epoch 33, model saved with Loss: 2.0556, Train F1: 0.3815, Val F1: 0.3740, Test F1: 0.3750
# *Epoch 34, model saved with Loss: 2.0528, Train F1: 0.3813, Val F1: 0.3753, Test F1: 0.3751
# *Epoch 35, model saved with Loss: 2.0487, Train F1: 0.3820, Val F1: 0.3760, Test F1: 0.3758
# *Epoch 36, model saved with Loss: 2.0494, Train F1: 0.3831, Val F1: 0.3764, Test F1: 0.3756
# *Epoch 37, model saved with Loss: 2.0480, Train F1: 0.3838, Val F1: 0.3768, Test F1: 0.3756
# *Epoch 38, model saved with Loss: 2.0451, Train F1: 0.3843, Val F1: 0.3776, Test F1: 0.3753
# *Epoch 39, model saved with Loss: 2.0453, Train F1: 0.3847, Val F1: 0.3784, Test F1: 0.3753
# *Epoch 40, model saved with Loss: 2.0421, Train F1: 0.3857, Val F1: 0.3800, Test F1: 0.3786
# *Epoch 41, model saved with Loss: 2.0410, Train F1: 0.3870, Val F1: 0.3812, Test F1: 0.3791
# *Epoch 42, model saved with Loss: 2.0397, Train F1: 0.3871, Val F1: 0.3822, Test F1: 0.3792
# *Epoch 43, model saved with Loss: 2.0375, Train F1: 0.3890, Val F1: 0.3840, Test F1: 0.3802
# *Epoch 44, model saved with Loss: 2.0374, Train F1: 0.3896, Val F1: 0.3841, Test F1: 0.3804
# *Epoch 45, model saved with Loss: 2.0332, Train F1: 0.3907, Val F1: 0.3861, Test F1: 0.3820
# *Epoch 57, model saved with Loss: 2.0095, Train F1: 0.3987, Val F1: 0.3877, Test F1: 0.3874
# *Epoch 58, model saved with Loss: 2.0086, Train F1: 0.4000, Val F1: 0.3905, Test F1: 0.3892
# *Epoch 62, model saved with Loss: 1.9962, Train F1: 0.4043, Val F1: 0.3911, Test F1: 0.3920
# *Epoch 63, model saved with Loss: 1.9986, Train F1: 0.4048, Val F1: 0.3915, Test F1: 0.3916
# *Epoch 64, model saved with Loss: 1.9942, Train F1: 0.4051, Val F1: 0.3923, Test F1: 0.3918
# *Epoch 65, model saved with Loss: 1.9925, Train F1: 0.4057, Val F1: 0.3926, Test F1: 0.3910
# *Epoch 68, model saved with Loss: 1.9842, Train F1: 0.4079, Val F1: 0.3933, Test F1: 0.3920
# *Epoch 70, model saved with Loss: 1.9791, Train F1: 0.4085, Val F1: 0.3938, Test F1: 0.3933
# *Epoch 81, model saved with Loss: 1.9561, Train F1: 0.4156, Val F1: 0.3941, Test F1: 0.3944
# *Epoch 83, model saved with Loss: 1.9486, Train F1: 0.4139, Val F1: 0.3941, Test F1: 0.3928
# *Epoch 84, model saved with Loss: 1.9471, Train F1: 0.4150, Val F1: 0.3947, Test F1: 0.3931
# *Epoch 85, model saved with Loss: 1.9455, Train F1: 0.4154, Val F1: 0.3957, Test F1: 0.3936
# *Epoch 86, model saved with Loss: 1.9413, Train F1: 0.4166, Val F1: 0.3972, Test F1: 0.3918
# *Epoch 87, model saved with Loss: 1.9423, Train F1: 0.4171, Val F1: 0.3983, Test F1: 0.3913
# *Epoch 99, model saved with Loss: 1.9161, Train F1: 0.4232, Val F1: 0.3985, Test F1: 0.3931
# Epoch 100, Loss: 1.9119, Train F1: 0.4241, Val F1: 0.3975, Test F1: 0.3925
# *Epoch 104, model saved with Loss: 1.9056, Train F1: 0.4277, Val F1: 0.3998, Test F1: 0.3905
# *Epoch 119, model saved with Loss: 1.8824, Train F1: 0.4323, Val F1: 0.4000, Test F1: 0.3879
# *Epoch 122, model saved with Loss: 1.8753, Train F1: 0.4329, Val F1: 0.4019, Test F1: 0.3887
# *Epoch 124, model saved with Loss: 1.8700, Train F1: 0.4343, Val F1: 0.4027, Test F1: 0.3907
# *Epoch 127, model saved with Loss: 1.8636, Train F1: 0.4361, Val F1: 0.4032, Test F1: 0.3925
# *Epoch 128, model saved with Loss: 1.8637, Train F1: 0.4359, Val F1: 0.4032, Test F1: 0.3934
# *Epoch 129, model saved with Loss: 1.8609, Train F1: 0.4365, Val F1: 0.4036, Test F1: 0.3934
# *Epoch 130, model saved with Loss: 1.8608, Train F1: 0.4377, Val F1: 0.4045, Test F1: 0.3928
# *Epoch 131, model saved with Loss: 1.8572, Train F1: 0.4388, Val F1: 0.4045, Test F1: 0.3929
# *Epoch 132, model saved with Loss: 1.8562, Train F1: 0.4387, Val F1: 0.4060, Test F1: 0.3929
# *Epoch 133, model saved with Loss: 1.8512, Train F1: 0.4392, Val F1: 0.4078, Test F1: 0.3934
# *Epoch 154, model saved with Loss: 1.8202, Train F1: 0.4490, Val F1: 0.4086, Test F1: 0.3987
# *Epoch 160, model saved with Loss: 1.8132, Train F1: 0.4518, Val F1: 0.4086, Test F1: 0.4013
# *Epoch 163, model saved with Loss: 1.8071, Train F1: 0.4544, Val F1: 0.4086, Test F1: 0.4000
# *Epoch 164, model saved with Loss: 1.8081, Train F1: 0.4543, Val F1: 0.4089, Test F1: 0.4000
# *Epoch 165, model saved with Loss: 1.8056, Train F1: 0.4553, Val F1: 0.4101, Test F1: 0.4013
# *Epoch 166, model saved with Loss: 1.8048, Train F1: 0.4564, Val F1: 0.4106, Test F1: 0.4021
# *Epoch 195, model saved with Loss: 1.7670, Train F1: 0.4730, Val F1: 0.4106, Test F1: 0.4072
# *Epoch 196, model saved with Loss: 1.7637, Train F1: 0.4739, Val F1: 0.4111, Test F1: 0.4091
# *Epoch 200, model saved with Loss: 1.7572, Train F1: 0.4744, Val F1: 0.4119, Test F1: 0.4078
# Epoch 200, Loss: 1.7572, Train F1: 0.4744, Val F1: 0.4119, Test F1: 0.4078
# *Epoch 210, model saved with Loss: 1.7510, Train F1: 0.4829, Val F1: 0.4129, Test F1: 0.4116
# *Epoch 213, model saved with Loss: 1.7442, Train F1: 0.4842, Val F1: 0.4130, Test F1: 0.4138
# *Epoch 215, model saved with Loss: 1.7373, Train F1: 0.4851, Val F1: 0.4132, Test F1: 0.4130
# *Epoch 216, model saved with Loss: 1.7427, Train F1: 0.4852, Val F1: 0.4137, Test F1: 0.4134
# *Epoch 217, model saved with Loss: 1.7406, Train F1: 0.4865, Val F1: 0.4148, Test F1: 0.4140
# *Epoch 222, model saved with Loss: 1.7302, Train F1: 0.4903, Val F1: 0.4148, Test F1: 0.4153
# *Epoch 223, model saved with Loss: 1.7332, Train F1: 0.4912, Val F1: 0.4152, Test F1: 0.4150
# *Epoch 224, model saved with Loss: 1.7304, Train F1: 0.4919, Val F1: 0.4153, Test F1: 0.4135
# *Epoch 226, model saved with Loss: 1.7354, Train F1: 0.4941, Val F1: 0.4160, Test F1: 0.4135
# *Epoch 234, model saved with Loss: 1.7146, Train F1: 0.4993, Val F1: 0.4170, Test F1: 0.4165
# *Epoch 237, model saved with Loss: 1.7127, Train F1: 0.5014, Val F1: 0.4187, Test F1: 0.4186
# *Epoch 243, model saved with Loss: 1.7100, Train F1: 0.5047, Val F1: 0.4187, Test F1: 0.4174
# *Epoch 245, model saved with Loss: 1.7049, Train F1: 0.5056, Val F1: 0.4210, Test F1: 0.4194
# *Epoch 261, model saved with Loss: 1.6835, Train F1: 0.5141, Val F1: 0.4210, Test F1: 0.4215
# *Epoch 264, model saved with Loss: 1.6873, Train F1: 0.5171, Val F1: 0.4222, Test F1: 0.4238
# *Epoch 265, model saved with Loss: 1.7019, Train F1: 0.5165, Val F1: 0.4222, Test F1: 0.4205
# *Epoch 266, model saved with Loss: 1.6835, Train F1: 0.5179, Val F1: 0.4228, Test F1: 0.4215
# *Epoch 270, model saved with Loss: 1.6745, Train F1: 0.5198, Val F1: 0.4228, Test F1: 0.4209
# *Epoch 273, model saved with Loss: 1.6655, Train F1: 0.5207, Val F1: 0.4233, Test F1: 0.4225
# *Epoch 278, model saved with Loss: 1.6692, Train F1: 0.5269, Val F1: 0.4236, Test F1: 0.4245
# *Epoch 279, model saved with Loss: 1.6627, Train F1: 0.5269, Val F1: 0.4253, Test F1: 0.4254
# *Epoch 284, model saved with Loss: 1.6576, Train F1: 0.5294, Val F1: 0.4268, Test F1: 0.4245
# Epoch 300, Loss: 1.6391, Train F1: 0.5388, Val F1: 0.4261, Test F1: 0.4264
# *Epoch 301, model saved with Loss: 1.6382, Train F1: 0.5417, Val F1: 0.4269, Test F1: 0.4295
# *Epoch 302, model saved with Loss: 1.6331, Train F1: 0.5398, Val F1: 0.4276, Test F1: 0.4290
# *Epoch 316, model saved with Loss: 1.6168, Train F1: 0.5503, Val F1: 0.4284, Test F1: 0.4315
# *Epoch 318, model saved with Loss: 1.6139, Train F1: 0.5505, Val F1: 0.4289, Test F1: 0.4321
# *Epoch 326, model saved with Loss: 1.6092, Train F1: 0.5528, Val F1: 0.4299, Test F1: 0.4325
# *Epoch 333, model saved with Loss: 1.6082, Train F1: 0.5583, Val F1: 0.4299, Test F1: 0.4321
# *Epoch 334, model saved with Loss: 1.6000, Train F1: 0.5596, Val F1: 0.4302, Test F1: 0.4308
# *Epoch 336, model saved with Loss: 1.5973, Train F1: 0.5606, Val F1: 0.4307, Test F1: 0.4328
# *Epoch 344, model saved with Loss: 1.5987, Train F1: 0.5655, Val F1: 0.4310, Test F1: 0.4336
# *Epoch 345, model saved with Loss: 1.5854, Train F1: 0.5653, Val F1: 0.4315, Test F1: 0.4334
# *Epoch 348, model saved with Loss: 1.5960, Train F1: 0.5655, Val F1: 0.4321, Test F1: 0.4326
# *Epoch 349, model saved with Loss: 1.5849, Train F1: 0.5647, Val F1: 0.4330, Test F1: 0.4341
# *Epoch 350, model saved with Loss: 1.5854, Train F1: 0.5655, Val F1: 0.4336, Test F1: 0.4328
# *Epoch 355, model saved with Loss: 1.5827, Train F1: 0.5697, Val F1: 0.4341, Test F1: 0.4348
# *Epoch 357, model saved with Loss: 1.5864, Train F1: 0.5701, Val F1: 0.4344, Test F1: 0.4349
# *Epoch 368, model saved with Loss: 1.5731, Train F1: 0.5835, Val F1: 0.4348, Test F1: 0.4357
# *Epoch 372, model saved with Loss: 1.5662, Train F1: 0.5793, Val F1: 0.4354, Test F1: 0.4357
# *Epoch 384, model saved with Loss: 1.5521, Train F1: 0.5902, Val F1: 0.4359, Test F1: 0.4397
# *Epoch 396, model saved with Loss: 1.5340, Train F1: 0.5969, Val F1: 0.4361, Test F1: 0.4395
# Epoch 400, Loss: 1.5282, Train F1: 0.5955, Val F1: 0.4334, Test F1: 0.4390
# *Epoch 405, model saved with Loss: 1.5221, Train F1: 0.6004, Val F1: 0.4366, Test F1: 0.4406
# *Epoch 417, model saved with Loss: 1.5274, Train F1: 0.6067, Val F1: 0.4369, Test F1: 0.4411
# *Epoch 430, model saved with Loss: 1.5021, Train F1: 0.6138, Val F1: 0.4369, Test F1: 0.4431
# *Epoch 431, model saved with Loss: 1.4977, Train F1: 0.6114, Val F1: 0.4369, Test F1: 0.4421
# *Epoch 433, model saved with Loss: 1.4977, Train F1: 0.6140, Val F1: 0.4387, Test F1: 0.4436
# *Epoch 436, model saved with Loss: 1.4899, Train F1: 0.6166, Val F1: 0.4393, Test F1: 0.4462
# *Epoch 440, model saved with Loss: 1.5001, Train F1: 0.6169, Val F1: 0.4401, Test F1: 0.4460
# *Epoch 457, model saved with Loss: 1.4751, Train F1: 0.6251, Val F1: 0.4411, Test F1: 0.4465
# *Epoch 459, model saved with Loss: 1.4755, Train F1: 0.6260, Val F1: 0.4416, Test F1: 0.4473
# *Epoch 460, model saved with Loss: 1.4686, Train F1: 0.6258, Val F1: 0.4416, Test F1: 0.4455
# *Epoch 468, model saved with Loss: 1.4756, Train F1: 0.6289, Val F1: 0.4419, Test F1: 0.4480
# *Epoch 469, model saved with Loss: 1.4656, Train F1: 0.6298, Val F1: 0.4419, Test F1: 0.4473
# *Epoch 476, model saved with Loss: 1.4583, Train F1: 0.6309, Val F1: 0.4421, Test F1: 0.4475
# *Epoch 477, model saved with Loss: 1.4510, Train F1: 0.6347, Val F1: 0.4432, Test F1: 0.4485
# *Epoch 482, model saved with Loss: 1.4489, Train F1: 0.6329, Val F1: 0.4441, Test F1: 0.4475
# *Epoch 483, model saved with Loss: 1.4583, Train F1: 0.6375, Val F1: 0.4454, Test F1: 0.4480
# *Epoch 484, model saved with Loss: 1.4482, Train F1: 0.6368, Val F1: 0.4454, Test F1: 0.4473
# *Epoch 491, model saved with Loss: 1.4423, Train F1: 0.6387, Val F1: 0.4454, Test F1: 0.4490
# *Epoch 492, model saved with Loss: 1.4424, Train F1: 0.6372, Val F1: 0.4454, Test F1: 0.4485
# *Epoch 493, model saved with Loss: 1.4425, Train F1: 0.6405, Val F1: 0.4472, Test F1: 0.4499
# *Epoch 498, model saved with Loss: 1.4377, Train F1: 0.6412, Val F1: 0.4475, Test F1: 0.4488
# *Epoch 499, model saved with Loss: 1.4353, Train F1: 0.6436, Val F1: 0.4477, Test F1: 0.4504
# Best Test F1 throughout: 0.4504
# Loading best model for final evaluation...: 0.4477
# Best Test F1 after loading saved model: 0.4504
# Run: 2
# *Epoch 0, model saved with Loss: 2.3301, Train F1: 0.2126, Val F1: 0.2149, Test F1: 0.2061
# Epoch 0, Loss: 2.3301, Train F1: 0.2126, Val F1: 0.2149, Test F1: 0.2061
# *Epoch 1, model saved with Loss: 2.3060, Train F1: 0.2953, Val F1: 0.3007, Test F1: 0.2891
# *Epoch 2, model saved with Loss: 2.2836, Train F1: 0.3337, Val F1: 0.3310, Test F1: 0.3212
# *Epoch 3, model saved with Loss: 2.2647, Train F1: 0.3533, Val F1: 0.3471, Test F1: 0.3408
# *Epoch 4, model saved with Loss: 2.2436, Train F1: 0.3622, Val F1: 0.3569, Test F1: 0.3562
# *Epoch 5, model saved with Loss: 2.2272, Train F1: 0.3662, Val F1: 0.3608, Test F1: 0.3618
# *Epoch 6, model saved with Loss: 2.2097, Train F1: 0.3664, Val F1: 0.3649, Test F1: 0.3657
# *Epoch 7, model saved with Loss: 2.1947, Train F1: 0.3678, Val F1: 0.3658, Test F1: 0.3667
# *Epoch 8, model saved with Loss: 2.1824, Train F1: 0.3679, Val F1: 0.3660, Test F1: 0.3668
# *Epoch 10, model saved with Loss: 2.1524, Train F1: 0.3682, Val F1: 0.3670, Test F1: 0.3670
# *Epoch 13, model saved with Loss: 2.1200, Train F1: 0.3692, Val F1: 0.3675, Test F1: 0.3675
# *Epoch 14, model saved with Loss: 2.1110, Train F1: 0.3690, Val F1: 0.3676, Test F1: 0.3676
# *Epoch 17, model saved with Loss: 2.0906, Train F1: 0.3684, Val F1: 0.3676, Test F1: 0.3675
# *Epoch 18, model saved with Loss: 2.0853, Train F1: 0.3685, Val F1: 0.3678, Test F1: 0.3676
# *Epoch 20, model saved with Loss: 2.0797, Train F1: 0.3692, Val F1: 0.3678, Test F1: 0.3686
# *Epoch 21, model saved with Loss: 2.0773, Train F1: 0.3698, Val F1: 0.3680, Test F1: 0.3696
# *Epoch 22, model saved with Loss: 2.0744, Train F1: 0.3707, Val F1: 0.3689, Test F1: 0.3702
# *Epoch 25, model saved with Loss: 2.0724, Train F1: 0.3726, Val F1: 0.3712, Test F1: 0.3714
# *Epoch 28, model saved with Loss: 2.0661, Train F1: 0.3759, Val F1: 0.3714, Test F1: 0.3729
# *Epoch 31, model saved with Loss: 2.0600, Train F1: 0.3784, Val F1: 0.3730, Test F1: 0.3751
# *Epoch 34, model saved with Loss: 2.0554, Train F1: 0.3797, Val F1: 0.3737, Test F1: 0.3764
# *Epoch 35, model saved with Loss: 2.0524, Train F1: 0.3800, Val F1: 0.3743, Test F1: 0.3764
# *Epoch 36, model saved with Loss: 2.0511, Train F1: 0.3811, Val F1: 0.3758, Test F1: 0.3766
# *Epoch 37, model saved with Loss: 2.0481, Train F1: 0.3813, Val F1: 0.3758, Test F1: 0.3768
# *Epoch 38, model saved with Loss: 2.0461, Train F1: 0.3818, Val F1: 0.3781, Test F1: 0.3764
# *Epoch 39, model saved with Loss: 2.0463, Train F1: 0.3821, Val F1: 0.3799, Test F1: 0.3761
# *Epoch 40, model saved with Loss: 2.0430, Train F1: 0.3831, Val F1: 0.3815, Test F1: 0.3761
# *Epoch 41, model saved with Loss: 2.0420, Train F1: 0.3845, Val F1: 0.3823, Test F1: 0.3773
# *Epoch 42, model saved with Loss: 2.0396, Train F1: 0.3856, Val F1: 0.3831, Test F1: 0.3774
# *Epoch 43, model saved with Loss: 2.0376, Train F1: 0.3866, Val F1: 0.3841, Test F1: 0.3789
# *Epoch 44, model saved with Loss: 2.0343, Train F1: 0.3867, Val F1: 0.3843, Test F1: 0.3791
# *Epoch 45, model saved with Loss: 2.0342, Train F1: 0.3876, Val F1: 0.3845, Test F1: 0.3796
# *Epoch 49, model saved with Loss: 2.0258, Train F1: 0.3909, Val F1: 0.3845, Test F1: 0.3809
# *Epoch 50, model saved with Loss: 2.0242, Train F1: 0.3922, Val F1: 0.3858, Test F1: 0.3807
# *Epoch 51, model saved with Loss: 2.0226, Train F1: 0.3925, Val F1: 0.3861, Test F1: 0.3802
# *Epoch 56, model saved with Loss: 2.0122, Train F1: 0.3963, Val F1: 0.3867, Test F1: 0.3848
# *Epoch 57, model saved with Loss: 2.0102, Train F1: 0.3970, Val F1: 0.3872, Test F1: 0.3854
# *Epoch 58, model saved with Loss: 2.0109, Train F1: 0.3983, Val F1: 0.3876, Test F1: 0.3846
# *Epoch 59, model saved with Loss: 2.0059, Train F1: 0.3995, Val F1: 0.3885, Test F1: 0.3845
# *Epoch 60, model saved with Loss: 2.0034, Train F1: 0.3991, Val F1: 0.3894, Test F1: 0.3838
# *Epoch 61, model saved with Loss: 2.0018, Train F1: 0.3997, Val F1: 0.3905, Test F1: 0.3835
# *Epoch 62, model saved with Loss: 1.9982, Train F1: 0.3999, Val F1: 0.3911, Test F1: 0.3836
# *Epoch 66, model saved with Loss: 1.9900, Train F1: 0.4023, Val F1: 0.3923, Test F1: 0.3861
# *Epoch 67, model saved with Loss: 1.9883, Train F1: 0.4040, Val F1: 0.3928, Test F1: 0.3876
# *Epoch 68, model saved with Loss: 1.9875, Train F1: 0.4040, Val F1: 0.3928, Test F1: 0.3882
# *Epoch 69, model saved with Loss: 1.9854, Train F1: 0.4049, Val F1: 0.3934, Test F1: 0.3892
# *Epoch 70, model saved with Loss: 1.9806, Train F1: 0.4067, Val F1: 0.3934, Test F1: 0.3903
# *Epoch 71, model saved with Loss: 1.9820, Train F1: 0.4062, Val F1: 0.3944, Test F1: 0.3911
# *Epoch 75, model saved with Loss: 1.9693, Train F1: 0.4085, Val F1: 0.3944, Test F1: 0.3907
# *Epoch 76, model saved with Loss: 1.9650, Train F1: 0.4090, Val F1: 0.3947, Test F1: 0.3908
# *Epoch 79, model saved with Loss: 1.9593, Train F1: 0.4106, Val F1: 0.3947, Test F1: 0.3915
# *Epoch 84, model saved with Loss: 1.9458, Train F1: 0.4125, Val F1: 0.3956, Test F1: 0.3928
# *Epoch 89, model saved with Loss: 1.9474, Train F1: 0.4158, Val F1: 0.3957, Test F1: 0.3923
# *Epoch 90, model saved with Loss: 1.9401, Train F1: 0.4145, Val F1: 0.3957, Test F1: 0.3920
# *Epoch 93, model saved with Loss: 1.9346, Train F1: 0.4165, Val F1: 0.3957, Test F1: 0.3936
# *Epoch 94, model saved with Loss: 1.9380, Train F1: 0.4163, Val F1: 0.3957, Test F1: 0.3921
# *Epoch 95, model saved with Loss: 1.9303, Train F1: 0.4164, Val F1: 0.3959, Test F1: 0.3911
# *Epoch 97, model saved with Loss: 1.9231, Train F1: 0.4179, Val F1: 0.3962, Test F1: 0.3911
# *Epoch 98, model saved with Loss: 1.9245, Train F1: 0.4179, Val F1: 0.3962, Test F1: 0.3911
# *Epoch 99, model saved with Loss: 1.9243, Train F1: 0.4187, Val F1: 0.3965, Test F1: 0.3902
# Epoch 100, Loss: 1.9190, Train F1: 0.4190, Val F1: 0.3957, Test F1: 0.3890
# *Epoch 103, model saved with Loss: 1.9178, Train F1: 0.4203, Val F1: 0.3965, Test F1: 0.3872
# *Epoch 107, model saved with Loss: 1.9074, Train F1: 0.4228, Val F1: 0.3965, Test F1: 0.3880
# *Epoch 109, model saved with Loss: 1.9047, Train F1: 0.4235, Val F1: 0.3974, Test F1: 0.3877
# *Epoch 110, model saved with Loss: 1.8997, Train F1: 0.4238, Val F1: 0.3978, Test F1: 0.3880
# *Epoch 111, model saved with Loss: 1.8992, Train F1: 0.4238, Val F1: 0.3990, Test F1: 0.3879
# *Epoch 112, model saved with Loss: 1.8963, Train F1: 0.4245, Val F1: 0.3993, Test F1: 0.3880
# *Epoch 118, model saved with Loss: 1.8889, Train F1: 0.4259, Val F1: 0.3993, Test F1: 0.3876
# *Epoch 119, model saved with Loss: 1.8846, Train F1: 0.4265, Val F1: 0.3998, Test F1: 0.3884
# *Epoch 120, model saved with Loss: 1.8838, Train F1: 0.4272, Val F1: 0.3998, Test F1: 0.3885
# *Epoch 121, model saved with Loss: 1.8813, Train F1: 0.4273, Val F1: 0.3998, Test F1: 0.3876
# *Epoch 127, model saved with Loss: 1.8770, Train F1: 0.4312, Val F1: 0.4001, Test F1: 0.3897
# *Epoch 130, model saved with Loss: 1.8702, Train F1: 0.4317, Val F1: 0.4001, Test F1: 0.3895
# *Epoch 135, model saved with Loss: 1.8614, Train F1: 0.4343, Val F1: 0.4014, Test F1: 0.3913
# *Epoch 138, model saved with Loss: 1.8603, Train F1: 0.4369, Val F1: 0.4024, Test F1: 0.3918
# *Epoch 144, model saved with Loss: 1.8495, Train F1: 0.4391, Val F1: 0.4031, Test F1: 0.3938
# *Epoch 153, model saved with Loss: 1.8396, Train F1: 0.4441, Val F1: 0.4036, Test F1: 0.3960
# *Epoch 154, model saved with Loss: 1.8334, Train F1: 0.4439, Val F1: 0.4044, Test F1: 0.3960
# *Epoch 163, model saved with Loss: 1.8182, Train F1: 0.4497, Val F1: 0.4054, Test F1: 0.3957
# *Epoch 167, model saved with Loss: 1.8285, Train F1: 0.4490, Val F1: 0.4067, Test F1: 0.3949
# *Epoch 169, model saved with Loss: 1.8342, Train F1: 0.4518, Val F1: 0.4070, Test F1: 0.3972
# *Epoch 170, model saved with Loss: 1.8121, Train F1: 0.4510, Val F1: 0.4070, Test F1: 0.3964
# *Epoch 171, model saved with Loss: 1.8292, Train F1: 0.4538, Val F1: 0.4076, Test F1: 0.3967
# *Epoch 172, model saved with Loss: 1.8228, Train F1: 0.4544, Val F1: 0.4078, Test F1: 0.3978
# *Epoch 176, model saved with Loss: 1.8191, Train F1: 0.4567, Val F1: 0.4080, Test F1: 0.3993
# *Epoch 180, model saved with Loss: 1.8145, Train F1: 0.4579, Val F1: 0.4085, Test F1: 0.3982
# *Epoch 181, model saved with Loss: 1.7990, Train F1: 0.4578, Val F1: 0.4086, Test F1: 0.3987
# *Epoch 182, model saved with Loss: 1.8074, Train F1: 0.4592, Val F1: 0.4093, Test F1: 0.3993
# Epoch 200, Loss: 1.7804, Train F1: 0.4689, Val F1: 0.4088, Test F1: 0.4042
# *Epoch 213, model saved with Loss: 1.7647, Train F1: 0.4753, Val F1: 0.4098, Test F1: 0.4070
# *Epoch 215, model saved with Loss: 1.7637, Train F1: 0.4781, Val F1: 0.4101, Test F1: 0.4065
# *Epoch 216, model saved with Loss: 1.7602, Train F1: 0.4775, Val F1: 0.4117, Test F1: 0.4075
# *Epoch 217, model saved with Loss: 1.7572, Train F1: 0.4798, Val F1: 0.4121, Test F1: 0.4089
# *Epoch 220, model saved with Loss: 1.7517, Train F1: 0.4813, Val F1: 0.4122, Test F1: 0.4080
# *Epoch 222, model saved with Loss: 1.7490, Train F1: 0.4820, Val F1: 0.4122, Test F1: 0.4083
# *Epoch 223, model saved with Loss: 1.7512, Train F1: 0.4831, Val F1: 0.4125, Test F1: 0.4086
# *Epoch 227, model saved with Loss: 1.7442, Train F1: 0.4833, Val F1: 0.4127, Test F1: 0.4112
# *Epoch 228, model saved with Loss: 1.7481, Train F1: 0.4858, Val F1: 0.4137, Test F1: 0.4114
# *Epoch 229, model saved with Loss: 1.7473, Train F1: 0.4846, Val F1: 0.4138, Test F1: 0.4114
# *Epoch 230, model saved with Loss: 1.7491, Train F1: 0.4873, Val F1: 0.4143, Test F1: 0.4112
# *Epoch 232, model saved with Loss: 1.7419, Train F1: 0.4864, Val F1: 0.4145, Test F1: 0.4121
# *Epoch 234, model saved with Loss: 1.7411, Train F1: 0.4867, Val F1: 0.4168, Test F1: 0.4122
# *Epoch 235, model saved with Loss: 1.7352, Train F1: 0.4866, Val F1: 0.4168, Test F1: 0.4114
# *Epoch 236, model saved with Loss: 1.7377, Train F1: 0.4882, Val F1: 0.4168, Test F1: 0.4114
# *Epoch 237, model saved with Loss: 1.7400, Train F1: 0.4873, Val F1: 0.4168, Test F1: 0.4107
# *Epoch 239, model saved with Loss: 1.7315, Train F1: 0.4891, Val F1: 0.4179, Test F1: 0.4124
# *Epoch 242, model saved with Loss: 1.7296, Train F1: 0.4908, Val F1: 0.4179, Test F1: 0.4122
# *Epoch 249, model saved with Loss: 1.7173, Train F1: 0.4972, Val F1: 0.4191, Test F1: 0.4135
# *Epoch 250, model saved with Loss: 1.7184, Train F1: 0.4971, Val F1: 0.4202, Test F1: 0.4148
# *Epoch 255, model saved with Loss: 1.7200, Train F1: 0.4991, Val F1: 0.4202, Test F1: 0.4156
# *Epoch 257, model saved with Loss: 1.7096, Train F1: 0.5026, Val F1: 0.4212, Test F1: 0.4140
# *Epoch 258, model saved with Loss: 1.7094, Train F1: 0.5029, Val F1: 0.4219, Test F1: 0.4150
# *Epoch 263, model saved with Loss: 1.7043, Train F1: 0.5050, Val F1: 0.4227, Test F1: 0.4184
# *Epoch 265, model saved with Loss: 1.7020, Train F1: 0.5072, Val F1: 0.4246, Test F1: 0.4178
# *Epoch 278, model saved with Loss: 1.6860, Train F1: 0.5120, Val F1: 0.4253, Test F1: 0.4215
# *Epoch 280, model saved with Loss: 1.6850, Train F1: 0.5144, Val F1: 0.4258, Test F1: 0.4222
# *Epoch 282, model saved with Loss: 1.6941, Train F1: 0.5174, Val F1: 0.4274, Test F1: 0.4214
# *Epoch 297, model saved with Loss: 1.6643, Train F1: 0.5249, Val F1: 0.4276, Test F1: 0.4240
# Epoch 300, Loss: 1.6628, Train F1: 0.5283, Val F1: 0.4274, Test F1: 0.4254
# *Epoch 306, model saved with Loss: 1.6522, Train F1: 0.5302, Val F1: 0.4276, Test F1: 0.4238
# *Epoch 309, model saved with Loss: 1.6515, Train F1: 0.5341, Val F1: 0.4282, Test F1: 0.4258
# *Epoch 312, model saved with Loss: 1.6501, Train F1: 0.5336, Val F1: 0.4299, Test F1: 0.4240
# *Epoch 315, model saved with Loss: 1.6558, Train F1: 0.5382, Val F1: 0.4299, Test F1: 0.4261
# *Epoch 318, model saved with Loss: 1.6599, Train F1: 0.5390, Val F1: 0.4320, Test F1: 0.4266
# *Epoch 319, model saved with Loss: 1.6433, Train F1: 0.5389, Val F1: 0.4320, Test F1: 0.4254
# *Epoch 321, model saved with Loss: 1.6489, Train F1: 0.5395, Val F1: 0.4328, Test F1: 0.4258
# *Epoch 358, model saved with Loss: 1.5981, Train F1: 0.5612, Val F1: 0.4338, Test F1: 0.4290
# *Epoch 361, model saved with Loss: 1.6027, Train F1: 0.5655, Val F1: 0.4341, Test F1: 0.4312
# *Epoch 363, model saved with Loss: 1.5964, Train F1: 0.5633, Val F1: 0.4343, Test F1: 0.4292
# *Epoch 364, model saved with Loss: 1.5928, Train F1: 0.5658, Val F1: 0.4348, Test F1: 0.4318
# *Epoch 370, model saved with Loss: 1.5890, Train F1: 0.5688, Val F1: 0.4351, Test F1: 0.4287
# *Epoch 375, model saved with Loss: 1.5838, Train F1: 0.5697, Val F1: 0.4351, Test F1: 0.4300
# *Epoch 377, model saved with Loss: 1.5853, Train F1: 0.5703, Val F1: 0.4356, Test F1: 0.4323
# *Epoch 378, model saved with Loss: 1.5747, Train F1: 0.5719, Val F1: 0.4361, Test F1: 0.4320
# *Epoch 397, model saved with Loss: 1.5629, Train F1: 0.5826, Val F1: 0.4361, Test F1: 0.4321
# *Epoch 398, model saved with Loss: 1.5615, Train F1: 0.5837, Val F1: 0.4369, Test F1: 0.4325
# Epoch 400, Loss: 1.5639, Train F1: 0.5842, Val F1: 0.4367, Test F1: 0.4325
# *Epoch 406, model saved with Loss: 1.5536, Train F1: 0.5871, Val F1: 0.4370, Test F1: 0.4331
# *Epoch 407, model saved with Loss: 1.5568, Train F1: 0.5879, Val F1: 0.4372, Test F1: 0.4346
# *Epoch 418, model saved with Loss: 1.5370, Train F1: 0.5912, Val F1: 0.4374, Test F1: 0.4349
# *Epoch 419, model saved with Loss: 1.5507, Train F1: 0.5961, Val F1: 0.4382, Test F1: 0.4359
# *Epoch 422, model saved with Loss: 1.5466, Train F1: 0.5977, Val F1: 0.4382, Test F1: 0.4361
# *Epoch 425, model saved with Loss: 1.5485, Train F1: 0.5981, Val F1: 0.4401, Test F1: 0.4361
# *Epoch 426, model saved with Loss: 1.5320, Train F1: 0.5995, Val F1: 0.4415, Test F1: 0.4370
# *Epoch 428, model saved with Loss: 1.5433, Train F1: 0.5990, Val F1: 0.4418, Test F1: 0.4385
# *Epoch 429, model saved with Loss: 1.5293, Train F1: 0.6008, Val F1: 0.4432, Test F1: 0.4369
# *Epoch 445, model saved with Loss: 1.5140, Train F1: 0.6092, Val F1: 0.4436, Test F1: 0.4392
# *Epoch 454, model saved with Loss: 1.5054, Train F1: 0.6123, Val F1: 0.4437, Test F1: 0.4419
# *Epoch 456, model saved with Loss: 1.4960, Train F1: 0.6103, Val F1: 0.4444, Test F1: 0.4431
# *Epoch 457, model saved with Loss: 1.5014, Train F1: 0.6130, Val F1: 0.4444, Test F1: 0.4439
# *Epoch 462, model saved with Loss: 1.4960, Train F1: 0.6126, Val F1: 0.4449, Test F1: 0.4447
# *Epoch 463, model saved with Loss: 1.4995, Train F1: 0.6161, Val F1: 0.4467, Test F1: 0.4434
# *Epoch 464, model saved with Loss: 1.4922, Train F1: 0.6157, Val F1: 0.4470, Test F1: 0.4426
# *Epoch 467, model saved with Loss: 1.4865, Train F1: 0.6162, Val F1: 0.4473, Test F1: 0.4439
# *Epoch 468, model saved with Loss: 1.4830, Train F1: 0.6161, Val F1: 0.4477, Test F1: 0.4457
# *Epoch 488, model saved with Loss: 1.4680, Train F1: 0.6291, Val F1: 0.4478, Test F1: 0.4457
# *Epoch 494, model saved with Loss: 1.4657, Train F1: 0.6317, Val F1: 0.4480, Test F1: 0.4450
# Best Test F1 throughout: 0.4477
# Loading best model for final evaluation...: 0.4480
# Best Test F1 after loading saved model: 0.4450
# Run: 3
# *Epoch 0, model saved with Loss: 2.3005, Train F1: 0.2833, Val F1: 0.2714, Test F1: 0.2674
# Epoch 0, Loss: 2.3005, Train F1: 0.2833, Val F1: 0.2714, Test F1: 0.2674
# *Epoch 1, model saved with Loss: 2.2771, Train F1: 0.3151, Val F1: 0.3105, Test F1: 0.3069
# *Epoch 2, model saved with Loss: 2.2579, Train F1: 0.3477, Val F1: 0.3340, Test F1: 0.3381
# *Epoch 3, model saved with Loss: 2.2408, Train F1: 0.3640, Val F1: 0.3531, Test F1: 0.3570
# *Epoch 4, model saved with Loss: 2.2229, Train F1: 0.3659, Val F1: 0.3557, Test F1: 0.3644
# *Epoch 5, model saved with Loss: 2.2077, Train F1: 0.3662, Val F1: 0.3614, Test F1: 0.3632
# *Epoch 6, model saved with Loss: 2.1901, Train F1: 0.3667, Val F1: 0.3652, Test F1: 0.3649
# *Epoch 7, model saved with Loss: 2.1751, Train F1: 0.3679, Val F1: 0.3668, Test F1: 0.3662
# *Epoch 8, model saved with Loss: 2.1622, Train F1: 0.3684, Val F1: 0.3670, Test F1: 0.3652
# *Epoch 9, model saved with Loss: 2.1519, Train F1: 0.3682, Val F1: 0.3675, Test F1: 0.3662
# *Epoch 11, model saved with Loss: 2.1283, Train F1: 0.3679, Val F1: 0.3681, Test F1: 0.3673
# *Epoch 12, model saved with Loss: 2.1184, Train F1: 0.3680, Val F1: 0.3681, Test F1: 0.3675
# *Epoch 13, model saved with Loss: 2.1086, Train F1: 0.3686, Val F1: 0.3681, Test F1: 0.3678
# *Epoch 14, model saved with Loss: 2.1042, Train F1: 0.3684, Val F1: 0.3681, Test F1: 0.3676
# *Epoch 25, model saved with Loss: 2.0692, Train F1: 0.3733, Val F1: 0.3683, Test F1: 0.3689
# *Epoch 26, model saved with Loss: 2.0691, Train F1: 0.3749, Val F1: 0.3691, Test F1: 0.3683
# *Epoch 27, model saved with Loss: 2.0656, Train F1: 0.3743, Val F1: 0.3706, Test F1: 0.3689
# *Epoch 28, model saved with Loss: 2.0651, Train F1: 0.3745, Val F1: 0.3712, Test F1: 0.3678
# *Epoch 29, model saved with Loss: 2.0617, Train F1: 0.3767, Val F1: 0.3714, Test F1: 0.3704
# *Epoch 30, model saved with Loss: 2.0606, Train F1: 0.3768, Val F1: 0.3714, Test F1: 0.3701
# *Epoch 36, model saved with Loss: 2.0493, Train F1: 0.3810, Val F1: 0.3729, Test F1: 0.3725
# *Epoch 37, model saved with Loss: 2.0457, Train F1: 0.3810, Val F1: 0.3733, Test F1: 0.3729
# *Epoch 39, model saved with Loss: 2.0432, Train F1: 0.3829, Val F1: 0.3751, Test F1: 0.3730
# *Epoch 40, model saved with Loss: 2.0416, Train F1: 0.3836, Val F1: 0.3771, Test F1: 0.3730
# *Epoch 41, model saved with Loss: 2.0395, Train F1: 0.3849, Val F1: 0.3781, Test F1: 0.3745
# *Epoch 42, model saved with Loss: 2.0388, Train F1: 0.3857, Val F1: 0.3794, Test F1: 0.3763
# *Epoch 43, model saved with Loss: 2.0370, Train F1: 0.3860, Val F1: 0.3794, Test F1: 0.3761
# *Epoch 44, model saved with Loss: 2.0357, Train F1: 0.3866, Val F1: 0.3815, Test F1: 0.3771
# *Epoch 45, model saved with Loss: 2.0326, Train F1: 0.3866, Val F1: 0.3815, Test F1: 0.3791
# *Epoch 46, model saved with Loss: 2.0290, Train F1: 0.3884, Val F1: 0.3827, Test F1: 0.3791
# *Epoch 47, model saved with Loss: 2.0299, Train F1: 0.3891, Val F1: 0.3827, Test F1: 0.3797
# *Epoch 48, model saved with Loss: 2.0266, Train F1: 0.3893, Val F1: 0.3828, Test F1: 0.3784
# *Epoch 51, model saved with Loss: 2.0202, Train F1: 0.3913, Val F1: 0.3833, Test F1: 0.3789
# *Epoch 52, model saved with Loss: 2.0204, Train F1: 0.3920, Val F1: 0.3849, Test F1: 0.3789
# *Epoch 57, model saved with Loss: 2.0093, Train F1: 0.3957, Val F1: 0.3849, Test F1: 0.3823
# *Epoch 58, model saved with Loss: 2.0038, Train F1: 0.3962, Val F1: 0.3853, Test F1: 0.3828
# *Epoch 59, model saved with Loss: 2.0035, Train F1: 0.3969, Val F1: 0.3861, Test F1: 0.3828
# *Epoch 61, model saved with Loss: 1.9983, Train F1: 0.3972, Val F1: 0.3862, Test F1: 0.3823
# *Epoch 62, model saved with Loss: 1.9944, Train F1: 0.3997, Val F1: 0.3869, Test F1: 0.3833
# *Epoch 63, model saved with Loss: 1.9908, Train F1: 0.4003, Val F1: 0.3871, Test F1: 0.3843
# *Epoch 65, model saved with Loss: 1.9886, Train F1: 0.4016, Val F1: 0.3885, Test F1: 0.3849
# *Epoch 66, model saved with Loss: 1.9890, Train F1: 0.4032, Val F1: 0.3887, Test F1: 0.3856
# *Epoch 67, model saved with Loss: 1.9831, Train F1: 0.4042, Val F1: 0.3892, Test F1: 0.3872
# *Epoch 70, model saved with Loss: 1.9766, Train F1: 0.4067, Val F1: 0.3898, Test F1: 0.3894
# *Epoch 71, model saved with Loss: 1.9746, Train F1: 0.4073, Val F1: 0.3907, Test F1: 0.3903
# *Epoch 72, model saved with Loss: 1.9699, Train F1: 0.4076, Val F1: 0.3916, Test F1: 0.3908
# *Epoch 75, model saved with Loss: 1.9633, Train F1: 0.4076, Val F1: 0.3925, Test F1: 0.3902
# *Epoch 77, model saved with Loss: 1.9597, Train F1: 0.4085, Val F1: 0.3926, Test F1: 0.3898
# *Epoch 78, model saved with Loss: 1.9672, Train F1: 0.4085, Val F1: 0.3931, Test F1: 0.3898
# *Epoch 83, model saved with Loss: 1.9559, Train F1: 0.4108, Val F1: 0.3938, Test F1: 0.3915
# *Epoch 84, model saved with Loss: 1.9495, Train F1: 0.4113, Val F1: 0.3949, Test F1: 0.3918
# *Epoch 85, model saved with Loss: 1.9488, Train F1: 0.4115, Val F1: 0.3954, Test F1: 0.3921
# *Epoch 89, model saved with Loss: 1.9393, Train F1: 0.4143, Val F1: 0.3957, Test F1: 0.3920
# *Epoch 100, model saved with Loss: 1.9196, Train F1: 0.4209, Val F1: 0.3957, Test F1: 0.3907
# Epoch 100, Loss: 1.9196, Train F1: 0.4209, Val F1: 0.3957, Test F1: 0.3907
# *Epoch 101, model saved with Loss: 1.9136, Train F1: 0.4209, Val F1: 0.3964, Test F1: 0.3907
# *Epoch 109, model saved with Loss: 1.9026, Train F1: 0.4245, Val F1: 0.3974, Test F1: 0.3897
# *Epoch 111, model saved with Loss: 1.8981, Train F1: 0.4245, Val F1: 0.3977, Test F1: 0.3895
# *Epoch 112, model saved with Loss: 1.8930, Train F1: 0.4247, Val F1: 0.3987, Test F1: 0.3895
# *Epoch 113, model saved with Loss: 1.8958, Train F1: 0.4246, Val F1: 0.3988, Test F1: 0.3880
# *Epoch 114, model saved with Loss: 1.8932, Train F1: 0.4247, Val F1: 0.3996, Test F1: 0.3879
# *Epoch 116, model saved with Loss: 1.8904, Train F1: 0.4269, Val F1: 0.4000, Test F1: 0.3880
# *Epoch 118, model saved with Loss: 1.8875, Train F1: 0.4281, Val F1: 0.4005, Test F1: 0.3882
# *Epoch 119, model saved with Loss: 1.8846, Train F1: 0.4274, Val F1: 0.4006, Test F1: 0.3877
# *Epoch 120, model saved with Loss: 1.8833, Train F1: 0.4280, Val F1: 0.4018, Test F1: 0.3890
# *Epoch 131, model saved with Loss: 1.8692, Train F1: 0.4335, Val F1: 0.4018, Test F1: 0.3923
# *Epoch 132, model saved with Loss: 1.8672, Train F1: 0.4357, Val F1: 0.4026, Test F1: 0.3915
# *Epoch 136, model saved with Loss: 1.8603, Train F1: 0.4358, Val F1: 0.4032, Test F1: 0.3913
# *Epoch 137, model saved with Loss: 1.8644, Train F1: 0.4361, Val F1: 0.4032, Test F1: 0.3929
# *Epoch 139, model saved with Loss: 1.8554, Train F1: 0.4374, Val F1: 0.4045, Test F1: 0.3943
# *Epoch 143, model saved with Loss: 1.8430, Train F1: 0.4388, Val F1: 0.4049, Test F1: 0.3939
# ...
# *Epoch 380, model saved with Loss: 1.5674, Train F1: 0.5770, Val F1: 0.4354, Test F1: 0.4300
# *Epoch 392, model saved with Loss: 1.5542, Train F1: 0.5839, Val F1: 0.4361, Test F1: 0.4308
# *Epoch 393, model saved with Loss: 1.5557, Train F1: 0.5860, Val F1: 0.4374, Test F1: 0.4303
# *Epoch 397, model saved with Loss: 1.5541, Train F1: 0.5857, Val F1: 0.4387, Test F1: 0.4294
# Epoch 400, Loss: 1.5455, Train F1: 0.5871, Val F1: 0.4359, Test F1: 0.4303
# *Epoch 403, model saved with Loss: 1.5425, Train F1: 0.5911, Val F1: 0.4395, Test F1: 0.4317
# *Epoch 404, model saved with Loss: 1.5500, Train F1: 0.5881, Val F1: 0.4395, Test F1: 0.4313
# *Epoch 405, model saved with Loss: 1.5489, Train F1: 0.5923, Val F1: 0.4397, Test F1: 0.4317
# *Epoch 408, model saved with Loss: 1.5374, Train F1: 0.5951, Val F1: 0.4400, Test F1: 0.4323
# *Epoch 416, model saved with Loss: 1.5313, Train F1: 0.5957, Val F1: 0.4415, Test F1: 0.4318
# *Epoch 424, model saved with Loss: 1.5189, Train F1: 0.6001, Val F1: 0.4415, Test F1: 0.4331
# *Epoch 426, model saved with Loss: 1.5209, Train F1: 0.6022, Val F1: 0.4419, Test F1: 0.4341
# *Epoch 431, model saved with Loss: 1.5196, Train F1: 0.6045, Val F1: 0.4419, Test F1: 0.4310
# *Epoch 432, model saved with Loss: 1.5196, Train F1: 0.6034, Val F1: 0.4431, Test F1: 0.4318
# *Epoch 442, model saved with Loss: 1.5071, Train F1: 0.6098, Val F1: 0.4436, Test F1: 0.4348
# *Epoch 443, model saved with Loss: 1.5118, Train F1: 0.6076, Val F1: 0.4436, Test F1: 0.4341
# *Epoch 444, model saved with Loss: 1.5093, Train F1: 0.6112, Val F1: 0.4459, Test F1: 0.4325
# *Epoch 445, model saved with Loss: 1.5026, Train F1: 0.6120, Val F1: 0.4483, Test F1: 0.4341
# *Epoch 485, model saved with Loss: 1.4711, Train F1: 0.6324, Val F1: 0.4488, Test F1: 0.4357
# *Epoch 490, model saved with Loss: 1.4551, Train F1: 0.6329, Val F1: 0.4496, Test F1: 0.4375
# Best Test F1 throughout: 0.4415
# Loading best model for final evaluation...: 0.4496
# Best Test F1 after loading saved model: 0.4375
# Run: 4
# *Epoch 0, model saved with Loss: 2.2737, Train F1: 0.3536, Val F1: 0.3539, Test F1: 0.3456
# Epoch 0, Loss: 2.2737, Train F1: 0.3536, Val F1: 0.3539, Test F1: 0.3456
# *Epoch 1, model saved with Loss: 2.2531, Train F1: 0.3631, Val F1: 0.3640, Test F1: 0.3608
# *Epoch 2, model saved with Loss: 2.2340, Train F1: 0.3660, Val F1: 0.3670, Test F1: 0.3680
# *Epoch 3, model saved with Loss: 2.2159, Train F1: 0.3671, Val F1: 0.3688, Test F1: 0.3671
# *Epoch 4, model saved with Loss: 2.1999, Train F1: 0.3671, Val F1: 0.3693, Test F1: 0.3667
# *Epoch 5, model saved with Loss: 2.1806, Train F1: 0.3670, Val F1: 0.3694, Test F1: 0.3676
# *Epoch 22, model saved with Loss: 2.0712, Train F1: 0.3724, Val F1: 0.3715, Test F1: 0.3730
# *Epoch 23, model saved with Loss: 2.0695, Train F1: 0.3741, Val F1: 0.3722, Test F1: 0.3730
# *Epoch 24, model saved with Loss: 2.0661, Train F1: 0.3756, Val F1: 0.3737, Test F1: 0.3742
# *Epoch 25, model saved with Loss: 2.0654, Train F1: 0.3774, Val F1: 0.3740, Test F1: 0.3742
# *Epoch 26, model saved with Loss: 2.0659, Train F1: 0.3778, Val F1: 0.3742, Test F1: 0.3740
# *Epoch 27, model saved with Loss: 2.0606, Train F1: 0.3787, Val F1: 0.3753, Test F1: 0.3737
# *Epoch 31, model saved with Loss: 2.0538, Train F1: 0.3813, Val F1: 0.3755, Test F1: 0.3732
# *Epoch 32, model saved with Loss: 2.0514, Train F1: 0.3813, Val F1: 0.3766, Test F1: 0.3737
# *Epoch 33, model saved with Loss: 2.0485, Train F1: 0.3813, Val F1: 0.3776, Test F1: 0.3742
# *Epoch 34, model saved with Loss: 2.0483, Train F1: 0.3813, Val F1: 0.3776, Test F1: 0.3745
# *Epoch 35, model saved with Loss: 2.0457, Train F1: 0.3818, Val F1: 0.3778, Test F1: 0.3747
# *Epoch 37, model saved with Loss: 2.0408, Train F1: 0.3831, Val F1: 0.3778, Test F1: 0.3755
# *Epoch 38, model saved with Loss: 2.0394, Train F1: 0.3840, Val F1: 0.3782, Test F1: 0.3753
# *Epoch 39, model saved with Loss: 2.0375, Train F1: 0.3841, Val F1: 0.3794, Test F1: 0.3760
# *Epoch 40, model saved with Loss: 2.0360, Train F1: 0.3842, Val F1: 0.3797, Test F1: 0.3771
# *Epoch 41, model saved with Loss: 2.0329, Train F1: 0.3851, Val F1: 0.3818, Test F1: 0.3776
# *Epoch 42, model saved with Loss: 2.0315, Train F1: 0.3864, Val F1: 0.3830, Test F1: 0.3807
# *Epoch 43, model saved with Loss: 2.0287, Train F1: 0.3867, Val F1: 0.3843, Test F1: 0.3807
# *Epoch 44, model saved with Loss: 2.0260, Train F1: 0.3877, Val F1: 0.3853, Test F1: 0.3805
# *Epoch 45, model saved with Loss: 2.0238, Train F1: 0.3894, Val F1: 0.3869, Test F1: 0.3797
# *Epoch 48, model saved with Loss: 2.0184, Train F1: 0.3907, Val F1: 0.3874, Test F1: 0.3817
# *Epoch 49, model saved with Loss: 2.0143, Train F1: 0.3921, Val F1: 0.3877, Test F1: 0.3825
# *Epoch 50, model saved with Loss: 2.0129, Train F1: 0.3938, Val F1: 0.3882, Test F1: 0.3831
# *Epoch 51, model saved with Loss: 2.0116, Train F1: 0.3951, Val F1: 0.3894, Test F1: 0.3836
# *Epoch 52, model saved with Loss: 2.0069, Train F1: 0.3958, Val F1: 0.3894, Test F1: 0.3848
# *Epoch 54, model saved with Loss: 2.0030, Train F1: 0.3974, Val F1: 0.3898, Test F1: 0.3843
# *Epoch 55, model saved with Loss: 1.9997, Train F1: 0.3982, Val F1: 0.3907, Test F1: 0.3849
# *Epoch 58, model saved with Loss: 1.9939, Train F1: 0.4005, Val F1: 0.3910, Test F1: 0.3859
# *Epoch 62, model saved with Loss: 1.9838, Train F1: 0.4026, Val F1: 0.3911, Test F1: 0.3862
# *Epoch 63, model saved with Loss: 1.9825, Train F1: 0.4039, Val F1: 0.3913, Test F1: 0.3867
# *Epoch 64, model saved with Loss: 1.9807, Train F1: 0.4044, Val F1: 0.3920, Test F1: 0.3880
# *Epoch 73, model saved with Loss: 1.9577, Train F1: 0.4096, Val F1: 0.3921, Test F1: 0.3911
# *Epoch 74, model saved with Loss: 1.9573, Train F1: 0.4100, Val F1: 0.3929, Test F1: 0.3900
# *Epoch 76, model saved with Loss: 1.9509, Train F1: 0.4111, Val F1: 0.3939, Test F1: 0.3897
# *Epoch 78, model saved with Loss: 1.9472, Train F1: 0.4126, Val F1: 0.3946, Test F1: 0.3900
# *Epoch 79, model saved with Loss: 1.9458, Train F1: 0.4130, Val F1: 0.3954, Test F1: 0.3905
# *Epoch 81, model saved with Loss: 1.9382, Train F1: 0.4136, Val F1: 0.3960, Test F1: 0.3903
# *Epoch 82, model saved with Loss: 1.9391, Train F1: 0.4142, Val F1: 0.3965, Test F1: 0.3910
# *Epoch 83, model saved with Loss: 1.9341, Train F1: 0.4144, Val F1: 0.3970, Test F1: 0.3915
# *Epoch 97, model saved with Loss: 1.9119, Train F1: 0.4201, Val F1: 0.3974, Test F1: 0.3879
# Epoch 100, Loss: 1.9016, Train F1: 0.4216, Val F1: 0.3947, Test F1: 0.3890
# *Epoch 101, model saved with Loss: 1.9020, Train F1: 0.4228, Val F1: 0.3975, Test F1: 0.3887
# *Epoch 105, model saved with Loss: 1.8916, Train F1: 0.4249, Val F1: 0.3975, Test F1: 0.3895
# *Epoch 107, model saved with Loss: 1.8925, Train F1: 0.4254, Val F1: 0.3980, Test F1: 0.3887
# *Epoch 108, model saved with Loss: 1.8868, Train F1: 0.4260, Val F1: 0.3992, Test F1: 0.3890
# *Epoch 110, model saved with Loss: 1.8834, Train F1: 0.4259, Val F1: 0.3995, Test F1: 0.3892
# *Epoch 117, model saved with Loss: 1.8711, Train F1: 0.4282, Val F1: 0.4001, Test F1: 0.3910
# *Epoch 118, model saved with Loss: 1.8747, Train F1: 0.4293, Val F1: 0.4003, Test F1: 0.3923
# *Epoch 119, model saved with Loss: 1.8728, Train F1: 0.4294, Val F1: 0.4006, Test F1: 0.3926
# *Epoch 121, model saved with Loss: 1.8678, Train F1: 0.4295, Val F1: 0.4031, Test F1: 0.3920
# *Epoch 122, model saved with Loss: 1.8645, Train F1: 0.4291, Val F1: 0.4036, Test F1: 0.3910
# *Epoch 123, model saved with Loss: 1.8680, Train F1: 0.4303, Val F1: 0.4037, Test F1: 0.3920
# *Epoch 134, model saved with Loss: 1.8483, Train F1: 0.4352, Val F1: 0.4039, Test F1: 0.3933
# *Epoch 135, model saved with Loss: 1.8441, Train F1: 0.4370, Val F1: 0.4057, Test F1: 0.3931
# *Epoch 136, model saved with Loss: 1.8481, Train F1: 0.4392, Val F1: 0.4063, Test F1: 0.3936
# *Epoch 137, model saved with Loss: 1.8445, Train F1: 0.4392, Val F1: 0.4063, Test F1: 0.3926
# *Epoch 141, model saved with Loss: 1.8407, Train F1: 0.4407, Val F1: 0.4067, Test F1: 0.3936
# *Epoch 148, model saved with Loss: 1.8296, Train F1: 0.4450, Val F1: 0.4075, Test F1: 0.3952
# *Epoch 158, model saved with Loss: 1.8166, Train F1: 0.4490, Val F1: 0.4078, Test F1: 0.3960
# *Epoch 159, model saved with Loss: 1.8133, Train F1: 0.4490, Val F1: 0.4083, Test F1: 0.3962
# *Epoch 161, model saved with Loss: 1.8130, Train F1: 0.4495, Val F1: 0.4091, Test F1: 0.3970
# *Epoch 162, model saved with Loss: 1.8107, Train F1: 0.4502, Val F1: 0.4094, Test F1: 0.3987
# *Epoch 177, model saved with Loss: 1.7902, Train F1: 0.4575, Val F1: 0.4094, Test F1: 0.4019
# *Epoch 179, model saved with Loss: 1.7998, Train F1: 0.4587, Val F1: 0.4096, Test F1: 0.4018
# *Epoch 180, model saved with Loss: 1.7889, Train F1: 0.4591, Val F1: 0.4099, Test F1: 0.4026
# *Epoch 181, model saved with Loss: 1.7834, Train F1: 0.4597, Val F1: 0.4101, Test F1: 0.4058
# *Epoch 184, model saved with Loss: 1.7863, Train F1: 0.4624, Val F1: 0.4112, Test F1: 0.4027
# *Epoch 190, model saved with Loss: 1.7781, Train F1: 0.4665, Val F1: 0.4117, Test F1: 0.4026
# *Epoch 193, model saved with Loss: 1.7725, Train F1: 0.4700, Val F1: 0.4135, Test F1: 0.4057
# *Epoch 199, model saved with Loss: 1.7809, Train F1: 0.4728, Val F1: 0.4147, Test F1: 0.4065
# Epoch 200, Loss: 1.7687, Train F1: 0.4742, Val F1: 0.4138, Test F1: 0.4062
# *Epoch 207, model saved with Loss: 1.7500, Train F1: 0.4780, Val F1: 0.4148, Test F1: 0.4065
# *Epoch 208, model saved with Loss: 1.7592, Train F1: 0.4769, Val F1: 0.4148, Test F1: 0.4055
# *Epoch 214, model saved with Loss: 1.7405, Train F1: 0.4804, Val F1: 0.4148, Test F1: 0.4067
# *Epoch 216, model saved with Loss: 1.7403, Train F1: 0.4820, Val F1: 0.4153, Test F1: 0.4086
# *Epoch 217, model saved with Loss: 1.7424, Train F1: 0.4833, Val F1: 0.4155, Test F1: 0.4088
# *Epoch 218, model saved with Loss: 1.7433, Train F1: 0.4840, Val F1: 0.4156, Test F1: 0.4081
# *Epoch 220, model saved with Loss: 1.7431, Train F1: 0.4865, Val F1: 0.4160, Test F1: 0.4099
# *Epoch 224, model saved with Loss: 1.7321, Train F1: 0.4878, Val F1: 0.4170, Test F1: 0.4099
# *Epoch 232, model saved with Loss: 1.7216, Train F1: 0.4935, Val F1: 0.4179, Test F1: 0.4121
# *Epoch 236, model saved with Loss: 1.7172, Train F1: 0.4954, Val F1: 0.4181, Test F1: 0.4137
# *Epoch 237, model saved with Loss: 1.7111, Train F1: 0.4961, Val F1: 0.4187, Test F1: 0.4135
# *Epoch 239, model saved with Loss: 1.7092, Train F1: 0.4979, Val F1: 0.4189, Test F1: 0.4135
# *Epoch 243, model saved with Loss: 1.7149, Train F1: 0.5006, Val F1: 0.4191, Test F1: 0.4143
# *Epoch 244, model saved with Loss: 1.7098, Train F1: 0.5016, Val F1: 0.4192, Test F1: 0.4147
# *Epoch 249, model saved with Loss: 1.7015, Train F1: 0.5056, Val F1: 0.4194, Test F1: 0.4171
# *Epoch 250, model saved with Loss: 1.7002, Train F1: 0.5056, Val F1: 0.4202, Test F1: 0.4184
# *Epoch 251, model saved with Loss: 1.6994, Train F1: 0.5054, Val F1: 0.4204, Test F1: 0.4170
# *Epoch 253, model saved with Loss: 1.6958, Train F1: 0.5081, Val F1: 0.4212, Test F1: 0.4183
# *Epoch 254, model saved with Loss: 1.6951, Train F1: 0.5091, Val F1: 0.4223, Test F1: 0.4176
# *Epoch 255, model saved with Loss: 1.6927, Train F1: 0.5106, Val F1: 0.4227, Test F1: 0.4186
# *Epoch 270, model saved with Loss: 1.6805, Train F1: 0.5200, Val F1: 0.4230, Test F1: 0.4183
# *Epoch 271, model saved with Loss: 1.6763, Train F1: 0.5199, Val F1: 0.4233, Test F1: 0.4186
# *Epoch 272, model saved with Loss: 1.6782, Train F1: 0.5197, Val F1: 0.4241, Test F1: 0.4192
# *Epoch 286, model saved with Loss: 1.6618, Train F1: 0.5289, Val F1: 0.4248, Test F1: 0.4243
# *Epoch 287, model saved with Loss: 1.6541, Train F1: 0.5282, Val F1: 0.4248, Test F1: 0.4225
# *Epoch 288, model saved with Loss: 1.6545, Train F1: 0.5288, Val F1: 0.4258, Test F1: 0.4220
# *Epoch 298, model saved with Loss: 1.6548, Train F1: 0.5336, Val F1: 0.4271, Test F1: 0.4271
# Epoch 300, Loss: 1.6587, Train F1: 0.5349, Val F1: 0.4269, Test F1: 0.4259
# *Epoch 306, model saved with Loss: 1.6365, Train F1: 0.5379, Val F1: 0.4274, Test F1: 0.4241
# *Epoch 313, model saved with Loss: 1.6296, Train F1: 0.5416, Val F1: 0.4274, Test F1: 0.4243
# *Epoch 314, model saved with Loss: 1.6313, Train F1: 0.5429, Val F1: 0.4274, Test F1: 0.4250
# *Epoch 315, model saved with Loss: 1.6277, Train F1: 0.5428, Val F1: 0.4277, Test F1: 0.4268
# *Epoch 316, model saved with Loss: 1.6308, Train F1: 0.5449, Val F1: 0.4279, Test F1: 0.4276
# *Epoch 317, model saved with Loss: 1.6269, Train F1: 0.5444, Val F1: 0.4281, Test F1: 0.4276
# *Epoch 318, model saved with Loss: 1.6184, Train F1: 0.5439, Val F1: 0.4282, Test F1: 0.4259
# *Epoch 319, model saved with Loss: 1.6286, Train F1: 0.5463, Val F1: 0.4284, Test F1: 0.4281
# *Epoch 320, model saved with Loss: 1.6256, Train F1: 0.5461, Val F1: 0.4284, Test F1: 0.4284
# *Epoch 321, model saved with Loss: 1.6198, Train F1: 0.5489, Val F1: 0.4287, Test F1: 0.4300
# *Epoch 326, model saved with Loss: 1.6224, Train F1: 0.5502, Val F1: 0.4287, Test F1: 0.4302
# *Epoch 329, model saved with Loss: 1.6152, Train F1: 0.5532, Val F1: 0.4290, Test F1: 0.4307
# *Epoch 331, model saved with Loss: 1.6107, Train F1: 0.5554, Val F1: 0.4303, Test F1: 0.4295
# *Epoch 337, model saved with Loss: 1.6006, Train F1: 0.5565, Val F1: 0.4308, Test F1: 0.4297
# *Epoch 339, model saved with Loss: 1.6083, Train F1: 0.5597, Val F1: 0.4321, Test F1: 0.4313
# *Epoch 341, model saved with Loss: 1.6075, Train F1: 0.5595, Val F1: 0.4325, Test F1: 0.4317
# *Epoch 349, model saved with Loss: 1.5969, Train F1: 0.5639, Val F1: 0.4331, Test F1: 0.4348
# *Epoch 351, model saved with Loss: 1.5907, Train F1: 0.5639, Val F1: 0.4333, Test F1: 0.4331
# *Epoch 353, model saved with Loss: 1.5925, Train F1: 0.5645, Val F1: 0.4341, Test F1: 0.4333
# *Epoch 354, model saved with Loss: 1.5924, Train F1: 0.5670, Val F1: 0.4344, Test F1: 0.4336
# *Epoch 355, model saved with Loss: 1.5936, Train F1: 0.5670, Val F1: 0.4348, Test F1: 0.4331
# *Epoch 357, model saved with Loss: 1.5922, Train F1: 0.5666, Val F1: 0.4352, Test F1: 0.4333
# *Epoch 360, model saved with Loss: 1.5814, Train F1: 0.5719, Val F1: 0.4357, Test F1: 0.4346
# *Epoch 363, model saved with Loss: 1.5854, Train F1: 0.5728, Val F1: 0.4362, Test F1: 0.4354
# *Epoch 372, model saved with Loss: 1.5696, Train F1: 0.5732, Val F1: 0.4364, Test F1: 0.4343
# *Epoch 375, model saved with Loss: 1.5707, Train F1: 0.5763, Val F1: 0.4374, Test F1: 0.4369
# *Epoch 391, model saved with Loss: 1.5503, Train F1: 0.5865, Val F1: 0.4374, Test F1: 0.4415
# *Epoch 392, model saved with Loss: 1.5526, Train F1: 0.5859, Val F1: 0.4382, Test F1: 0.4397
# *Epoch 394, model saved with Loss: 1.5455, Train F1: 0.5897, Val F1: 0.4385, Test F1: 0.4395
# *Epoch 397, model saved with Loss: 1.5481, Train F1: 0.5926, Val F1: 0.4392, Test F1: 0.4415
# *Epoch 400, model saved with Loss: 1.5375, Train F1: 0.5899, Val F1: 0.4397, Test F1: 0.4431
# Epoch 400, Loss: 1.5375, Train F1: 0.5899, Val F1: 0.4397, Test F1: 0.4431
# *Epoch 418, model saved with Loss: 1.5196, Train F1: 0.5995, Val F1: 0.4397, Test F1: 0.4480
# *Epoch 423, model saved with Loss: 1.5191, Train F1: 0.6022, Val F1: 0.4415, Test F1: 0.4475
# *Epoch 441, model saved with Loss: 1.5000, Train F1: 0.6135, Val F1: 0.4423, Test F1: 0.4436
# *Epoch 443, model saved with Loss: 1.5012, Train F1: 0.6143, Val F1: 0.4432, Test F1: 0.4452
# *Epoch 450, model saved with Loss: 1.4932, Train F1: 0.6177, Val F1: 0.4436, Test F1: 0.4468
# *Epoch 461, model saved with Loss: 1.4899, Train F1: 0.6221, Val F1: 0.4436, Test F1: 0.4444
# *Epoch 462, model saved with Loss: 1.4930, Train F1: 0.6195, Val F1: 0.4436, Test F1: 0.4446
# *Epoch 488, model saved with Loss: 1.4690, Train F1: 0.6306, Val F1: 0.4441, Test F1: 0.4493
# *Epoch 489, model saved with Loss: 1.4628, Train F1: 0.6306, Val F1: 0.4454, Test F1: 0.4486
# *Epoch 491, model saved with Loss: 1.4583, Train F1: 0.6338, Val F1: 0.4457, Test F1: 0.4503
# *Epoch 497, model saved with Loss: 1.4523, Train F1: 0.6350, Val F1: 0.4463, Test F1: 0.4522
# *Epoch 499, model saved with Loss: 1.4479, Train F1: 0.6361, Val F1: 0.4465, Test F1: 0.4516
# Best Test F1 throughout: 0.4526
# Loading best model for final evaluation...: 0.4465
# Best Test F1 after loading saved model: 0.4516
# Mean Std of Test F1 Score: 0.4460 +/- 0.0050

# %%
# Plot the F1 scores of last run
plt.figure(figsize=(10, 6))
plt.plot(train_f1_scores, label='Train F1 Score')
plt.plot(val_f1_scores, label='Validation F1 Score')
plt.plot(test_f1_scores, label='Test F1 Score')
# plt.plot(loss_scores, label='Training Loss')
plt.xlabel('Epoch')
plt.ylabel('F1 Score')
plt.title('F1 Scores over Epochs')
plt.legend()
plt.show()

# %%
for batch in cluster_loader:
    print(batch.num_nodes)
    print(batch.edge_index.shape)
# Out:
# 24492
# torch.Size([2, 93050])

# %%
import networkx as nx
import matplotlib.pyplot as plt
import torch
import matplotlib.colors as mcolors
from torch_geometric.utils import to_networkx
from torch_geometric.data import Data

# %%
torch.where(data.train_mask == True)
# Out:
# (tensor([    0,     2,     3,  ..., 24489, 24490, 24491], device='cuda:0'),)

# %%
def count_edges_with_different_labels(data, sampled_edge_index):
    """
    Counts edges with different labels at endpoints in both the original and sampled graphs.
    
    Args:
        data: Data object containing the original graph information.
        sampled_edge_index: Edge index of the sampled subgraph.
    
    Returns:
        A dictionary with counts and percentages of edges with different labels.
    """
    # Original graph edges
    original_edges = data.edge_index
    num_original_edges = original_edges.size(1)
    
    # Count edges with different labels in the original graph
    different_label_edges_original = 0
    for i in range(num_original_edges):
        node1, node2 = original_edges[:, i]
        if data.y[node1].item() != data.y[node2].item():
            different_label_edges_original += 1
    
    # Sampled graph edges
    sampled_edges = sampled_edge_index
    num_sampled_edges = sampled_edges.size(1)

    # Count edges with different labels in the sampled graph
    different_label_edges_sampled = 0
    for i in range(num_sampled_edges):
        node1, node2 = sampled_edges[:, i]
        if data.y[node1].item() != data.y[node2].item():
            different_label_edges_sampled += 1

    # Calculate percentages
    percentage_original = (different_label_edges_original / num_original_edges) * 100 if num_original_edges > 0 else 0
    percentage_sampled = (different_label_edges_sampled / num_sampled_edges) * 100 if num_sampled_edges > 0 else 0

    # Prepare the result
    result = {
        "original_graph": {
            "different_label_edges": different_label_edges_original,
            "total_edges": num_original_edges,
            "percentage": percentage_original
        },
        "sampled_graph": {
            "different_label_edges": different_label_edges_sampled,
            "total_edges": num_sampled_edges,
            "percentage": percentage_sampled
        }
    }

    return result

# %%
def plot_full_graph_with_train_nodes(data, train_mask, ax=None):
    """
    Plots the full graph with training nodes highlighted and colored by their labels.
    Args:
        data: Data object containing edge_index, node labels, and other features.
        train_mask: Boolean tensor indicating training nodes.
        ax: Matplotlib axis on which to plot (for side-by-side plotting).
    """
    # Convert PyG data to NetworkX graph for visualization
    G = to_networkx(data)
    
    # Generate color map for each label
    unique_labels = torch.unique(data.y[train_mask]).tolist()
    color_map = {label: color for label, color in zip(unique_labels, mcolors.TABLEAU_COLORS)}

    # Set node colors based on whether they are a training node and their label
    node_colors = [
        color_map[data.y[i].item()] if train_mask[i].item() else 'gray' for i in range(data.num_nodes)
    ]
    
    pos = None
    
    if DATASET_NAME == 'moon':
        pos = {i: (data.x[i][0].item(), data.x[i][1].item()) for i in range(len(data.x))}
    elif pos is None:
        pos = nx.spring_layout(G, seed=42)

    # Plot the full graph with training nodes highlighted by label color
    nx.draw(G, pos, node_color=node_colors, ax=ax, with_labels=False, node_size=100, edge_color="lightblue")
    
    # Add label above each node showing the label value
    for node, p in pos.items():
        label = data.y[node].item()
        ax.text(p[0], p[1] + 0.05, str(label), fontsize=8, ha='center', va='center')
    
    ax.set_title("Full Graph with Training Nodes Highlighted by Label")
    ax.axis("off")
    
    return pos


def plot_sampled_subgraph(data, sampled_edge_index, train_mask, ax=None, pos=None):
    """
    Plots the sampled subgraph based on the edge probability model with training nodes highlighted by label.
    Args:
        data: Data object containing node information.
        sampled_edge_index: Edge index of the sampled subgraph.
        train_mask: Boolean tensor indicating training nodes.
        ax: Matplotlib axis on which to plot (for side-by-side plotting).
    """
    # Convert sampled edges to NetworkX graph
    G_sampled = to_networkx(Data(x = data.x, y = data.y, edge_index = sampled_edge_index))
    
    # Use same color map as the full graph
    unique_labels = torch.unique(data.y[train_mask]).tolist()
    color_map = {label: color for label, color in zip(unique_labels, mcolors.TABLEAU_COLORS)}

    # Use same layout as the full graph for consistent positioning
    if pos is None:
        pos = nx.spring_layout(G_sampled, seed=42)
    
    # Set node colors based on training status and label for nodes in the sampled graph
    node_colors = [
        color_map[data.y[i].item()] if train_mask[i].item() and i in G_sampled.nodes else 'gray'
        for i in G_sampled.nodes
    ]

    # Plot the sampled subgraph with node labels
    nx.draw(G_sampled, pos, node_color=node_colors, ax=ax, with_labels=False, node_size=100, edge_color="orange")
    
    # Add label above each node showing the label value
    for node, p in pos.items():
        label = data.y[node].item()
        ax.text(p[0], p[1] + 0.05, str(label), fontsize=8, ha='center', va='center')
    
    ax.set_title("Sampled Subgraph (Edge Probability Model) with Training Nodes Highlighted by Label")
    ax.axis("off")


def visualize_graphs_side_by_side(data, train_mask, sampled_edge_index, show=True):
    """
    Visualizes the full graph with training nodes and the sampled subgraph side by side, with training nodes colored by label.
    Args:
        data: Data object containing the full graph information.
        train_mask: Boolean tensor indicating training nodes.
        sampled_edge_index: Edge index of the sampled subgraph.
    """
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 7))
    
    # Plot full graph with training nodes highlighted by label
    pos1 = plot_full_graph_with_train_nodes(data, train_mask, ax=ax1)

    # Plot sampled subgraph with training nodes highlighted by label, using the same layout
    plot_sampled_subgraph(data, sampled_edge_index, train_mask, ax=ax2, pos=pos1)
    
    if show==False:
        plt.close()
    else:
        plt.show()
    
    return fig

# Example Usage:
# Assuming `train_mask` is a boolean mask tensor, and `sampled_edge_index` is the edge index after sampling
# visualize_graphs_side_by_side(data, train_mask=data.train_mask, sampled_edge_index=sampled_edge_index)

# %%
def visualize(istest=True, show=True):
    if use_metis == False:
        with torch.no_grad():
            edge_probs = model.edge_prob_mlp(data.x, data.edge_index).squeeze()
            sampled_edge_indices, sampled_edge_weight = gumbel_softmax_sampling(data,
                edge_probs,
                data.edge_index,
                q=sample_size, istest=istest)

            sampled_edge_index = data.edge_index[:, sampled_edge_indices]
            fig = None
            #fig = visualize_graphs_side_by_side(data, train_mask=data.train_mask, sampled_edge_index=sampled_edge_index, show=show)

            # Example Usage
            # Assuming `data` is your original graph and `sampled_edge_index` is your sampled edge index
            result = count_edges_with_different_labels(data, sampled_edge_index)

            print("\% of heterophily:")

            # Print the results
            print(f"Original graph: {result['original_graph']['different_label_edges']} edges with different labels "
                  f"out of {result['original_graph']['total_edges']} total edges "
                  f"({result['original_graph']['percentage']:.2f}%).")

            print(f"Sampled graph: {result['sampled_graph']['different_label_edges']} edges with different labels "
                  f"out of {result['sampled_graph']['total_edges']} total edges "
                  f"({result['sampled_graph']['percentage']:.2f}%).")
            
            return fig
            
fig = visualize(False) #Sampled from the best
fig = visualize(True)  #Best Sparsifier
# Out:
# \% of heterophily:
# Original graph: 57656 edges with different labels out of 93050 total edges (61.96%).
# Sampled graph: 9971 edges with different labels out of 15791 total edges (63.14%).
# \% of heterophily:
# Original graph: 57656 edges with different labels out of 93050 total edges (61.96%).
# Sampled graph: 9986 edges with different labels out of 15791 total edges (63.24%).

# %%
# def sample_gumbel(shape, eps=1e-20):
#     """Sample from Gumbel(0, 1)"""
#     U = torch.rand(shape)
#     return -torch.log(-torch.log(U + eps) + eps)

# # Example usage
# shape = (10,)  # Sample 10 values
# gumbel_noise = sample_gumbel(shape)
# print(gumbel_noise)

# %% [markdown]
# ## Animate the Sparsification

# %%
def store_figures_during_test():
    figures = []
    for epoch in range(20):  # Assuming 100 epochs
        fig = visualize(False, False)
        figures.append(fig)
        plt.close(fig)
    return figures

# figures = store_figures_during_test()

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation

def create_animation_from_figures(figures):
    fig_anim, ax_anim = plt.subplots()

    def update_fig(i):
        ax_anim.clear()
        figures[i].canvas.draw()
        img_array = np.frombuffer(figures[i].canvas.tostring_rgb(), dtype=np.uint8)
        img_array = img_array.reshape(figures[i].canvas.get_width_height()[::-1] + (3,))
        ax_anim.imshow(img_array)
        ax_anim.axis('off')

    ani = animation.FuncAnimation(fig_anim, update_fig, frames=len(figures), interval=200, blit=False)

    from IPython.display import HTML
    return HTML(ani.to_jshtml())

# # Example Usage:
# # Assuming `figures` is a list of stored figure objects from `store_figures_during_training`.
# animation_html = create_animation_from_figures(figures)
# display(animation_html)

# %%
if figure_log:
    animation_html = create_animation_from_figures(train_figures)
    display(animation_html)
