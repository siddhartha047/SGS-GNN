# %%
import os
import sys
import math
import copy 
import torch 
import random
DEBUG = False
import numpy as np
import torch_sparse
import pandas as pd 
import pickle as pkl
from tqdm import tqdm
from time import time
import networkx as nx
from dgl import DGLGraph
from scipy import linalg
from pathlib import Path
from torch import Tensor
import scipy.sparse as sp
from random import randint
from dgl import transforms
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
from scipy import sparse, stats
from scipy.sparse import csgraph
from scipy.sparse import csr_matrix
from dgl import from_networkx, DGLGraph
from torch_geometric.utils import scatter
from dgl.data import citation_graph as citegrh
from torch_geometric.typing import SparseTensor
from torch_geometric.utils import to_undirected
from torch_geometric.utils import remove_self_loops
from sklearn.metrics.pairwise import cosine_similarity
# from ipynb.fs.full.Dataset import get_data_from_dataset
# from ipynb.fs.full.Dataset import get_data_from_dataset,train_val_test_mask
from ogb.nodeproppred import Evaluator, PygNodePropPredDataset
from typing import Callable, List, NamedTuple, Optional, Tuple, Union
from torch_geometric.utils import add_self_loops,add_remaining_self_loops
# from ipynb.fs.full.SpectralSparsifier import EffectiveResistance, LocalEffectiveResistance, get_sparse_adj_matrix

# %%
import numpy as np
import torch
import pickle as pkl
import sys
import networkx as nx
import numpy as np
import scipy.sparse as sp

import argparse
import time
from time import localtime
import torch
import torch.nn.functional as F
from dgl import DGLGraph
from dgl.data import register_data_args, load_data
import random
from torch.backends import cudnn
import networkx as nx
import numpy as np
import torch
import torch.nn as nn
import dgl.function as fn
from dgl.nn.pytorch import edge_softmax
import numpy as np
import torch.nn.functional as F

import torch
import torch.nn as nn
import dgl.function as fn
from dgl.nn.pytorch import edge_softmax
import numpy as np
import torch.nn.functional as F

# %%
import torch
from contextlib import contextmanager
import subprocess
import re

# # At the start of your script
# torch.cuda.reset_peak_memory_stats()  # Reset memory statistics

# # ... your training loop ...

# # Get max memory used (in bytes)
# max_memory = torch.cuda.max_memory_allocated()
# print(f"Max GPU memory used: {max_memory / 1024**2:.2f} MB")

# # Optionally, get memory by device if using multiple GPUs
# for i in range(torch.cuda.device_count()):
#     max_memory = torch.cuda.max_memory_allocated(i)
#     print(f"Max GPU memory used on device {i}: {max_memory / 1024**2:.2f} MB")


# @contextmanager
# def track_memory_usage(description="", device=None):
#     if device is None:
#         device = torch.cuda.current_device()
#     torch.cuda.synchronize(device)
#     torch.cuda.reset_peak_memory_stats(device)
#     yield
#     torch.cuda.synchronize(device)
#     max_memory = torch.cuda.max_memory_allocated(device)
#     print(f"{description} Max GPU memory used: {max_memory / 1024**2:.2f} MB")
    
def get_gpu_memory_usage():
    result = subprocess.check_output(['nvidia-smi', '--query-gpu=memory.used', '--format=csv,nounits,noheader'])
    memory_usage = [int(x) for x in result.decode('utf-8').strip().split('\n')]
    return memory_usage

# Call this periodically during training to track memory usage
get_gpu_memory_usage()
# Out:
# [1271]

# %%
import DeviceDir

DIR, RESULTS_DIR = DeviceDir.get_directory()
device, NUM_PROCESSORS = DeviceDir.get_device()

# %%
from ipynb.fs.full.SGSLoadDataset import LOAD_DATASET, train_val_test_mask

DATASET_NAME = "moon"
data, dataset  = LOAD_DATASET(DIR, DATASET_NAME)
num_classes = max(data.y).item()+1
# if DATASET_NAME == "wiki":
#     data = train_val_test_mask(data, train=0.2, val=0.4, test=0.4, random_state=False)
# data
if len(data.train_mask.shape)>1:
    index = 0
    data.train_mask = data.train_mask[:,index]
    data.val_mask = data.val_mask[:,index]
    if DATASET_NAME == 'wiki':
        None
    else:
        data.test_mask = data.test_mask[:,index]
    
data
# Out:
# moon N: 100 E: 574 F: 2 C: 2 d: 5.74 lr: 0.20 i: False s: False u: True
# Data(x=[100, 2], edge_index=[2, 574], y=[100], train_mask=[100], val_mask=[100], test_mask=[100], edge_weight=[574, 1])

# %%
from ipynb.fs.full.Moon import MoonDataset

DATASET_NAME = "moon"
dataset = MoonDataset(n_samples=150, degree=4, train=0.3, h=0.2)
data = dataset[0]

if "train_mask" not in data.__dict__["_store"]:
    data = train_val_test_mask(data, train=0.3, val=0.3, test=0.4, random_state=False)

num_classes = max(data.y).item() + 1

# %%
sig = nn.Sigmoid()
hardtanh = nn.Hardtanh(0,1)
gamma = -0.1
zeta = 1.1
beta = 0.66
eps = 1e-20
const1 = beta*np.log(-gamma/zeta + eps)

def l0_train(logAlpha, min, max):
    U = torch.rand(logAlpha.size()).type_as(logAlpha) + eps
    s = sig((torch.log(U / (1 - U)) + logAlpha) / beta)
    s_bar = s * (zeta - gamma) + gamma
    mask = F.hardtanh(s_bar, min, max)
    return mask

def l0_test(logAlpha, min, max):
    s = sig(logAlpha/beta)
    s_bar = s * (zeta - gamma) + gamma
    mask = F.hardtanh(s_bar, min, max)
    return mask

def get_loss2(logAlpha):
    return sig(logAlpha - const1)


class GraphAttention(nn.Module):
    def __init__(self,
                 g,
                 in_dim,
                 out_dim,
                 num_heads,
                 feat_drop,
                 attn_drop,
                 alpha,
                 bias_l0,
                 residual=False,l0=0, min=0):
        super(GraphAttention, self).__init__()
        self.g = g
        self.num_heads = num_heads
        self.fc = nn.Linear(in_dim, num_heads * out_dim, bias=False)
        if feat_drop:
            self.feat_drop = nn.Dropout(feat_drop)
        else:
            self.feat_drop = lambda x : x
        if attn_drop:
            self.attn_drop = nn.Dropout(attn_drop)
        else:
            self.attn_drop = lambda x : x
        self.attn_l = nn.Parameter(torch.Tensor(size=(1, 1, out_dim)))
        self.attn_r = nn.Parameter(torch.Tensor(size=(1, 1, out_dim)))
        self.bias_l0 = nn.Parameter(torch.FloatTensor([bias_l0]))

        nn.init.xavier_normal_(self.fc.weight.data, gain=1.414)
        nn.init.xavier_normal_(self.attn_l.data, gain=1.414)
        nn.init.xavier_normal_(self.attn_r.data, gain=1.414)
        self.leaky_relu = nn.LeakyReLU(alpha)
        self.softmax = edge_softmax
        self.residual = residual
        self.num = 0
        self.l0 = l0
        self.loss = 0
        self.dis = []
        self.min=min
        if residual:
            if in_dim != out_dim:
                self.res_fc = nn.Linear(in_dim, num_heads * out_dim, bias=False)
                nn.init.xavier_normal_(self.res_fc.weight.data, gain=1.414)
            else:
                self.res_fc = None

    def forward(self, inputs, edges="__ALL__", skip=0):
        self.loss = 0
        # prepare
        h = self.feat_drop(inputs)  # NxD
        ft = self.fc(h).reshape((h.shape[0], self.num_heads, -1))  # NxHxD'
        a1 = (ft * self.attn_l).sum(dim=-1).unsqueeze(-1) # N x H x 1
        a2 = (ft * self.attn_r).sum(dim=-1).unsqueeze(-1) # N x H x 1
      
        self.g.ndata.update({'ft' : ft, 'a1' : a1, 'a2' : a2})

        if skip == 0:
            # 1. compute edge attention
            self.g.apply_edges(self.edge_attention, edges)

            # 2. compute softmax
            if self.l0 == 1:
                ind = self.g.nodes()
                self.g.apply_edges(self.loop, edges=(ind, ind))

            self.edge_softmax()

            if self.l0 == 1:
                self.g.apply_edges(self.norm)

        # 2. compute the aggregated node features scaled by the dropped,
            edges = self.g.edata['a'].squeeze().nonzero().squeeze()


        self.g.edata['a_drop'] = self.attn_drop(self.g.edata['a'])
        self.num = (self.g.edata['a'] > 0).sum()
        self.g.update_all(fn.u_mul_e('ft', 'a_drop', 'ft'), fn.sum('ft', 'ft'))
        ret = self.g.ndata['ft']

        # 4. residual
        if self.residual:
            if self.res_fc is not None:
                resval = self.res_fc(h).reshape((h.shape[0], self.num_heads, -1))  # NxHxD'
            else:
                resval = torch.unsqueeze(h, 1)  # Nx1xD'
            ret = resval + ret
        return ret, edges

    def edge_attention(self, edges):
        # an edge UDF to compute unnormalized attention values from src and dst
        if self.l0 == 0:
            m = self.leaky_relu(edges.src['a1'] + edges.dst['a2'])
        else:
            tmp = edges.src['a1'] + edges.dst['a2']
            logits = tmp + self.bias_l0

            if self.training:
                m = l0_train(logits, 0, 1)
            else:
                m = l0_test(logits, 0, 1)
            self.loss = get_loss2(logits[:,0,:]).sum()
        return {'a': m}

    def norm(self, edges):
        # normalize attention
        a = edges.data['a'] / edges.dst['z']
        return {'a' : a}

    def loop(self, edges):
        # set attention to itself as 1
        return {'a': torch.pow(edges.data['a'], 0)}

    def normalize(self, logits):
        self._logits_name = "_logits"
        self._normalizer_name = "_norm"
        self.g.edata[self._logits_name] = logits
        self.g.update_all(fn.copy_edge(self._logits_name, self._logits_name),
                         fn.sum(self._logits_name, self._normalizer_name))
        return self.g.edata.pop(self._logits_name), self.g.ndata.pop(self._normalizer_name)

    def edge_softmax(self):

        if self.l0 == 0:
            scores = self.softmax(self.g, self.g.edata.pop('a'))
        else:
            scores, normalizer = self.normalize(self.g.edata.pop('a'))
            self.g.ndata['z'] = normalizer[:,0,:].unsqueeze(1)

        self.g.edata['a'] = scores[:,0,:].unsqueeze(1)

class GAT(nn.Module):
    def __init__(self,
                 g,
                 num_layers,
                 in_dim,
                 num_hidden,
                 num_classes,
                 heads,
                 activation,
                 feat_drop,
                 attn_drop,
                 alpha,
                 bias_l0,
                 residual, l0=0):
        super(GAT, self).__init__()
        self.g = g
        self.num_layers = num_layers
        self.gat_layers = nn.ModuleList()
        self.activation = activation
        # input projection (no residual)
        self.gat_layers.append(GraphAttention(
            g, in_dim, num_hidden, heads[0], feat_drop, attn_drop, alpha,bias_l0, False, l0=l0, min=0))
        # hidden layers
        for l in range(1, num_layers):
            # due to multi-head, the in_dim = num_hidden * num_heads
            self.gat_layers.append(GraphAttention(
                g, num_hidden * heads[l-1], num_hidden, heads[l],
                feat_drop, attn_drop, alpha,bias_l0, residual, l0=l0, min=0))
        # output projection
        self.gat_layers.append(GraphAttention(
            g, num_hidden * heads[-2], num_classes, heads[-1],
            feat_drop, attn_drop, alpha,bias_l0, residual, l0=l0))


    def forward(self, inputs):

        h = inputs
        edges = "__ALL__"
        h, edges = self.gat_layers[0](h, edges)
        h = self.activation(h.flatten(1))
        for l in range(1, self.num_layers):
            h, _= self.gat_layers[l](h, edges, skip=1)
            h = self.activation(h.flatten(1))

        # output projection
        logits,_ = self.gat_layers[-1](h, edges, skip=1)
        logits = logits.mean(1)
        return logits

# %% [markdown]
# utils .py

# %%
class EarlyStopping:
    def __init__(self, patience=10):
        self.patience = patience
        self.counter = 0
        self.best_score = None
        self.early_stop = False

    def step(self, acc, model):
        score = acc
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(model)
        elif score < self.best_score:
            self.counter += 1
            # print('EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(model)
            self.counter = 0
        return self.early_stop

    def save_checkpoint(self, model):
        '''Saves model when validation loss decrease.'''
        torch.save(model.state_dict(), 'es_checkpoint.pt')

# %% [markdown]
# GAT . py

# %%
from sklearn.metrics import f1_score

def accuracy(logits, labels):
#     _, indices = torch.max(logits, dim=1)
#     correct = torch.sum(indices == labels)
#     return correct.item() * 1.0 / len(labels)
    preds = logits.argmax(dim=1)
    f1 = f1_score(labels.cpu(), preds.cpu(), average='micro')
    return f1
    

def evaluate(model, features, labels, mask,loss_fcn):
    model.eval()
    with torch.no_grad():
        logits = model(features)
        logits = logits[mask]
        labels = labels[mask]
        loss_data = loss_fcn(logits, labels)
        return accuracy(logits, labels), loss_data

def set_seeds(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if gpu >= 0:
        torch.cuda.manual_seed(seed)
        cudnn.benchmark = False
        cudnn.deterministic = True

# %%
num_out_heads = 4
num_heads = 15
num_layers = 2
gpu = -1
l0 = 0
num_hidden = 128
residual = False 
idrop = 0.6
adrop = 0.6
lr = 0.005 
weight_decay = 5e-4
alpha = 0.2
early_stop = True 
fastmode = False 
seed = 123 
bias = 0 
loss_lo = 0 
syn_type = "scipy" 
self_loop = False 
sess ='default'
loss_l0  = 0
weight_decay = 0
l0 = 0

#data, dataset = get_data_from_dataset('cornell5')
epochs = 1500

data = data.to(device)

#features = torch.FloatTensor(data.x)
features = data.x
#labels = torch.LongTensor(data.y)
labels = data.y
train_mask = data.train_mask
val_mask = data.val_mask
test_mask = data.test_mask
num_feats = features.shape[1]
n_classes = max(data.y).item()+1
n_edges = data.num_edges
current_time = time.strftime('%d_%H:%M:%S', localtime())
print("HELLO WORLD")

print("""----Data statistics------'
    #Edges %d
    #Classes %d
    #Train samples %d
    #Val samples %d
    #Test samples %d""" %
        (n_edges, n_classes,
        train_mask.sum().item(),
        val_mask.sum().item(),
        test_mask.sum().item()))

cuda = True

import dgl
from dgl.data.utils import generate_mask_tensor

g = dgl.graph((data.edge_index[0], data.edge_index[1]), num_nodes=data.x.size(0))

# Add node features
g.ndata['feat'] = data.x
g.ndata['label'] = data.y
# g.ndata['train_mask'] = generate_mask_tensor(data.train_mask.numpy())
# g.ndata['val_mask'] = generate_mask_tensor(data.val_mask.numpy())
# g.ndata['test_mask'] = generate_mask_tensor(data.test_mask.numpy())

g.ndata['train_mask'] = data.train_mask
g.ndata['val_mask'] = data.val_mask
g.ndata['test_mask'] = data.test_mask


n_edges = g.number_of_edges()
heads = ([num_heads] * num_layers) + [num_out_heads]

model = GAT(g,
            num_layers,
            num_feats,
            num_hidden,
            n_classes,
            heads,
            F.elu,
            idrop,
            adrop,
            alpha,
            bias,
            residual,
            l0).to(device)
print(model)

if early_stop:
    stopper = EarlyStopping(patience=150)
loss_fcn = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
dur = []
time_used = 0
# Out:
# HELLO WORLD
# ----Data statistics------'
#     #Edges 864
#     #Classes 2
#     #Train samples 45
#     #Val samples 45
#     #Test samples 60
# GAT(
#   (gat_layers): ModuleList(
#     (0): GraphAttention(
#       (fc): Linear(in_features=2, out_features=1920, bias=False)
#       (feat_drop): Dropout(p=0.6, inplace=False)
#       (attn_drop): Dropout(p=0.6, inplace=False)
#       (leaky_relu): LeakyReLU(negative_slope=0.2)
#     )
#     (1): GraphAttention(
#       (fc): Linear(in_features=1920, out_features=1920, bias=False)
#       (feat_drop): Dropout(p=0.6, inplace=False)
#       (attn_drop): Dropout(p=0.6, inplace=False)
#       (leaky_relu): LeakyReLU(negative_slope=0.2)
#     )
#     (2): GraphAttention(
#       (fc): Linear(in_features=1920, out_features=8, bias=False)
#       (feat_drop): Dropout(p=0.6, inplace=False)
#       (attn_drop): Dropout(p=0.6, inplace=False)
#       (leaky_relu): LeakyReLU(negative_slope=0.2)
#     )
#   )
# )

# %%
model
# Out:
# GAT(
#   (gat_layers): ModuleList(
#     (0): GraphAttention(
#       (fc): Linear(in_features=2, out_features=1920, bias=False)
#       (feat_drop): Dropout(p=0.6, inplace=False)
#       (attn_drop): Dropout(p=0.6, inplace=False)
#       (leaky_relu): LeakyReLU(negative_slope=0.2)
#     )
#     (1): GraphAttention(
#       (fc): Linear(in_features=1920, out_features=1920, bias=False)
#       (feat_drop): Dropout(p=0.6, inplace=False)
#       (attn_drop): Dropout(p=0.6, inplace=False)
#       (leaky_relu): LeakyReLU(negative_slope=0.2)
#     )
#     (2): GraphAttention(
#       (fc): Linear(in_features=1920, out_features=8, bias=False)
#       (feat_drop): Dropout(p=0.6, inplace=False)
#       (attn_drop): Dropout(p=0.6, inplace=False)
#       (leaky_relu): LeakyReLU(negative_slope=0.2)
#     )
#   )
# )

# %%
dur = []
best_test_f1 = 0

for epoch in range(epochs):
    
    model.train()
    t0 = time.time()

    # forward
    logits = model(features)
    loss = loss_fcn(logits[train_mask], labels[train_mask])

    loss_l0 = loss_l0*( model.gat_layers[0].loss)
    optimizer.zero_grad()
    (loss + loss_l0).backward()
    optimizer.step()
    dur.append(time.time() - t0)
    
    print(get_gpu_memory_usage()[0], "MB")

    train_acc = accuracy(logits[train_mask], labels[train_mask])

    
    if fastmode:
        val_acc, loss = accuracy(logits[val_mask], labels[val_mask], loss_fcn)
    else:
        val_acc,_ = evaluate(model, features, labels, val_mask, loss_fcn)
        # if early_stop:
        #     if stopper.step(val_acc, model):   
        #         break        
    
    print("Epoch {:05d} | Time(s) {:.4f} | Loss {:.4f} | TrainAcc {:.4f} |"
            " ValAcc {:.4f} | ETputs(KTEPS) {:.2f}".format(epoch, np.mean(dur), loss.item(), train_acc,
                    val_acc, n_edges / np.mean(dur) / 1000))
# print(dataset.name)


print("Time per epoch: ", np.mean(dur))
# Out:
# 1303 MB
# Epoch 00000 | Time(s) 0.0094 | Loss 0.7646 | TrainAcc 0.4667 | ValAcc 0.5333 | ETputs(KTEPS) 91.71
# 1303 MB
# Epoch 00001 | Time(s) 0.0072 | Loss 7.0894 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 120.72
# 1303 MB
# Epoch 00002 | Time(s) 0.0064 | Loss 2.0164 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 135.00
# 1303 MB
# Epoch 00003 | Time(s) 0.0061 | Loss 6.3295 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 142.77
# 1303 MB
# Epoch 00004 | Time(s) 0.0058 | Loss 5.1458 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 148.43
# 1303 MB
# Epoch 00005 | Time(s) 0.0057 | Loss 1.8948 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 152.36
# 1303 MB
# Epoch 00006 | Time(s) 0.0056 | Loss 1.4954 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 153.57
# 1303 MB
# Epoch 00007 | Time(s) 0.0055 | Loss 2.5660 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 157.01
# 1303 MB
# Epoch 00008 | Time(s) 0.0055 | Loss 1.6245 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 158.38
# 1303 MB
# Epoch 00009 | Time(s) 0.0054 | Loss 1.1855 | TrainAcc 0.5111 | ValAcc 0.4889 | ETputs(KTEPS) 160.10
# 1303 MB
# Epoch 00010 | Time(s) 0.0054 | Loss 2.7290 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 161.45
# 1303 MB
# Epoch 00011 | Time(s) 0.0053 | Loss 1.3825 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 162.69
# 1303 MB
# Epoch 00012 | Time(s) 0.0053 | Loss 1.9727 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 163.69
# 1303 MB
# Epoch 00013 | Time(s) 0.0052 | Loss 0.7024 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 164.97
# 1303 MB
# Epoch 00014 | Time(s) 0.0052 | Loss 1.3514 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 165.97
# 1303 MB
# Epoch 00015 | Time(s) 0.0052 | Loss 0.9196 | TrainAcc 0.5111 | ValAcc 0.5111 | ETputs(KTEPS) 165.51
# 1303 MB
# Epoch 00016 | Time(s) 0.0052 | Loss 0.9548 | TrainAcc 0.5556 | ValAcc 0.4000 | ETputs(KTEPS) 165.93
# 1303 MB
# Epoch 00017 | Time(s) 0.0052 | Loss 0.7570 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 167.00
# 1303 MB
# Epoch 00018 | Time(s) 0.0052 | Loss 0.8566 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 167.07
# 1303 MB
# Epoch 00019 | Time(s) 0.0052 | Loss 0.8007 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 167.61
# 1303 MB
# Epoch 00020 | Time(s) 0.0051 | Loss 0.6515 | TrainAcc 0.5556 | ValAcc 0.4889 | ETputs(KTEPS) 168.22
# 1303 MB
# Epoch 00021 | Time(s) 0.0051 | Loss 0.7189 | TrainAcc 0.4667 | ValAcc 0.5111 | ETputs(KTEPS) 168.77
# 1303 MB
# Epoch 00022 | Time(s) 0.0051 | Loss 0.7625 | TrainAcc 0.5556 | ValAcc 0.5333 | ETputs(KTEPS) 169.02
# 1303 MB
# Epoch 00023 | Time(s) 0.0051 | Loss 0.6729 | TrainAcc 0.6222 | ValAcc 0.5333 | ETputs(KTEPS) 169.37
# 1303 MB
# Epoch 00024 | Time(s) 0.0051 | Loss 0.6537 | TrainAcc 0.6000 | ValAcc 0.5333 | ETputs(KTEPS) 169.89
# 1303 MB
# Epoch 00025 | Time(s) 0.0051 | Loss 0.7265 | TrainAcc 0.6222 | ValAcc 0.5333 | ETputs(KTEPS) 170.20
# 1303 MB
# Epoch 00026 | Time(s) 0.0051 | Loss 0.7934 | TrainAcc 0.4667 | ValAcc 0.5333 | ETputs(KTEPS) 170.45
# 1303 MB
# Epoch 00027 | Time(s) 0.0051 | Loss 0.7464 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 170.99
# 1303 MB
# Epoch 00028 | Time(s) 0.0050 | Loss 0.7067 | TrainAcc 0.4222 | ValAcc 0.4667 | ETputs(KTEPS) 171.44
# 1303 MB
# Epoch 00029 | Time(s) 0.0050 | Loss 0.6837 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 171.80
# 1303 MB
# Epoch 00030 | Time(s) 0.0050 | Loss 0.7098 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 172.32
# 1303 MB
# Epoch 00031 | Time(s) 0.0050 | Loss 0.7774 | TrainAcc 0.3333 | ValAcc 0.2444 | ETputs(KTEPS) 172.74
# 1303 MB
# Epoch 00032 | Time(s) 0.0050 | Loss 0.6793 | TrainAcc 0.4444 | ValAcc 0.5333 | ETputs(KTEPS) 173.14
# 1303 MB
# Epoch 00033 | Time(s) 0.0050 | Loss 0.6908 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 173.39
# 1303 MB
# Epoch 00034 | Time(s) 0.0050 | Loss 0.7445 | TrainAcc 0.4222 | ValAcc 0.5333 | ETputs(KTEPS) 173.43
# 1303 MB
# Epoch 00035 | Time(s) 0.0050 | Loss 0.7140 | TrainAcc 0.4444 | ValAcc 0.5333 | ETputs(KTEPS) 173.72
# 1303 MB
# Epoch 00036 | Time(s) 0.0050 | Loss 0.6826 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 174.07
# 1303 MB
# Epoch 00037 | Time(s) 0.0050 | Loss 0.7766 | TrainAcc 0.4222 | ValAcc 0.5333 | ETputs(KTEPS) 174.41
# 1303 MB
# Epoch 00038 | Time(s) 0.0049 | Loss 0.6306 | TrainAcc 0.6667 | ValAcc 0.5333 | ETputs(KTEPS) 174.70
# 1303 MB
# Epoch 00039 | Time(s) 0.0049 | Loss 0.6831 | TrainAcc 0.5778 | ValAcc 0.5333 | ETputs(KTEPS) 174.81
# 1303 MB
# Epoch 00040 | Time(s) 0.0049 | Loss 0.7085 | TrainAcc 0.6000 | ValAcc 0.5333 | ETputs(KTEPS) 174.88
# 1303 MB
# Epoch 00041 | Time(s) 0.0049 | Loss 0.7466 | TrainAcc 0.4889 | ValAcc 0.4889 | ETputs(KTEPS) 174.93
# 1303 MB
# Epoch 00042 | Time(s) 0.0049 | Loss 0.7665 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 175.04
# 1303 MB
# Epoch 00043 | Time(s) 0.0049 | Loss 0.7651 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 175.14
# 1303 MB
# Epoch 00044 | Time(s) 0.0049 | Loss 0.7529 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 175.39
# 1303 MB
# Epoch 00045 | Time(s) 0.0049 | Loss 0.8380 | TrainAcc 0.4222 | ValAcc 0.4667 | ETputs(KTEPS) 175.51
# 1303 MB
# Epoch 00046 | Time(s) 0.0049 | Loss 0.7103 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 175.72
# 1303 MB
# Epoch 00047 | Time(s) 0.0049 | Loss 0.8383 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 175.82
# 1303 MB
# Epoch 00048 | Time(s) 0.0049 | Loss 0.6920 | TrainAcc 0.5778 | ValAcc 0.5333 | ETputs(KTEPS) 175.76
# 1303 MB
# Epoch 00049 | Time(s) 0.0049 | Loss 0.7725 | TrainAcc 0.4667 | ValAcc 0.5333 | ETputs(KTEPS) 175.93
# 1303 MB
# Epoch 00050 | Time(s) 0.0049 | Loss 0.7240 | TrainAcc 0.5778 | ValAcc 0.4667 | ETputs(KTEPS) 175.54
# 1303 MB
# Epoch 00051 | Time(s) 0.0049 | Loss 0.7227 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 175.66
# 1303 MB
# Epoch 00052 | Time(s) 0.0049 | Loss 0.7109 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 175.90
# 1303 MB
# Epoch 00053 | Time(s) 0.0049 | Loss 0.6743 | TrainAcc 0.4889 | ValAcc 0.7111 | ETputs(KTEPS) 175.85
# 1303 MB
# Epoch 00054 | Time(s) 0.0049 | Loss 0.6937 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 175.73
# 1303 MB
# Epoch 00055 | Time(s) 0.0049 | Loss 0.7179 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 175.92
# 1303 MB
# Epoch 00056 | Time(s) 0.0049 | Loss 0.7105 | TrainAcc 0.5556 | ValAcc 0.5333 | ETputs(KTEPS) 176.05
# 1303 MB
# Epoch 00057 | Time(s) 0.0049 | Loss 0.7204 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 176.06
# 1303 MB
# Epoch 00058 | Time(s) 0.0049 | Loss 0.6941 | TrainAcc 0.4889 | ValAcc 0.5556 | ETputs(KTEPS) 175.96
# 1303 MB
# Epoch 00059 | Time(s) 0.0049 | Loss 0.7029 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 175.98
# 1303 MB
# Epoch 00060 | Time(s) 0.0049 | Loss 1.1519 | TrainAcc 0.3778 | ValAcc 0.4667 | ETputs(KTEPS) 176.06
# 1303 MB
# Epoch 00061 | Time(s) 0.0049 | Loss 0.7516 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 176.03
# 1303 MB
# Epoch 00062 | Time(s) 0.0049 | Loss 0.7039 | TrainAcc 0.4667 | ValAcc 0.5333 | ETputs(KTEPS) 176.19
# 1303 MB
# Epoch 00063 | Time(s) 0.0049 | Loss 0.7884 | TrainAcc 0.4222 | ValAcc 0.5333 | ETputs(KTEPS) 176.27
# 1303 MB
# Epoch 00064 | Time(s) 0.0049 | Loss 0.7370 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 176.27
# 1303 MB
# Epoch 00065 | Time(s) 0.0049 | Loss 0.7970 | TrainAcc 0.6000 | ValAcc 0.4444 | ETputs(KTEPS) 176.26
# 1303 MB
# Epoch 00066 | Time(s) 0.0049 | Loss 0.7171 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 176.40
# 1303 MB
# Epoch 00067 | Time(s) 0.0049 | Loss 0.8398 | TrainAcc 0.4222 | ValAcc 0.4667 | ETputs(KTEPS) 176.28
# 1303 MB
# Epoch 00068 | Time(s) 0.0049 | Loss 0.6788 | TrainAcc 0.6000 | ValAcc 0.5778 | ETputs(KTEPS) 176.21
# 1303 MB
# Epoch 00069 | Time(s) 0.0049 | Loss 0.8101 | TrainAcc 0.5333 | ValAcc 0.6667 | ETputs(KTEPS) 176.33
# 1303 MB
# Epoch 00070 | Time(s) 0.0049 | Loss 0.7596 | TrainAcc 0.4667 | ValAcc 0.5333 | ETputs(KTEPS) 176.34
# 1303 MB
# Epoch 00071 | Time(s) 0.0049 | Loss 0.7171 | TrainAcc 0.4444 | ValAcc 0.5333 | ETputs(KTEPS) 176.37
# 1303 MB
# Epoch 00072 | Time(s) 0.0049 | Loss 0.7426 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 176.37
# 1303 MB
# Epoch 00073 | Time(s) 0.0049 | Loss 0.7374 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 176.21
# 1303 MB
# Epoch 00074 | Time(s) 0.0049 | Loss 0.8830 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 176.32
# 1303 MB
# Epoch 00075 | Time(s) 0.0049 | Loss 0.7285 | TrainAcc 0.6000 | ValAcc 0.4667 | ETputs(KTEPS) 176.33
# 1303 MB
# Epoch 00076 | Time(s) 0.0049 | Loss 0.7549 | TrainAcc 0.3778 | ValAcc 0.4667 | ETputs(KTEPS) 176.03
# 1303 MB
# Epoch 00077 | Time(s) 0.0049 | Loss 0.9019 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 176.03
# 1303 MB
# Epoch 00078 | Time(s) 0.0049 | Loss 0.8733 | TrainAcc 0.4222 | ValAcc 0.4667 | ETputs(KTEPS) 176.07
# 1303 MB
# Epoch 00079 | Time(s) 0.0049 | Loss 0.7407 | TrainAcc 0.4667 | ValAcc 0.5333 | ETputs(KTEPS) 176.11
# 1303 MB
# Epoch 00080 | Time(s) 0.0049 | Loss 0.6620 | TrainAcc 0.6444 | ValAcc 0.5333 | ETputs(KTEPS) 176.19
# 1303 MB
# Epoch 00081 | Time(s) 0.0049 | Loss 0.7294 | TrainAcc 0.5778 | ValAcc 0.5333 | ETputs(KTEPS) 175.37
# 1303 MB
# Epoch 00082 | Time(s) 0.0049 | Loss 0.8654 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 175.21
# 1303 MB
# Epoch 00083 | Time(s) 0.0049 | Loss 0.8117 | TrainAcc 0.6000 | ValAcc 0.5333 | ETputs(KTEPS) 175.27
# 1303 MB
# Epoch 00084 | Time(s) 0.0049 | Loss 0.7177 | TrainAcc 0.5556 | ValAcc 0.5333 | ETputs(KTEPS) 175.28
# 1303 MB
# Epoch 00085 | Time(s) 0.0049 | Loss 0.7162 | TrainAcc 0.4667 | ValAcc 0.6444 | ETputs(KTEPS) 175.40
# 1303 MB
# Epoch 00086 | Time(s) 0.0049 | Loss 0.7141 | TrainAcc 0.6222 | ValAcc 0.4889 | ETputs(KTEPS) 175.30
# 1303 MB
# Epoch 00087 | Time(s) 0.0049 | Loss 0.8373 | TrainAcc 0.5556 | ValAcc 0.4444 | ETputs(KTEPS) 175.40
# 1303 MB
# Epoch 00088 | Time(s) 0.0049 | Loss 0.7642 | TrainAcc 0.5111 | ValAcc 0.4889 | ETputs(KTEPS) 175.47
# 1303 MB
# Epoch 00089 | Time(s) 0.0049 | Loss 0.7203 | TrainAcc 0.5778 | ValAcc 0.5333 | ETputs(KTEPS) 175.50
# 1303 MB
# Epoch 00090 | Time(s) 0.0049 | Loss 0.7515 | TrainAcc 0.4222 | ValAcc 0.5333 | ETputs(KTEPS) 175.43
# 1303 MB
# Epoch 00091 | Time(s) 0.0049 | Loss 0.7599 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 175.55
# 1303 MB
# Epoch 00092 | Time(s) 0.0049 | Loss 0.8807 | TrainAcc 0.4444 | ValAcc 0.5333 | ETputs(KTEPS) 175.52
# 1303 MB
# Epoch 00093 | Time(s) 0.0049 | Loss 0.6768 | TrainAcc 0.6222 | ValAcc 0.5333 | ETputs(KTEPS) 175.60
# 1303 MB
# Epoch 00094 | Time(s) 0.0049 | Loss 0.7169 | TrainAcc 0.5556 | ValAcc 0.5333 | ETputs(KTEPS) 175.50
# 1303 MB
# Epoch 00095 | Time(s) 0.0049 | Loss 0.6896 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 175.53
# 1303 MB
# Epoch 00096 | Time(s) 0.0049 | Loss 0.6658 | TrainAcc 0.6444 | ValAcc 0.5333 | ETputs(KTEPS) 175.41
# 1303 MB
# Epoch 00097 | Time(s) 0.0049 | Loss 0.8287 | TrainAcc 0.5111 | ValAcc 0.5556 | ETputs(KTEPS) 175.53
# 1303 MB
# Epoch 00098 | Time(s) 0.0049 | Loss 0.7892 | TrainAcc 0.5556 | ValAcc 0.6444 | ETputs(KTEPS) 175.60
# 1303 MB
# Epoch 00099 | Time(s) 0.0049 | Loss 0.8898 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 175.67
# 1303 MB
# Epoch 00100 | Time(s) 0.0049 | Loss 0.7918 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 175.74
# 1303 MB
# Epoch 00101 | Time(s) 0.0049 | Loss 0.7398 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 175.78
# 1303 MB
# Epoch 00102 | Time(s) 0.0049 | Loss 0.7559 | TrainAcc 0.3778 | ValAcc 0.5333 | ETputs(KTEPS) 175.75
# 1303 MB
# Epoch 00103 | Time(s) 0.0049 | Loss 0.7391 | TrainAcc 0.5778 | ValAcc 0.5333 | ETputs(KTEPS) 175.72
# 1303 MB
# Epoch 00104 | Time(s) 0.0049 | Loss 0.8312 | TrainAcc 0.4444 | ValAcc 0.5333 | ETputs(KTEPS) 175.70
# 1303 MB
# Epoch 00105 | Time(s) 0.0049 | Loss 0.9834 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 175.74
# 1303 MB
# Epoch 00106 | Time(s) 0.0049 | Loss 0.7246 | TrainAcc 0.4222 | ValAcc 0.5333 | ETputs(KTEPS) 175.77
# 1303 MB
# Epoch 00107 | Time(s) 0.0049 | Loss 0.7662 | TrainAcc 0.4667 | ValAcc 0.6222 | ETputs(KTEPS) 175.66
# 1303 MB
# Epoch 00108 | Time(s) 0.0049 | Loss 0.7710 | TrainAcc 0.4444 | ValAcc 0.6222 | ETputs(KTEPS) 175.56
# 1303 MB
# Epoch 00109 | Time(s) 0.0049 | Loss 0.7926 | TrainAcc 0.5333 | ValAcc 0.6444 | ETputs(KTEPS) 175.58
# 1303 MB
# Epoch 00110 | Time(s) 0.0049 | Loss 0.8885 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 175.68
# 1303 MB
# Epoch 00111 | Time(s) 0.0049 | Loss 0.7776 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 175.59
# 1303 MB
# Epoch 00112 | Time(s) 0.0049 | Loss 0.9352 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 175.57
# 1303 MB
# Epoch 00113 | Time(s) 0.0049 | Loss 0.7246 | TrainAcc 0.4000 | ValAcc 0.6000 | ETputs(KTEPS) 175.68
# 1303 MB
# Epoch 00114 | Time(s) 0.0049 | Loss 0.7392 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 175.68
# 1303 MB
# Epoch 00115 | Time(s) 0.0049 | Loss 0.7120 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 175.64
# 1303 MB
# Epoch 00116 | Time(s) 0.0049 | Loss 0.8175 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 175.58
# 1303 MB
# Epoch 00117 | Time(s) 0.0049 | Loss 0.7783 | TrainAcc 0.4000 | ValAcc 0.4667 | ETputs(KTEPS) 175.69
# 1303 MB
# Epoch 00118 | Time(s) 0.0049 | Loss 0.8707 | TrainAcc 0.3778 | ValAcc 0.4667 | ETputs(KTEPS) 175.80
# 1303 MB
# Epoch 00119 | Time(s) 0.0049 | Loss 0.8071 | TrainAcc 0.5778 | ValAcc 0.5333 | ETputs(KTEPS) 175.89
# 1303 MB
# Epoch 00120 | Time(s) 0.0049 | Loss 0.8085 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 175.89
# 1303 MB
# Epoch 00121 | Time(s) 0.0049 | Loss 0.7733 | TrainAcc 0.5111 | ValAcc 0.6889 | ETputs(KTEPS) 175.80
# 1303 MB
# Epoch 00122 | Time(s) 0.0049 | Loss 0.7004 | TrainAcc 0.4444 | ValAcc 0.4889 | ETputs(KTEPS) 175.81
# 1303 MB
# Epoch 00123 | Time(s) 0.0049 | Loss 0.6677 | TrainAcc 0.6000 | ValAcc 0.4889 | ETputs(KTEPS) 175.86
# 1303 MB
# Epoch 00124 | Time(s) 0.0049 | Loss 0.7247 | TrainAcc 0.4667 | ValAcc 0.6889 | ETputs(KTEPS) 175.90
# 1303 MB
# Epoch 00125 | Time(s) 0.0049 | Loss 0.7220 | TrainAcc 0.5778 | ValAcc 0.5333 | ETputs(KTEPS) 176.04
# 1303 MB
# Epoch 00201 | Time(s) 0.0049 | Loss 0.7226 | TrainAcc 0.5333 | ValAcc 0.5111 | ETputs(KTEPS) 176.89
# 1303 MB
# Epoch 00202 | Time(s) 0.0049 | Loss 0.7073 | TrainAcc 0.5778 | ValAcc 0.4667 | ETputs(KTEPS) 176.93
# 1303 MB
# Epoch 00203 | Time(s) 0.0049 | Loss 0.6720 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 176.90
# 1303 MB
# Epoch 00204 | Time(s) 0.0049 | Loss 0.6961 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 176.89
# 1303 MB
# Epoch 00205 | Time(s) 0.0049 | Loss 0.6872 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 176.97
# 1303 MB
# Epoch 00206 | Time(s) 0.0049 | Loss 0.6932 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 177.04
# 1303 MB
# Epoch 00207 | Time(s) 0.0049 | Loss 0.7255 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 177.12
# 1303 MB
# Epoch 00208 | Time(s) 0.0049 | Loss 0.6713 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 177.08
# 1303 MB
# Epoch 00209 | Time(s) 0.0049 | Loss 0.7151 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 177.10
# 1303 MB
# Epoch 00210 | Time(s) 0.0049 | Loss 0.7493 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 177.12
# 1303 MB
# Epoch 00211 | Time(s) 0.0049 | Loss 0.6934 | TrainAcc 0.5556 | ValAcc 0.5333 | ETputs(KTEPS) 177.12
# 1303 MB
# Epoch 00212 | Time(s) 0.0049 | Loss 0.7601 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 177.14
# 1303 MB
# Epoch 00213 | Time(s) 0.0049 | Loss 0.6852 | TrainAcc 0.6000 | ValAcc 0.5333 | ETputs(KTEPS) 177.19
# 1303 MB
# Epoch 00214 | Time(s) 0.0049 | Loss 0.6963 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 177.22
# 1303 MB
# Epoch 00215 | Time(s) 0.0049 | Loss 0.7263 | TrainAcc 0.5556 | ValAcc 0.5333 | ETputs(KTEPS) 177.27
# 1303 MB
# Epoch 00216 | Time(s) 0.0049 | Loss 0.7252 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 177.25
# 1303 MB
# Epoch 00217 | Time(s) 0.0049 | Loss 0.7899 | TrainAcc 0.4667 | ValAcc 0.5333 | ETputs(KTEPS) 177.23
# 1303 MB
# Epoch 00218 | Time(s) 0.0049 | Loss 0.6551 | TrainAcc 0.7111 | ValAcc 0.6444 | ETputs(KTEPS) 177.22
# 1303 MB
# Epoch 00219 | Time(s) 0.0049 | Loss 0.7090 | TrainAcc 0.6222 | ValAcc 0.6444 | ETputs(KTEPS) 177.24
# 1303 MB
# Epoch 00220 | Time(s) 0.0049 | Loss 0.6960 | TrainAcc 0.4889 | ValAcc 0.6444 | ETputs(KTEPS) 177.27
# 1303 MB
# Epoch 00221 | Time(s) 0.0049 | Loss 0.7566 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 177.28
# 1303 MB
# Epoch 00222 | Time(s) 0.0049 | Loss 0.7464 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 177.34
# 1303 MB
# Epoch 00223 | Time(s) 0.0049 | Loss 0.7060 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 177.37
# 1303 MB
# Epoch 00224 | Time(s) 0.0049 | Loss 0.7891 | TrainAcc 0.4000 | ValAcc 0.5333 | ETputs(KTEPS) 177.38
# 1303 MB
# Epoch 00225 | Time(s) 0.0049 | Loss 0.7161 | TrainAcc 0.5556 | ValAcc 0.5333 | ETputs(KTEPS) 177.36
# 1303 MB
# Epoch 00226 | Time(s) 0.0049 | Loss 0.7102 | TrainAcc 0.4667 | ValAcc 0.5333 | ETputs(KTEPS) 177.34
# 1303 MB
# Epoch 00227 | Time(s) 0.0049 | Loss 0.6319 | TrainAcc 0.5778 | ValAcc 0.5333 | ETputs(KTEPS) 177.37
# 1303 MB
# Epoch 00228 | Time(s) 0.0049 | Loss 0.8673 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 177.34
# 1303 MB
# Epoch 00229 | Time(s) 0.0049 | Loss 0.7021 | TrainAcc 0.4222 | ValAcc 0.4667 | ETputs(KTEPS) 177.37
# 1303 MB
# Epoch 00230 | Time(s) 0.0049 | Loss 0.7390 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 177.40
# 1303 MB
# Epoch 00231 | Time(s) 0.0049 | Loss 0.7103 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 177.44
# 1303 MB
# Epoch 00232 | Time(s) 0.0049 | Loss 0.6690 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 177.48
# 1303 MB
# Epoch 00233 | Time(s) 0.0049 | Loss 0.7804 | TrainAcc 0.4000 | ValAcc 0.5333 | ETputs(KTEPS) 177.51
# 1303 MB
# Epoch 00234 | Time(s) 0.0049 | Loss 0.7100 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 177.49
# 1303 MB
# Epoch 00235 | Time(s) 0.0049 | Loss 0.6923 | TrainAcc 0.6000 | ValAcc 0.5333 | ETputs(KTEPS) 177.50
# 1303 MB
# Epoch 00236 | Time(s) 0.0049 | Loss 0.6771 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 177.48
# 1303 MB
# Epoch 00237 | Time(s) 0.0049 | Loss 0.7315 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 177.47
# 1303 MB
# Epoch 00238 | Time(s) 0.0049 | Loss 0.6726 | TrainAcc 0.5556 | ValAcc 0.5333 | ETputs(KTEPS) 177.51
# 1303 MB
# Epoch 00239 | Time(s) 0.0049 | Loss 0.6624 | TrainAcc 0.5556 | ValAcc 0.5333 | ETputs(KTEPS) 177.53
# 1303 MB
# Epoch 00240 | Time(s) 0.0049 | Loss 0.6541 | TrainAcc 0.7111 | ValAcc 0.5333 | ETputs(KTEPS) 177.53
# 1303 MB
# Epoch 00241 | Time(s) 0.0049 | Loss 0.7813 | TrainAcc 0.5556 | ValAcc 0.5333 | ETputs(KTEPS) 177.51
# 1303 MB
# Epoch 00242 | Time(s) 0.0049 | Loss 0.7452 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 177.54
# 1303 MB
# Epoch 00243 | Time(s) 0.0049 | Loss 0.6767 | TrainAcc 0.6222 | ValAcc 0.5333 | ETputs(KTEPS) 177.52
# 1303 MB
# Epoch 00244 | Time(s) 0.0049 | Loss 0.6470 | TrainAcc 0.5778 | ValAcc 0.5333 | ETputs(KTEPS) 177.54
# 1303 MB
# Epoch 00245 | Time(s) 0.0049 | Loss 0.7736 | TrainAcc 0.5778 | ValAcc 0.5333 | ETputs(KTEPS) 177.51
# 1303 MB
# Epoch 00246 | Time(s) 0.0049 | Loss 0.7461 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 177.51
# 1303 MB
# Epoch 00247 | Time(s) 0.0049 | Loss 0.7530 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 177.51
# 1303 MB
# Epoch 00248 | Time(s) 0.0049 | Loss 0.7411 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 177.51
# 1303 MB
# Epoch 00249 | Time(s) 0.0049 | Loss 0.7204 | TrainAcc 0.4667 | ValAcc 0.5333 | ETputs(KTEPS) 177.49
# 1303 MB
# Epoch 00250 | Time(s) 0.0049 | Loss 0.7573 | TrainAcc 0.4889 | ValAcc 0.4000 | ETputs(KTEPS) 177.48
# 1303 MB
# Epoch 00251 | Time(s) 0.0049 | Loss 0.6819 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 177.45
# 1303 MB
# Epoch 00252 | Time(s) 0.0049 | Loss 0.7283 | TrainAcc 0.3111 | ValAcc 0.4667 | ETputs(KTEPS) 177.45
# 1303 MB
# Epoch 00253 | Time(s) 0.0049 | Loss 0.7464 | TrainAcc 0.5778 | ValAcc 0.4667 | ETputs(KTEPS) 177.43
# 1303 MB
# Epoch 00254 | Time(s) 0.0049 | Loss 0.6586 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 177.48
# 1303 MB
# Epoch 00255 | Time(s) 0.0049 | Loss 0.6961 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 177.48
# 1303 MB
# Epoch 00256 | Time(s) 0.0049 | Loss 0.7537 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 177.53
# 1303 MB
# Epoch 00257 | Time(s) 0.0049 | Loss 0.7428 | TrainAcc 0.5111 | ValAcc 0.4889 | ETputs(KTEPS) 177.56
# 1303 MB
# Epoch 00258 | Time(s) 0.0049 | Loss 0.7844 | TrainAcc 0.4222 | ValAcc 0.4667 | ETputs(KTEPS) 177.53
# 1303 MB
# Epoch 00259 | Time(s) 0.0049 | Loss 0.7536 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 177.56
# 1303 MB
# Epoch 00260 | Time(s) 0.0049 | Loss 0.7059 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 177.56
# 1303 MB
# Epoch 00261 | Time(s) 0.0049 | Loss 0.7139 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 177.58
# 1303 MB
# Epoch 00262 | Time(s) 0.0049 | Loss 0.6979 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 177.62
# 1303 MB
# Epoch 00263 | Time(s) 0.0049 | Loss 0.6948 | TrainAcc 0.6444 | ValAcc 0.4667 | ETputs(KTEPS) 177.67
# 1303 MB
# Epoch 00264 | Time(s) 0.0049 | Loss 0.7223 | TrainAcc 0.3778 | ValAcc 0.4667 | ETputs(KTEPS) 177.67
# 1303 MB
# Epoch 00265 | Time(s) 0.0049 | Loss 0.6810 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 177.67
# 1303 MB
# Epoch 00266 | Time(s) 0.0049 | Loss 0.6870 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 177.65
# 1303 MB
# Epoch 00267 | Time(s) 0.0049 | Loss 0.7280 | TrainAcc 0.4444 | ValAcc 0.5333 | ETputs(KTEPS) 177.64
# 1303 MB
# Epoch 00268 | Time(s) 0.0049 | Loss 0.7197 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 177.68
# 1303 MB
# Epoch 00269 | Time(s) 0.0049 | Loss 0.7360 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 177.66
# 1303 MB
# Epoch 00270 | Time(s) 0.0049 | Loss 0.6872 | TrainAcc 0.4889 | ValAcc 0.6444 | ETputs(KTEPS) 177.71
# 1303 MB
# Epoch 00271 | Time(s) 0.0049 | Loss 0.7333 | TrainAcc 0.4000 | ValAcc 0.4667 | ETputs(KTEPS) 177.75
# 1303 MB
# Epoch 00272 | Time(s) 0.0049 | Loss 0.7208 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 177.75
# 1303 MB
# Epoch 00273 | Time(s) 0.0049 | Loss 0.6658 | TrainAcc 0.5778 | ValAcc 0.4667 | ETputs(KTEPS) 177.77
# 1303 MB
# Epoch 00274 | Time(s) 0.0049 | Loss 0.7291 | TrainAcc 0.4667 | ValAcc 0.6444 | ETputs(KTEPS) 177.80
# 1303 MB
# Epoch 00275 | Time(s) 0.0049 | Loss 0.8722 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 177.82
# 1303 MB
# Epoch 00276 | Time(s) 0.0049 | Loss 0.6873 | TrainAcc 0.6222 | ValAcc 0.5333 | ETputs(KTEPS) 177.79
# 1303 MB
# Epoch 00277 | Time(s) 0.0049 | Loss 0.7284 | TrainAcc 0.4667 | ValAcc 0.5333 | ETputs(KTEPS) 177.80
# 1303 MB
# Epoch 00278 | Time(s) 0.0049 | Loss 0.7872 | TrainAcc 0.4667 | ValAcc 0.6889 | ETputs(KTEPS) 177.78
# 1303 MB
# Epoch 00279 | Time(s) 0.0049 | Loss 0.6554 | TrainAcc 0.6444 | ValAcc 0.4667 | ETputs(KTEPS) 177.79
# 1303 MB
# Epoch 00280 | Time(s) 0.0049 | Loss 0.7451 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 177.82
# 1303 MB
# Epoch 00281 | Time(s) 0.0049 | Loss 0.7415 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 177.84
# 1303 MB
# Epoch 00282 | Time(s) 0.0049 | Loss 0.7180 | TrainAcc 0.5556 | ValAcc 0.6889 | ETputs(KTEPS) 177.87
# 1303 MB
# Epoch 00283 | Time(s) 0.0049 | Loss 0.7171 | TrainAcc 0.4444 | ValAcc 0.5333 | ETputs(KTEPS) 177.89
# 1303 MB
# Epoch 00284 | Time(s) 0.0049 | Loss 0.7650 | TrainAcc 0.4667 | ValAcc 0.5333 | ETputs(KTEPS) 177.90
# 1303 MB
# Epoch 00285 | Time(s) 0.0049 | Loss 0.8036 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 177.92
# 1303 MB
# Epoch 00286 | Time(s) 0.0049 | Loss 0.6646 | TrainAcc 0.6444 | ValAcc 0.5333 | ETputs(KTEPS) 177.95
# 1303 MB
# Epoch 00287 | Time(s) 0.0049 | Loss 0.7277 | TrainAcc 0.6222 | ValAcc 0.5333 | ETputs(KTEPS) 177.93
# 1303 MB
# Epoch 00288 | Time(s) 0.0049 | Loss 0.6529 | TrainAcc 0.6889 | ValAcc 0.4667 | ETputs(KTEPS) 177.95
# 1303 MB
# Epoch 00289 | Time(s) 0.0049 | Loss 0.6510 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 177.94
# 1303 MB
# Epoch 00290 | Time(s) 0.0049 | Loss 0.7373 | TrainAcc 0.4222 | ValAcc 0.4667 | ETputs(KTEPS) 177.96
# 1303 MB
# Epoch 00291 | Time(s) 0.0049 | Loss 0.7027 | TrainAcc 0.4667 | ValAcc 0.5333 | ETputs(KTEPS) 177.95
# 1303 MB
# Epoch 00292 | Time(s) 0.0049 | Loss 0.6842 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 177.95
# 1303 MB
# Epoch 00293 | Time(s) 0.0049 | Loss 0.7402 | TrainAcc 0.4444 | ValAcc 0.5333 | ETputs(KTEPS) 177.98
# 1303 MB
# Epoch 00294 | Time(s) 0.0049 | Loss 0.7713 | TrainAcc 0.4000 | ValAcc 0.4667 | ETputs(KTEPS) 177.99
# 1303 MB
# Epoch 00295 | Time(s) 0.0049 | Loss 0.7656 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 177.96
# 1303 MB
# Epoch 00296 | Time(s) 0.0049 | Loss 0.7002 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 177.98
# 1303 MB
# Epoch 00297 | Time(s) 0.0049 | Loss 0.6986 | TrainAcc 0.4000 | ValAcc 0.4667 | ETputs(KTEPS) 177.98
# 1303 MB
# Epoch 00298 | Time(s) 0.0049 | Loss 0.7008 | TrainAcc 0.5556 | ValAcc 0.4222 | ETputs(KTEPS) 177.98
# 1303 MB
# Epoch 00299 | Time(s) 0.0049 | Loss 0.7129 | TrainAcc 0.4444 | ValAcc 0.5333 | ETputs(KTEPS) 177.99
# 1303 MB
# Epoch 00300 | Time(s) 0.0049 | Loss 0.7651 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 177.99
# 1303 MB
# Epoch 00301 | Time(s) 0.0049 | Loss 0.6741 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 177.95
# 1303 MB
# Epoch 00302 | Time(s) 0.0049 | Loss 0.6807 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 177.98
# 1303 MB
# Epoch 00303 | Time(s) 0.0049 | Loss 0.6864 | TrainAcc 0.5778 | ValAcc 0.5333 | ETputs(KTEPS) 177.97
# 1303 MB
# Epoch 00304 | Time(s) 0.0049 | Loss 0.7788 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 177.95
# 1303 MB
# Epoch 00305 | Time(s) 0.0049 | Loss 0.7181 | TrainAcc 0.6000 | ValAcc 0.5333 | ETputs(KTEPS) 177.98
# 1303 MB
# Epoch 00306 | Time(s) 0.0049 | Loss 0.6911 | TrainAcc 0.5556 | ValAcc 0.5333 | ETputs(KTEPS) 178.01
# 1303 MB
# Epoch 00307 | Time(s) 0.0049 | Loss 0.6992 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 178.01
# 1303 MB
# Epoch 00308 | Time(s) 0.0049 | Loss 0.8556 | TrainAcc 0.5333 | ValAcc 0.5333 | ETputs(KTEPS) 178.01
# 1303 MB
# Epoch 00309 | Time(s) 0.0049 | Loss 0.7544 | TrainAcc 0.4667 | ValAcc 0.5333 | ETputs(KTEPS) 178.03
# 1303 MB
# Epoch 00310 | Time(s) 0.0049 | Loss 0.6943 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 178.05
# 1303 MB
# Epoch 00311 | Time(s) 0.0049 | Loss 0.7298 | TrainAcc 0.4000 | ValAcc 0.4667 | ETputs(KTEPS) 178.07
# 1303 MB
# Epoch 00312 | Time(s) 0.0049 | Loss 0.7239 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 178.11
# 1303 MB
# Epoch 00313 | Time(s) 0.0049 | Loss 0.7065 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 178.12
# 1303 MB
# Epoch 00314 | Time(s) 0.0049 | Loss 0.7860 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 178.12
# 1303 MB
# Epoch 00315 | Time(s) 0.0049 | Loss 0.7752 | TrainAcc 0.5333 | ValAcc 0.3778 | ETputs(KTEPS) 178.14
# 1303 MB
# Epoch 00316 | Time(s) 0.0048 | Loss 0.6972 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 178.16
# 1303 MB
# Epoch 00317 | Time(s) 0.0048 | Loss 0.9541 | TrainAcc 0.4222 | ValAcc 0.4667 | ETputs(KTEPS) 178.17
# 1303 MB
# Epoch 00318 | Time(s) 0.0048 | Loss 0.7108 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 178.15
# 1303 MB
# Epoch 00319 | Time(s) 0.0048 | Loss 0.9120 | TrainAcc 0.5778 | ValAcc 0.4667 | ETputs(KTEPS) 178.16
# 1303 MB
# Epoch 00320 | Time(s) 0.0048 | Loss 0.8279 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 178.15
# 1303 MB
# Epoch 00321 | Time(s) 0.0048 | Loss 0.7035 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 178.15
# 1303 MB
# Epoch 00322 | Time(s) 0.0049 | Loss 0.7387 | TrainAcc 0.4889 | ValAcc 0.5333 | ETputs(KTEPS) 178.13
# 1303 MB
# Epoch 00323 | Time(s) 0.0049 | Loss 0.7477 | TrainAcc 0.5111 | ValAcc 0.5333 | ETputs(KTEPS) 178.13
# 1303 MB
# Epoch 00324 | Time(s) 0.0049 | Loss 0.7745 | TrainAcc 0.4667 | ValAcc 0.5333 | ETputs(KTEPS) 178.13
# 1303 MB
# Epoch 00325 | Time(s) 0.0049 | Loss 0.6872 | TrainAcc 0.5556 | ValAcc 0.5333 | ETputs(KTEPS) 178.14
# 1303 MB
# Epoch 00326 | Time(s) 0.0048 | Loss 0.6750 | TrainAcc 0.5556 | ValAcc 0.5778 | ETputs(KTEPS) 178.15
# 1303 MB
# Epoch 00327 | Time(s) 0.0048 | Loss 0.7045 | TrainAcc 0.4222 | ValAcc 0.4667 | ETputs(KTEPS) 178.15
# 1303 MB
# Epoch 00328 | Time(s) 0.0049 | Loss 0.8043 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 178.13
# 1303 MB
# Epoch 00329 | Time(s) 0.0049 | Loss 0.7571 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 178.12
# 1303 MB
# Epoch 00330 | Time(s) 0.0049 | Loss 0.7606 | TrainAcc 0.4222 | ValAcc 0.4667 | ETputs(KTEPS) 178.12
# 1303 MB
# Epoch 00331 | Time(s) 0.0048 | Loss 0.8780 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 178.15
# 1303 MB
# 1303 MB
# Epoch 01373 | Time(s) 0.0048 | Loss 0.7954 | TrainAcc 0.4667 | ValAcc 0.4000 | ETputs(KTEPS) 179.46
# 1303 MB
# Epoch 01374 | Time(s) 0.0048 | Loss 0.6969 | TrainAcc 0.5111 | ValAcc 0.4000 | ETputs(KTEPS) 179.46
# 1303 MB
# Epoch 01375 | Time(s) 0.0048 | Loss 1.4263 | TrainAcc 0.5778 | ValAcc 0.3778 | ETputs(KTEPS) 179.47
# 1303 MB
# Epoch 01376 | Time(s) 0.0048 | Loss 0.6280 | TrainAcc 0.5111 | ValAcc 0.3778 | ETputs(KTEPS) 179.46
# 1303 MB
# Epoch 01377 | Time(s) 0.0048 | Loss 0.7352 | TrainAcc 0.4889 | ValAcc 0.3778 | ETputs(KTEPS) 179.46
# 1303 MB
# Epoch 01378 | Time(s) 0.0048 | Loss 0.7825 | TrainAcc 0.4889 | ValAcc 0.3778 | ETputs(KTEPS) 179.46
# 1303 MB
# Epoch 01379 | Time(s) 0.0048 | Loss 0.7624 | TrainAcc 0.4667 | ValAcc 0.3778 | ETputs(KTEPS) 179.47
# 1303 MB
# Epoch 01380 | Time(s) 0.0048 | Loss 1.8550 | TrainAcc 0.5333 | ValAcc 0.3556 | ETputs(KTEPS) 179.46
# 1303 MB
# Epoch 01381 | Time(s) 0.0048 | Loss 0.6473 | TrainAcc 0.5556 | ValAcc 0.3556 | ETputs(KTEPS) 179.47
# 1303 MB
# Epoch 01382 | Time(s) 0.0048 | Loss 1.7157 | TrainAcc 0.5111 | ValAcc 0.3778 | ETputs(KTEPS) 179.47
# 1303 MB
# Epoch 01383 | Time(s) 0.0048 | Loss 1.0194 | TrainAcc 0.5556 | ValAcc 0.3778 | ETputs(KTEPS) 179.47
# 1303 MB
# Epoch 01384 | Time(s) 0.0048 | Loss 1.1196 | TrainAcc 0.4444 | ValAcc 0.3778 | ETputs(KTEPS) 179.47
# 1303 MB
# Epoch 01385 | Time(s) 0.0048 | Loss 1.0463 | TrainAcc 0.5333 | ValAcc 0.3778 | ETputs(KTEPS) 179.47
# 1303 MB
# Epoch 01386 | Time(s) 0.0048 | Loss 2.0507 | TrainAcc 0.5111 | ValAcc 0.3556 | ETputs(KTEPS) 179.47
# 1303 MB
# Epoch 01387 | Time(s) 0.0048 | Loss 5.6405 | TrainAcc 0.6000 | ValAcc 0.3556 | ETputs(KTEPS) 179.46
# 1303 MB
# Epoch 01388 | Time(s) 0.0048 | Loss 1.3530 | TrainAcc 0.5778 | ValAcc 0.3556 | ETputs(KTEPS) 179.46
# 1303 MB
# Epoch 01389 | Time(s) 0.0048 | Loss 12.8671 | TrainAcc 0.6000 | ValAcc 0.3556 | ETputs(KTEPS) 179.46
# 1303 MB
# Epoch 01390 | Time(s) 0.0048 | Loss 0.6912 | TrainAcc 0.5333 | ValAcc 0.3778 | ETputs(KTEPS) 179.47
# 1303 MB
# 1303 MB
# Epoch 01448 | Time(s) 0.0048 | Loss 0.9654 | TrainAcc 0.3556 | ValAcc 0.4667 | ETputs(KTEPS) 179.54
# 1303 MB
# Epoch 01449 | Time(s) 0.0048 | Loss 0.8632 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 179.54
# 1303 MB
# Epoch 01450 | Time(s) 0.0048 | Loss 3.5433 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 179.54
# 1303 MB
# Epoch 01451 | Time(s) 0.0048 | Loss 0.8378 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 179.54
# 1303 MB
# Epoch 01452 | Time(s) 0.0048 | Loss 0.6588 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 179.54
# 1303 MB
# Epoch 01453 | Time(s) 0.0048 | Loss 0.6816 | TrainAcc 0.6222 | ValAcc 0.4667 | ETputs(KTEPS) 179.54
# 1303 MB
# Epoch 01454 | Time(s) 0.0048 | Loss 1.7685 | TrainAcc 0.5778 | ValAcc 0.4667 | ETputs(KTEPS) 179.55
# 1303 MB
# Epoch 01455 | Time(s) 0.0048 | Loss 0.8246 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 179.53
# 1303 MB
# Epoch 01456 | Time(s) 0.0048 | Loss 0.6923 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 179.54
# 1303 MB
# Epoch 01457 | Time(s) 0.0048 | Loss 17.8205 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 179.54
# 1303 MB
# Epoch 01458 | Time(s) 0.0048 | Loss 0.7706 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 179.54
# 1303 MB
# Epoch 01459 | Time(s) 0.0048 | Loss 1.2468 | TrainAcc 0.3778 | ValAcc 0.4667 | ETputs(KTEPS) 179.53
# 1303 MB
# Epoch 01460 | Time(s) 0.0048 | Loss 0.7252 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 179.53
# 1303 MB
# Epoch 01461 | Time(s) 0.0048 | Loss 5.1359 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 179.53
# 1303 MB
# Epoch 01462 | Time(s) 0.0048 | Loss 0.6935 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 179.53
# 1303 MB
# Epoch 01463 | Time(s) 0.0048 | Loss 0.6956 | TrainAcc 0.3111 | ValAcc 0.4667 | ETputs(KTEPS) 179.54
# 1303 MB
# Epoch 01464 | Time(s) 0.0048 | Loss 8.6928 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 179.54
# 1303 MB
# Epoch 01465 | Time(s) 0.0048 | Loss 1.7048 | TrainAcc 0.4222 | ValAcc 0.4667 | ETputs(KTEPS) 179.53
# 1303 MB
# Epoch 01466 | Time(s) 0.0048 | Loss 0.7196 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 179.52
# 1303 MB
# Epoch 01467 | Time(s) 0.0048 | Loss 1.0879 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 179.52
# 1303 MB
# Epoch 01468 | Time(s) 0.0048 | Loss 0.6638 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 179.53
# 1303 MB
# Epoch 01469 | Time(s) 0.0048 | Loss 1.9694 | TrainAcc 0.4000 | ValAcc 0.4667 | ETputs(KTEPS) 179.53
# 1303 MB
# Epoch 01470 | Time(s) 0.0048 | Loss 0.6749 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 179.53
# 1303 MB
# Epoch 01471 | Time(s) 0.0048 | Loss 0.6923 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 179.54
# 1303 MB
# Epoch 01472 | Time(s) 0.0048 | Loss 1.2880 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 179.53
# 1303 MB
# Epoch 01473 | Time(s) 0.0048 | Loss 1.0251 | TrainAcc 0.5778 | ValAcc 0.4667 | ETputs(KTEPS) 179.54
# 1303 MB
# Epoch 01474 | Time(s) 0.0048 | Loss 0.7561 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 179.54
# 1303 MB
# Epoch 01475 | Time(s) 0.0048 | Loss 0.6932 | TrainAcc 0.5333 | ValAcc 0.4889 | ETputs(KTEPS) 179.54
# 1303 MB
# Epoch 01476 | Time(s) 0.0048 | Loss 0.7001 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 179.54
# 1303 MB
# Epoch 01477 | Time(s) 0.0048 | Loss 7.0124 | TrainAcc 0.4222 | ValAcc 0.4444 | ETputs(KTEPS) 179.53
# 1303 MB
# Epoch 01478 | Time(s) 0.0048 | Loss 4.0515 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 179.54
# 1303 MB
# Epoch 01479 | Time(s) 0.0048 | Loss 0.6897 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 179.53
# 1303 MB
# Epoch 01480 | Time(s) 0.0048 | Loss 0.7632 | TrainAcc 0.4000 | ValAcc 0.4667 | ETputs(KTEPS) 179.53
# 1303 MB
# Epoch 01481 | Time(s) 0.0048 | Loss 0.7423 | TrainAcc 0.3556 | ValAcc 0.4667 | ETputs(KTEPS) 179.52
# 1303 MB
# Epoch 01482 | Time(s) 0.0048 | Loss 0.8577 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 179.52
# 1303 MB
# Epoch 01483 | Time(s) 0.0048 | Loss 0.7525 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 179.52
# 1303 MB
# Epoch 01484 | Time(s) 0.0048 | Loss 0.6883 | TrainAcc 0.4222 | ValAcc 0.4667 | ETputs(KTEPS) 179.52
# 1303 MB
# Epoch 01485 | Time(s) 0.0048 | Loss 0.7198 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 179.53
# 1303 MB
# Epoch 01486 | Time(s) 0.0048 | Loss 0.8719 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 179.53
# 1303 MB
# Epoch 01487 | Time(s) 0.0048 | Loss 1.1040 | TrainAcc 0.3778 | ValAcc 0.4667 | ETputs(KTEPS) 179.52
# 1303 MB
# Epoch 01488 | Time(s) 0.0048 | Loss 12.9523 | TrainAcc 0.4000 | ValAcc 0.4667 | ETputs(KTEPS) 179.52
# 1303 MB
# Epoch 01489 | Time(s) 0.0048 | Loss 0.7042 | TrainAcc 0.4222 | ValAcc 0.4667 | ETputs(KTEPS) 179.51
# 1303 MB
# Epoch 01490 | Time(s) 0.0048 | Loss 1.0459 | TrainAcc 0.5333 | ValAcc 0.4667 | ETputs(KTEPS) 179.52
# 1303 MB
# Epoch 01491 | Time(s) 0.0048 | Loss 1.5420 | TrainAcc 0.3778 | ValAcc 0.4667 | ETputs(KTEPS) 179.53
# 1303 MB
# Epoch 01492 | Time(s) 0.0048 | Loss 1.7877 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 179.53
# 1303 MB
# Epoch 01493 | Time(s) 0.0048 | Loss 0.6871 | TrainAcc 0.5111 | ValAcc 0.4667 | ETputs(KTEPS) 179.52
# 1303 MB
# Epoch 01494 | Time(s) 0.0048 | Loss 9.9908 | TrainAcc 0.4667 | ValAcc 0.4667 | ETputs(KTEPS) 179.52
# 1303 MB
# Epoch 01495 | Time(s) 0.0048 | Loss 10.6670 | TrainAcc 0.6222 | ValAcc 0.4667 | ETputs(KTEPS) 179.53
# 1303 MB
# Epoch 01496 | Time(s) 0.0048 | Loss 0.8354 | TrainAcc 0.4889 | ValAcc 0.4667 | ETputs(KTEPS) 179.52
# 1303 MB
# Epoch 01497 | Time(s) 0.0048 | Loss 74.2840 | TrainAcc 0.4444 | ValAcc 0.4667 | ETputs(KTEPS) 179.52
# 1303 MB
# Epoch 01498 | Time(s) 0.0048 | Loss 0.7080 | TrainAcc 0.5556 | ValAcc 0.4667 | ETputs(KTEPS) 179.53
# 1303 MB
# Epoch 01499 | Time(s) 0.0048 | Loss 0.7987 | TrainAcc 0.6000 | ValAcc 0.4667 | ETputs(KTEPS) 179.53
# Time per epoch:  0.004812587738037109

# %% [markdown]
# Test Model Accuracy

# %%
acc, _ = evaluate(model,features, labels, test_mask, loss_fcn)
print("Test Accuracy {:.4f}".format(acc))
# Out:
# Test Accuracy 0.5333

# %% [markdown]
# Calculating Mean and Standard Deviation

# %%
a= [0.5676,0.2973,0.2973]
mean_a = np.mean(a)
std_dev_a = np.std(a)
print(mean_a, std_dev_a)
# Out:
# 0.38739999999999997 0.12742064196981587

# %%
import sys
from pathlib import Path

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import torch

# Font + global sizing
font_dir = Path.home() / '.local' / 'share' / 'fonts' / 'msttcore'
font_paths = []
if font_dir.exists():
    font_paths = list(font_dir.glob('*.ttf')) + list(font_dir.glob('*.TTF'))
    for font_path in font_paths:
        fm.fontManager.addfont(str(font_path))

font_name = None
if font_paths:
    font_name = fm.FontProperties(fname=str(font_paths[0])).get_name()

if font_name:
    mpl.rcParams['font.family'] = font_name
    mpl.rcParams['font.serif'] = [font_name, 'Times New Roman', 'Times', 'DejaVu Serif']
else:
    mpl.rcParams['font.family'] = 'serif'
    mpl.rcParams['font.serif'] = ['Times New Roman', 'Times', 'DejaVu Serif']

FIGSIZE = (7, 6)
mpl.rcParams['figure.figsize'] = FIGSIZE

root_dir = Path.cwd()
if not (root_dir / 'visualization_utils').exists() and (root_dir.parent / 'visualization_utils').exists():
    sys.path.insert(0, str(root_dir.parent))

from visualization_utils.graph import (
    compute_graph_layout,
    count_edges_with_different_labels,
    plot_graph_two_class,
    visualize_graphs_side_by_side,
)
from visualization_utils.embeddings import (
    extract_embeddings,
    reduce_embeddings_2d,
    plot_embeddings_2d,
)
from visualization_utils.io import ensure_dir, save_figure
from visualization_utils.utils import select_two_classes

# %%
def topk_per_neighbor(edge_index: torch.Tensor,
                      edge_weight: torch.Tensor,
                      frac: float = 0.2,
                      num_nodes: int | None = None,
                      min_k: int = 1) -> torch.Tensor:
    """
    Select top frac of outgoing edges for each source node (row of edge_index),
    based on edge_weight. Returns sampled_edge_index [2, E'].
    """
    assert edge_index.dim() == 2 and edge_index.size(0) == 2
    assert edge_weight.dim() == 1 and edge_weight.numel() == edge_index.size(1)

    row = edge_index[0]
    E = edge_weight.numel()

    if num_nodes is None:
        num_nodes = int(row.max().item()) + 1 if E > 0 else 0

    # degrees per source node
    deg = torch.bincount(row, minlength=num_nodes)  # [N]
    # top-k per node = max(min_k, ceil(frac * deg))
    k = torch.ceil(deg.float() * frac).long().clamp(min=min_k)  # [N]

    # ---- sort edges by (row asc, weight desc within row) ----
    # 1) sort by weight desc
    perm_w = torch.argsort(edge_weight, descending=True)
    row_w = row[perm_w]

    # 2) stable sort by row so weight order is preserved within each row group
    perm_r = torch.argsort(row_w, stable=True)
    perm = perm_w[perm_r]  # final permutation

    row_s = row[perm]

    # position of each edge inside its row-group after sorting (0,1,2,...)
    is_new_group = torch.ones_like(row_s, dtype=torch.bool)
    is_new_group[1:] = row_s[1:] != row_s[:-1]
    group_id = torch.cumsum(is_new_group.long(), dim=0) - 1  # [E], 0..G-1

    # index of first occurrence per group
    first_idx = torch.full((int(group_id.max().item()) + 1,), -1, device=row.device, dtype=torch.long)
    first_idx[group_id[is_new_group]] = torch.nonzero(is_new_group, as_tuple=False).view(-1)

    # pos_in_group = arange(E) - first_idx[group_id]
    ar = torch.arange(row_s.size(0), device=row.device)
    pos_in_group = ar - first_idx[group_id]

    # keep if pos_in_group < k[src_node]
    keep = pos_in_group < k[row_s]

    sampled_edge_index = edge_index[:, perm[keep]]
    return sampled_edge_index


# # ---- usage ----
# edge_index_all, edge_weights = get_sparsegat_edge_weights(model)

# %%
# SparseGAT visualization helpers

def get_sparsegat_edge_weights(model):
    model.eval()
    with torch.no_grad():
        _ = model(features)
    g_local = model.gat_layers[0].g
    att = g_local.edata['a']
    weights = att.view(-1).detach().cpu()
    src, dst = g_local.edges()
    edge_index = torch.stack([src, dst], dim=0).cpu()
    return edge_index, weights


def get_sparsegat_embeddings(model):
    model.eval()
    with torch.no_grad():
        h = features
        edges = "__ALL__"
        h, edges = model.gat_layers[0](h, edges)
        h = model.activation(h.flatten(1))
        for l in range(1, model.num_layers):
            h, _ = model.gat_layers[l](h, edges, skip=1)
            h = model.activation(h.flatten(1))
    return h.detach().cpu()

# Paper-ready figures (SparseGAT)
fig_dir = ensure_dir('KDDFigures')
class_pair = select_two_classes(data.y, None)

edge_index_all, edge_weights = get_sparsegat_edge_weights(model)
# num_edges = edge_weights.numel()
# top_k = max(1, int(0.2 * num_edges))
# top_idx = torch.topk(edge_weights, top_k).indices
# sampled_edge_index = edge_index_all[:, top_idx]

sampled_edge_index = topk_per_neighbor(
    edge_index_all,
    edge_weights,
    frac=0.2,      # top 20% per node
    num_nodes=data.num_nodes,  # recommended if you have it
    min_k=1
)

pos = compute_graph_layout(data, dataset_name=DATASET_NAME, seed=42)

fig_full, ax_full = plt.subplots(figsize=FIGSIZE)
plot_graph_two_class(
    data,
    ax=ax_full,
    pos=pos,
    class_pair=class_pair,
    dataset_name=DATASET_NAME,
#     title='Original dense graph (SparseGAT)',
    node_size=50,
    highlight_colors=('blue', 'red'),
)
save_figure(fig_full, fig_dir / 'SparseGATOriginalGraph.pdf', dpi=300)

fig_sparse, ax_sparse = plt.subplots(figsize=FIGSIZE)
plot_graph_two_class(
    data,
    edge_index=sampled_edge_index,
    ax=ax_sparse,
    pos=pos,
    class_pair=class_pair,
    dataset_name=DATASET_NAME,
#     title='SparseGAT subgraph (top 20%)',
    node_size=50,
    highlight_colors=('blue', 'red'),
)
save_figure(fig_sparse, fig_dir / 'SparseGATSparseGraph.pdf', dpi=300)

embeddings = get_sparsegat_embeddings(model)
emb_2d = reduce_embeddings_2d(embeddings, method='pca', random_state=42)
fig_emb, ax_emb = plt.subplots(figsize=FIGSIZE)
plot_embeddings_2d(
    emb_2d,
    data.y,
    class_pair=class_pair,
    ax=ax_emb,
#     title='SparseGAT embeddings (PCA)',
    highlight_colors=('blue', 'red'),
)
save_figure(fig_emb, fig_dir / 'SparseGATEmbedding.pdf', dpi=300)

plt.show()

# %%
result  = count_edges_with_different_labels(data, sampled_edge_index)
print(f"Original graph: {result['original_graph']['different_label_edges']} edges with different labels "
              f"out of {result['original_graph']['total_edges']} total edges "
              f"(Edge homophily: {100-result['original_graph']['percentage']:.2f}%).")

print(f"Sampled graph: {result['sampled_graph']['different_label_edges']} edges with different labels "
      f"out of {result['sampled_graph']['total_edges']} total edges "
      f"(Edge homophily: {100-result['sampled_graph']['percentage']:.2f}%).")
# Out:
# Original graph: 572 edges with different labels out of 864 total edges (Edge homophily: 33.80%).
# Sampled graph: 205 edges with different labels out of 303 total edges (Edge homophily: 32.34%).
