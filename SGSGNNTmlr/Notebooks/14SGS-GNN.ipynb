# %%
# %pip install torch_geometric
# %pip install ogb
# %pip install pyg_lib torch_scatter torch_sparse torch_cluster torch_spline_conv -f https://data.pyg.org/whl/torch-2.4.0+cu121.html

# %%
import DeviceDir

DIR, RESULTS_DIR = DeviceDir.get_directory()
device, NUM_PROCESSORS = DeviceDir.get_device()

# %%
import os
import torch
import random
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.datasets import Planetoid, Reddit
from torch_geometric.nn import GCNConv
from torch_geometric.loader import ClusterData, ClusterLoader
from sklearn.metrics import f1_score
import numpy as np
import matplotlib.pyplot as plt
import time
from torch_geometric.datasets import WikipediaNetwork
from sklearn.model_selection import train_test_split
from torch_geometric.typing import Adj, SparseTensor
from ogb.nodeproppred import Evaluator, PygNodePropPredDataset
from torch_geometric.utils import scatter
from torch_geometric.datasets import Reddit, Reddit2, Flickr, Yelp, AmazonProducts, PPI,  OGB_MAG,  FakeDataset, Amazon,Coauthor,HeterophilousGraphDataset, CitationFull
from torch_geometric.utils import homophily
from torch_geometric.utils import negative_sampling


def fix_seeds(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

fix_seeds()

# %%
# from torch_geometric.datasets import LINKXDataset
# dataset_name = 'Roman-empire'
# dataset = HeterophilousGraphDataset('/tmp/Cora', DATASET_NAME)
# DATASET_NAME = dataset_name
# data = dataset[0]
# print(data)

# %%
from torch_geometric.datasets import KarateClub, Reddit, Reddit2, Flickr, Yelp, AmazonProducts, PPI,  OGB_MAG,  FakeDataset, Amazon,Coauthor,HeterophilousGraphDataset,LINKXDataset

def load_dataset(dataset_name):
    if dataset_name == "karate":
        dataset = KarateClub()
    elif dataset_name == "moon":
        from ipynb.fs.full.Moon import MoonDataset
        dataset = MoonDataset(n_samples=100, degree=4, train=0.2, h = 0.2)
    elif dataset_name == "SmallCora":
        dataset = Planetoid(root=DIR+'/tmp/Cora', name='Cora')
    elif dataset_name in ["Cora", "Cora_ML" "CiteSeer", "DBLP", "PubMed"]:
        dataset = CitationFull(root=DIR+'/tmp/Citation/'+dataset_name, name=dataset_name)
    elif dataset_name == 'Amazon-ratings':
        dataset = HeterophilousGraphDataset(root=DIR+'/tmp/amazon_ratings', name = dataset_name)
    elif dataset_name == 'Roman-empire':
        from torch_geometric.datasets import LINKXDataset
        dataset = LINKXDataset(DIR+'/tmp/Roman_empire', dataset_name)
    elif dataset_name == "Reddit":
        dataset = Reddit(root=DIR+'/tmp/Reddit')
    elif dataset_name == 'penn94':
        from torch_geometric.datasets import LINKXDataset
        dataset = LINKXDataset(root=DIR+'/tmp/LINKX', name=dataset_name)
    elif dataset_name == 'wiki':
        from torch_geometric.datasets import WikiCS
        dataset = WikiCS(root=DIR+'/tmp/WikiCS')
    elif dataset_name == 'Photo':
        dataset = Amazon(root=DIR+'/tmp/Photo', name='Photo')
    elif dataset_name == 'CiteSeer':
        dataset = Planetoid(root=DIR+'/tmp/CiteSeer', name=DATASET_NAME)
    elif dataset_name == 'CS':
        dataset = Coauthor(root=DIR+'/tmp/CS', name = DATASET_NAME)
    elif dataset_name == 'Physics':
        dataset = Coauthor(root=DIR+'/tmp/Physics', name = DATASET_NAME)
    elif dataset_name == 'Minesweeper':
        dataset   = HeterophilousGraphDataset(root=DIR+'/tmp/Mine',name=dataset_name)
    elif dataset_name == 'pokec':
        print("HELLOWROLD ")
    elif dataset_name == 'ogbn-proteins':
        dataset = PygNodePropPredDataset(name='ogbn-proteins', root=DIR+'/tmp/ogbn-proteins')
        data = dataset[0]
        data.node_species = None
        data.y = data.y.to(torch.float)

        # Initialize features of nodes by aggregating edge features.
        row, col = data.edge_index
        data.x = scatter(data.edge_attr, col, dim_size=data.num_nodes, reduce='sum')
        labels = data.y.argmax(dim=1)
        data.y = labels
        return dataset, data
    elif dataset_name == 'squirrel':
        dataset = WikipediaNetwork(root=DIR+'/tmp/squirrel', name='Squirrel')
    elif dataset_name == 'AmazonProducts':
        dataset = AmazonProducts(root=DIR+'/tmp/AmazonProducts')
    else:
        dataset = Planetoid(root=DIR+'/tmp/Cora', name='Cora')

    print(dataset)
    data = dataset[0]
    print(data)
    return dataset, data

# Example usage
dataset_name = "moon"
DATASET_NAME = dataset_name
dataset, data = load_dataset(dataset_name)
# Out:
# MoonDataset(10)
# Data(x=[100, 2], edge_index=[2, 596], y=[100], train_mask=[100], val_mask=[100], test_mask=[100], edge_weight=[596, 1])

# %%
# dataset_name = 'Roman-empire'
# DATASET_NAME = dataset_name
# dataset   = HeterophilousGraphDataset(root='/tmp/roman',name=dataset_name)
# print(data)

# %%
dataset.num_classes
He = homophily(data.edge_index, data.y, method='edge')
print("Edge Homophily: ", He)
# Out:
# Edge Homophily:  0.3187919557094574

# %%
def train_val_test_mask(data, train=0.4, val=0.3, test=0.3, random_state=False):

    if isinstance(data.x, SparseTensor):
        N = data.x.size(0)
        data.num_nodes = N
    else:
        N = data.x.shape[0]

    indexs = list(range(N))

    if random_state:
        train_index, test_index = train_test_split(indexs, test_size=val+test)
        val_index, test_index = train_test_split(test_index, test_size=test/(val+test))
    else:
        train_index, test_index = train_test_split(indexs, test_size=val+test, random_state=1)
        val_index, test_index = train_test_split(test_index, test_size=test/(val+test), random_state=1)



    train_mask = torch.zeros(N, dtype=bool)
    train_mask[train_index]=True
    val_mask = torch.zeros(N, dtype=bool)
    val_mask[val_index]=True
    test_mask = torch.zeros(N, dtype=bool)
    test_mask[test_index]=True

    data.train_mask = train_mask
    data.val_mask = val_mask
    data.test_mask = test_mask

    return data

# %%
if "val_mask" not in data.__dict__['_store']:    
    data = train_val_test_mask(data, train=0.2, val=0.4, test=0.4)

if len(data.train_mask.shape) > 1:
    split_index = 2
    data.train_mask = data.train_mask[:,split_index]
    data.val_mask = data.val_mask[:,split_index]
    data.test_mask = data.test_mask[:,split_index]

# %%
# Define the MLP for edge probability with dropout
class EdgeProbMLP(nn.Module):
    def __init__(self, in_channels, hidden_dim, dropout_prob=0.5):
        super(EdgeProbMLP, self).__init__()
        self.fc1 = nn.Linear(2 * in_channels, hidden_dim)
        self.dropout = nn.Dropout(dropout_prob)
        self.fc2 = nn.Linear(hidden_dim, 1)

    def forward(self, node_features, edge_index):
        edge_features = torch.cat([node_features[edge_index[0]], node_features[edge_index[1]]], dim=1)
        x = F.relu(self.fc1(edge_features))
        #x = self.dropout(x)
        prob = torch.sigmoid(self.fc2(x))
        return prob

# Define the overall model with Edge Probabilities and GCNConv (GNN) with dropout
class GNNModel(nn.Module):
    def __init__(self, in_channels, hidden_dim, out_channels, num_classes, dropout_prob=0.5):
        super(GNNModel, self).__init__()
        self.edge_prob_mlp = EdgeProbMLP(in_channels, hidden_dim, dropout_prob)
        self.gcn1 = GCNConv(in_channels, hidden_dim)
        self.dropout = nn.Dropout(dropout_prob)
        self.gcn2 = GCNConv(hidden_dim, num_classes)

    def forward(self, data, edge_index, edge_weight=None):
        x = F.relu(self.gcn1(data.x, edge_index, edge_weight))
        #x = self.dropout(x)
        out = self.gcn2(x, edge_index, edge_weight)
        return out

# %%
# Gumbel-Softmax trick for edge sampling
def gumbel_softmax_sampling(edge_probs, edge_index, q=500, temperature=0.5, log=False, istest=False):
        
    if istest:
        samples = F.softmax(edge_probs/temperature, dim=-1)
        top_k_values, sampled_edges = torch.topk(edge_probs, q, dim=-1, largest=True, sorted=True)
    else:
        samples = F.softmax(edge_probs/temperature, dim=-1)
        sampled_edges = torch.multinomial(samples, q, replacement=False) #nothing

#     gumbels = -torch.empty_like(edge_probs).exponential_().log()
#     gumbels = (gumbels - gumbels.min()) / (gumbels.max() - gumbels.min())
#     gumbels = gumbels/10.0

#     logits = (edge_probs + gumbels) / temperature    
#     samples = F.softmax(logits, dim=-1)

#     top_k_values, sampled_edges = torch.topk(samples, q, dim=-1, largest=True, sorted=True) # 50       
#     sampled_edges = torch.multinomial(samples, q, replacement=False)
#     top_k_values, sampled_edges = torch.topk(edge_probs, q, dim=-1, largest=True, sorted=True)    
    
    one_hot = torch.zeros_like(samples)
    one_hot.scatter_(0, sampled_edges, 1.0)     
    
    indexs = (one_hot - samples).detach() + samples
    
#     if log:
#         print("indexs before: ",indexs)
    
    edge_probs = edge_probs*indexs
    
    indexs = indexs.bool()
    
    
#     if log:        
#         print("edge_probs: ",edge_probs)
# #         print("gumbels: ", gumbels)
# #         print("logits: ",logits)
#         print("samples: ",samples)
#         print("sampled_edges: ",sampled_edges)
#         print("One hot: ", one_hot)
#         print("Indexs: ",indexs)
#         print("edge_probs[indexs]:", edge_probs[indexs])

    
    return indexs, edge_probs[indexs]


# Random edge sampling
def random_edge_sampling(edge_index, q):
    num_edges = edge_index.shape[1]
    sampled_indices = torch.randperm(num_edges)[:q]
    sampled_edge_index = edge_index[:, sampled_indices]
    return sampled_edge_index

# F1 score calculation helper
def calculate_f1(logits, labels, mask):
    preds = logits[mask].argmax(dim=1)
    f1 = f1_score(labels[mask].cpu(), preds.cpu(), average='micro')
    return f1

# Training function with alternating updates
def train(epoch, max_epoch, model, optimizer_gnn, optimizer_edge_prob, criterion, cluster_loader, device, q=500, mode='learned', alternate_frequency=1):
    model.train()
    total_loss = 0
    iteration = 0

    for batch in cluster_loader:
        if not batch.train_mask.any():
            continue

        batch = batch.to(device)
        
        if alternate_frequency == 0:
            update_gnn = True
            update_edge_prob = True
        else:            
            # Decide if we are updating GNN or edge probability model
            update_gnn = iteration % alternate_frequency == 0
            update_edge_prob = not update_gnn


        # Zero gradients selectively
        if update_gnn:
            optimizer_gnn.zero_grad()
        if update_edge_prob:
            optimizer_edge_prob.zero_grad()

        # Select edges based on mode
        if mode == 'learned':
            if batch.edge_index.shape[1] > q:
                edge_probs = model.edge_prob_mlp(batch.x, batch.edge_index).squeeze()                    
                temperature = 2.0 - (epoch * (2 - 0.5) / max_epoch)
                #temperature = 10
                #print(temperature)                
                sampled_edge_indices, sampled_edge_weight = gumbel_softmax_sampling(edge_probs, batch.edge_index, q=q, temperature=temperature, log=(epoch==max_epoch-1))
                sampled_edge_index = batch.edge_index[:, sampled_edge_indices]            
                out = model(batch, sampled_edge_index, sampled_edge_weight) 
                #out = model(batch, sampled_edge_index, None)                                        
            else:
                out = model(batch, batch.edge_index)
        elif mode == 'random':
            if batch.edge_index.shape[1] > q:
                sampled_edge_index = random_edge_sampling(batch.edge_index, q=q)
                out = model(batch, sampled_edge_index)
            else:
                out = model(batch, batch.edge_index)
        elif mode == 'full':
            out = model(batch, batch.edge_index)
        else:
            raise ValueError("Invalid mode. Choose 'learned', 'random', or 'full'.")

        # Compute node classification loss
        loss = criterion(out[batch.train_mask], batch.y[batch.train_mask])
        
        if mode == 'learned' and batch.edge_index.shape[1] > q:        
            
            #######---regularizer 1
            edge_labels = torch.full((batch.edge_index.size(1),), -1, dtype=torch.long, device=device)
            train_indices = torch.nonzero(batch.train_mask).squeeze()
            train_edge_mask = torch.isin(batch.edge_index[0], train_indices) & torch.isin(batch.edge_index[1], train_indices)

            # Assign labels based on the class of the endpoints
            same_class_mask = batch.y[batch.edge_index[0]] == batch.y[batch.edge_index[1]]
            edge_labels[train_edge_mask & same_class_mask] = 1
            edge_labels[train_edge_mask & ~same_class_mask] = 0

            # Filter out the edges with labels -1
            valid_edge_mask = edge_labels != -1
            valid_edge_probs = edge_probs[valid_edge_mask]
            valid_edge_labels = edge_labels[valid_edge_mask]
            
            print(torch.sum(valid_edge_labels))
            if torch.sum(valid_edge_labels).item() > 1:            
                loss2 = F.binary_cross_entropy(valid_edge_probs, valid_edge_labels.float().to(device))
            else:
                loss2 = 0
                        
            #### ----regularizer 2
            neg_q = int(torch.sum(valid_edge_labels).item())            
            neg_q = q
            neg_edge_index = negative_sampling(batch.edge_index, num_nodes=batch.num_nodes, num_neg_samples=neg_q)
            neg_edge_probs = model.edge_prob_mlp(batch.x, neg_edge_index).squeeze()
            neg_edge_labels = torch.zeros(neg_q, dtype=torch.float, device=batch.edge_index.device)            
            loss3 = F.binary_cross_entropy(neg_edge_probs, neg_edge_labels)
            
            
            #loss3 = 0
            
            #### ------Total Loss
            
            print("Loss1: ",loss.item(), " Loss2: ",loss2," Loss3: ",loss3)
            
            # Compute the loss using binary cross-entropy
            alpha1 = 1.0 
            alpha2 = 1.0 
            loss = loss + alpha1*loss2 + alpha2*loss3
            
            
            print("Total loss: ",loss.item())
            
        loss.backward()

        # Update parameters selectively
        if update_gnn:
            optimizer_gnn.step()
        if update_edge_prob:
            optimizer_edge_prob.step()

        total_loss += loss.item()
        iteration += 1

    return total_loss / len(cluster_loader)

# Evaluation function remains unchanged
def evaluate(model, cluster_loader, device, q=500, mode=None):
    model.eval()
    total_train_f1, total_val_f1, total_test_f1 = 0, 0, 0
    num_train_examples, num_val_examples, num_test_examples = 0, 0, 0

    with torch.no_grad():
        for batch in cluster_loader:
            batch = batch.to(device)
            if mode == 'learned':
                if batch.edge_index.shape[1] > q:
                    edge_probs = model.edge_prob_mlp(batch.x, batch.edge_index).squeeze()                    
                    sampled_edge_indices, sampled_edge_weight = gumbel_softmax_sampling(edge_probs, batch.edge_index, q=q, istest=True)
                    sampled_edge_index = batch.edge_index[:, sampled_edge_indices]
                    out =model(batch, sampled_edge_index, sampled_edge_weight)                                        
                    #out = model(batch, sampled_edge_index, None)                                        
                else:
                    out = model(batch, batch.edge_index)
            elif mode == 'random':
                if batch.edge_index.shape[1] > q:
                    sampled_edge_index = random_edge_sampling(batch.edge_index, q=q)
                    out = model(batch, sampled_edge_index)
                else:
                    out = model(batch, batch.edge_index)
            elif mode == 'full':
                out = model(batch, batch.edge_index)
            else:
                raise ValueError("Invalid mode. Choose 'learned', 'random', or 'full'.")

            # Calculate F1 scores for train, val, and test sets if masks are present
            if batch.train_mask.any():
                train_f1 = calculate_f1(out, batch.y, batch.train_mask)
                total_train_f1 += train_f1 * batch.train_mask.sum().item()
                num_train_examples += batch.train_mask.sum().item()

            if batch.val_mask.any():
                val_f1 = calculate_f1(out, batch.y, batch.val_mask)
                total_val_f1 += val_f1 * batch.val_mask.sum().item()
                num_val_examples += batch.val_mask.sum().item()

            if batch.test_mask.any():
                test_f1 = calculate_f1(out, batch.y, batch.test_mask)
                total_test_f1 += test_f1 * batch.test_mask.sum().item()
                num_test_examples += batch.test_mask.sum().item()

    avg_train_f1 = total_train_f1 / num_train_examples if num_train_examples > 0 else 0
    avg_val_f1 = total_val_f1 / num_val_examples if num_val_examples > 0 else 0
    avg_test_f1 = total_test_f1 / num_test_examples if num_test_examples > 0 else 0

    return avg_train_f1, avg_val_f1, avg_test_f1

# %%
if "edge_weight" in data.__dict__['_store']:
    print("Edge weights given")
else:
    print("No edge weights")
# Out:
# Edge weights given

# %%
data
# Out:
# Data(x=[100, 2], edge_index=[2, 596], y=[100], train_mask=[100], val_mask=[100], test_mask=[100], edge_weight=[596, 1])

# %%
# from sklearn.decomposition import TruncatedSVD

# def adj_feature(data):    
#     adj_mat = torch.zeros((data.num_nodes,data.num_nodes))
#     edges = data.edge_index.t()
#     adj_mat[edges[:,0], edges[:,1]] = 1
#     adj_mat[edges[:,1], edges[:,0]] = 1
    
# #     return adj_mat
    
# #     n_components = data.x.shape[1]
#     n_components = min(256, data.x.shape[1], data.num_nodes)

#     svd = TruncatedSVD(n_components=n_components)
#     x = svd.fit_transform(adj_mat)
    
#     x = torch.Tensor(x)
#     x.shape    
    
#     return x

# data.x = torch.cat((data.x, adj_feature(data)), dim=1)

# # data.x = adj_feature(data)
# # print(data.x.shape)
# # data.x

# %% [markdown]
# Main for multiple runs

# %%
# data = train_val_test_mask(data, train=0.5, val=0.25, test=0.25)
print(sum(data.train_mask))
data
# Out:
# tensor(20)
# Data(x=[100, 2], edge_index=[2, 596], y=[100], train_mask=[100], val_mask=[100], test_mask=[100], edge_weight=[596, 1])

# %%
# Configuration
RUNS = 1
NUM_EPOCHS = 250
best_test_f1s = []
log = True
mode = 'learned'  # available modes ['learned', 'random', 'full']
alternate_frequency = 0
sample_percent = 0.20
figure_log = False

# Check if partitioning is needed
use_metis = data.edge_index.shape[1]>=500000 # or data.num_nodes >= 20000

if use_metis:
    num_edges_per_partition = 500000
    num_parts = int(np.ceil(data.edge_index.shape[1] / num_edges_per_partition))    

#     num_parts = 1500
#     num_edges_per_partition = int(data.edge_index.shape[1] / num_parts)

    sample_size = int(num_edges_per_partition * sample_percent)
    print("Using METIS with num_parts:", num_parts, "avg edges per partition:", num_edges_per_partition, "sample size:", sample_size)
else:
    print("Graph has fewer than 10,000 nodes; don't do graph partition")
    sample_size = int(data.edge_index.shape[1] * sample_percent)

# Partition data using METIS clustering or load the entire graph as a single batch
if use_metis:
    start = time.time()
    cluster_dir = DIR + 'tmp/' + DATASET_NAME
    if not os.path.exists(cluster_dir):
        os.makedirs(cluster_dir)
    
    cluster_data = ClusterData(data, num_parts=num_parts, recursive=False, save_dir=cluster_dir, log=True)
    print("METIS Partition time:", time.time() - start)
    cluster_loader = ClusterLoader(cluster_data, batch_size=1, shuffle=True)
else:
    cluster_loader = [data]

# Training and evaluation loop
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_save_path = 'best_model.pth'

train_figures = []

for run in range(RUNS):
    print("Run:", run)
    
    train_figures = []

    # Initialize model and optimizers
    model = GNNModel(in_channels=data.x.shape[1], hidden_dim=128, out_channels=64, num_classes=dataset.num_classes).to(device)
    optimizer_gnn = torch.optim.Adam([param for name, param in model.named_parameters() if 'gcn' in name], lr=0.01)
    optimizer_edge_prob = torch.optim.Adam([param for name, param in model.named_parameters() if 'edge_prob_mlp' in name], lr=0.01)
    criterion = nn.CrossEntropyLoss()

    # Initialize F1 score trackers
    train_f1_scores = np.zeros(NUM_EPOCHS)
    val_f1_scores = np.zeros(NUM_EPOCHS)
    test_f1_scores = np.zeros(NUM_EPOCHS)
    best_test_f1 = 0
    best_val_f1 = 0

    # Training over epochs
    for epoch in range(NUM_EPOCHS):
        # Alternate training of GNN and edge probability model based on frequency
        loss = train(
            epoch,
            NUM_EPOCHS,
            model,
            optimizer_gnn,
            optimizer_edge_prob,
            criterion,
            cluster_loader,
            device,
            q=sample_size,
            mode=mode,
            alternate_frequency=alternate_frequency
        )

        # Evaluate model performance on train, validation, and test sets
        train_f1, val_f1, test_f1 = evaluate(model, cluster_loader, device, q=int(sample_size), mode=mode)

        # Store F1 scores
        train_f1_scores[epoch] = train_f1
        val_f1_scores[epoch] = val_f1
        test_f1_scores[epoch] = test_f1

        # Save model if validation F1 improves
        if val_f1 >= best_val_f1:
            best_val_f1 = val_f1
            #best_test_f1 = test_f1
            torch.save(model.state_dict(), model_save_path)
            if log:
                print(f"*Epoch {epoch}, model saved with Loss: {loss:.4f}, Train F1: {train_f1:.4f}, Val F1: {val_f1:.4f}, Test F1: {test_f1:.4f}")

#          #Save model if test F1 improves
        if test_f1 > best_test_f1:
            best_test_f1 = test_f1
#             torch.save(model.state_dict(), model_save_path)
#             if log:
#                 print(f"*Epoch {epoch}, model saved with Train F1: {train_f1:.4f}, Val F1: {val_f1:.4f}, Test F1: {test_f1:.4f}")

        if log and epoch % 100 == 0:
            print(f'Epoch {epoch}, Loss: {loss:.4f}, Train F1: {train_f1:.4f}, Val F1: {val_f1:.4f}, Test F1: {test_f1:.4f}')
            
        if figure_log:
            train_figures.append(visualize(istest=False,show=False))

    # Load the best model for evaluation
    print(f'Best Test F1 throughout: {best_test_f1:.4f}')
    print(f'Loading best model for final evaluation...: {best_val_f1:.4f}')
    model.load_state_dict(torch.load(model_save_path))
    _, _, best_test_f1 = evaluate(model, cluster_loader, device, q=sample_size, mode=mode)
    print(f'Best Test F1 after loading saved model: {best_test_f1:.4f}')
    best_test_f1s.append(best_test_f1)

# Report the mean and standard deviation of the best test F1 scores over runs
print(f'Mean Std of Test F1 Score: {np.mean(best_test_f1s):.4f} +/- {np.std(best_test_f1s):.4f}')
# Out:
# Graph has fewer than 10,000 nodes; don't do graph partition
# Run: 0
# tensor(16, device='cuda:0')
# Loss1:  0.6432573199272156  Loss2:  tensor(0.7419, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.6042, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.9893426895141602
# *Epoch 0, model saved with Loss: 1.9893, Train F1: 0.5500, Val F1: 0.4667, Test F1: 0.5000
# Epoch 0, Loss: 1.9893, Train F1: 0.5500, Val F1: 0.4667, Test F1: 0.5000
# tensor(16, device='cuda:0')
# Loss1:  0.6051350831985474  Loss2:  tensor(0.8798, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3856, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.870539665222168
# *Epoch 1, model saved with Loss: 1.8705, Train F1: 0.7000, Val F1: 0.5667, Test F1: 0.6400
# tensor(16, device='cuda:0')
# Loss1:  0.5771088600158691  Loss2:  tensor(1.0170, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2763, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.8704619407653809
# *Epoch 2, model saved with Loss: 1.8705, Train F1: 0.7500, Val F1: 0.8000, Test F1: 0.6800
# tensor(16, device='cuda:0')
# Loss1:  0.5430677533149719  Loss2:  tensor(1.0592, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2563, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.8585401773452759
# *Epoch 3, model saved with Loss: 1.8585, Train F1: 0.8000, Val F1: 0.8333, Test F1: 0.7400
# tensor(16, device='cuda:0')
# Loss1:  0.5292242169380188  Loss2:  tensor(1.0317, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2595, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.8204240798950195
# *Epoch 4, model saved with Loss: 1.8204, Train F1: 0.7500, Val F1: 0.8333, Test F1: 0.7800
# tensor(16, device='cuda:0')
# Loss1:  0.4893890917301178  Loss2:  tensor(0.9748, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2857, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.7499111890792847
# tensor(16, device='cuda:0')
# Loss1:  0.5406030416488647  Loss2:  tensor(0.9058, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3407, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.7870936393737793
# *Epoch 6, model saved with Loss: 1.7871, Train F1: 0.7500, Val F1: 0.8667, Test F1: 0.7800
# tensor(16, device='cuda:0')
# Loss1:  0.4968200623989105  Loss2:  tensor(0.8600, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3790, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.735860824584961
# *Epoch 7, model saved with Loss: 1.7359, Train F1: 0.8000, Val F1: 0.8667, Test F1: 0.7800
# tensor(16, device='cuda:0')
# Loss1:  0.563708484172821  Loss2:  tensor(0.8360, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3862, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.7858738899230957
# *Epoch 8, model saved with Loss: 1.7859, Train F1: 0.8000, Val F1: 0.9000, Test F1: 0.8000
# tensor(16, device='cuda:0')
# Loss1:  0.45098480582237244  Loss2:  tensor(0.8388, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3748, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.6645152568817139
# *Epoch 9, model saved with Loss: 1.6645, Train F1: 0.7500, Val F1: 0.9000, Test F1: 0.8200
# tensor(16, device='cuda:0')
# Loss1:  0.45146051049232483  Loss2:  tensor(0.8440, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3696, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.665018916130066
# *Epoch 10, model saved with Loss: 1.6650, Train F1: 0.7500, Val F1: 0.9000, Test F1: 0.8200
# tensor(16, device='cuda:0')
# Loss1:  0.5778650641441345  Loss2:  tensor(0.8577, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3598, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.7953516244888306
# *Epoch 11, model saved with Loss: 1.7954, Train F1: 0.8000, Val F1: 0.9000, Test F1: 0.8000
# tensor(16, device='cuda:0')
# Loss1:  0.4183303713798523  Loss2:  tensor(0.8904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3272, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.635875940322876
# tensor(16, device='cuda:0')
# Loss1:  0.4942511022090912  Loss2:  tensor(0.9143, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2997, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.7083195447921753
# tensor(16, device='cuda:0')
# Loss1:  0.5021357536315918  Loss2:  tensor(0.9368, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2844, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.7233526706695557
# *Epoch 14, model saved with Loss: 1.7234, Train F1: 0.8000, Val F1: 0.9000, Test F1: 0.8000
# tensor(16, device='cuda:0')
# Loss1:  0.45973119139671326  Loss2:  tensor(0.9548, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2767, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.6911699771881104
# *Epoch 15, model saved with Loss: 1.6912, Train F1: 0.8000, Val F1: 0.9333, Test F1: 0.8200
# tensor(16, device='cuda:0')
# Loss1:  0.4617306590080261  Loss2:  tensor(0.9583, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2504, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.6704206466674805
# tensor(16, device='cuda:0')
# Loss1:  0.34366506338119507  Loss2:  tensor(0.9416, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2758, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.5610955953598022
# tensor(16, device='cuda:0')
# Loss1:  0.5272432565689087  Loss2:  tensor(0.8921, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2996, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.7189395427703857
# tensor(16, device='cuda:0')
# Loss1:  0.5518087148666382  Loss2:  tensor(0.8419, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3212, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.7149583101272583
# tensor(16, device='cuda:0')
# Loss1:  0.5641534924507141  Loss2:  tensor(0.8120, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3758, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.7519721984863281
# tensor(16, device='cuda:0')
# Loss1:  0.5092678070068359  Loss2:  tensor(0.8065, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3401, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.6558942794799805
# tensor(16, device='cuda:0')
# Loss1:  0.5427379608154297  Loss2:  tensor(0.8173, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3308, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.6908282041549683
# *Epoch 22, model saved with Loss: 1.6908, Train F1: 0.8000, Val F1: 0.9667, Test F1: 0.8000
# tensor(16, device='cuda:0')
# Loss1:  0.46356338262557983  Loss2:  tensor(0.8321, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3140, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.6096707582473755
# *Epoch 23, model saved with Loss: 1.6097, Train F1: 0.8000, Val F1: 0.9667, Test F1: 0.8000
# tensor(16, device='cuda:0')
# Loss1:  0.38846465945243835  Loss2:  tensor(0.8392, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2867, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.514327049255371
# *Epoch 24, model saved with Loss: 1.5143, Train F1: 0.8000, Val F1: 0.9667, Test F1: 0.8400
# tensor(16, device='cuda:0')
# Loss1:  0.47119274735450745  Loss2:  tensor(0.8300, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3110, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.612206220626831
# *Epoch 25, model saved with Loss: 1.6122, Train F1: 0.8000, Val F1: 0.9667, Test F1: 0.8000
# tensor(16, device='cuda:0')
# Loss1:  0.43742936849594116  Loss2:  tensor(0.8206, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3006, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.5586283206939697
# *Epoch 26, model saved with Loss: 1.5586, Train F1: 0.8000, Val F1: 0.9667, Test F1: 0.8200
# tensor(16, device='cuda:0')
# Loss1:  0.36909019947052  Loss2:  tensor(0.8079, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3097, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.4867053031921387
# tensor(16, device='cuda:0')
# Loss1:  0.37589287757873535  Loss2:  tensor(0.7806, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3220, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.478546380996704
# tensor(16, device='cuda:0')
# Loss1:  0.37757351994514465  Loss2:  tensor(0.7495, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3656, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.4926514625549316
# *Epoch 29, model saved with Loss: 1.4927, Train F1: 0.8000, Val F1: 0.9667, Test F1: 0.8200
# tensor(16, device='cuda:0')
# Loss1:  0.3658982813358307  Loss2:  tensor(0.7304, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3780, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.4743030071258545
# *Epoch 30, model saved with Loss: 1.4743, Train F1: 0.8000, Val F1: 0.9667, Test F1: 0.8200
# tensor(16, device='cuda:0')
# Loss1:  0.39570149779319763  Loss2:  tensor(0.7223, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3665, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.4844715595245361
# *Epoch 31, model saved with Loss: 1.4845, Train F1: 0.8000, Val F1: 0.9667, Test F1: 0.8600
# tensor(16, device='cuda:0')
# Loss1:  0.4796290993690491  Loss2:  tensor(0.7207, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3810, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.5812716484069824
# *Epoch 32, model saved with Loss: 1.5813, Train F1: 0.8000, Val F1: 0.9667, Test F1: 0.8600
# tensor(16, device='cuda:0')
# Loss1:  0.35259729623794556  Loss2:  tensor(0.7433, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3158, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.4116610288619995
# *Epoch 33, model saved with Loss: 1.4117, Train F1: 0.8000, Val F1: 0.9667, Test F1: 0.8400
# tensor(16, device='cuda:0')
# Loss1:  0.38026708364486694  Loss2:  tensor(0.7562, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3278, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.4643193483352661
# *Epoch 34, model saved with Loss: 1.4643, Train F1: 0.8000, Val F1: 0.9667, Test F1: 0.8200
# tensor(16, device='cuda:0')
# Loss1:  0.364838182926178  Loss2:  tensor(0.7557, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3132, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.433751106262207
# *Epoch 35, model saved with Loss: 1.4338, Train F1: 0.8000, Val F1: 0.9667, Test F1: 0.8200
# tensor(16, device='cuda:0')
# Loss1:  0.34806472063064575  Loss2:  tensor(0.7435, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3370, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.4285197257995605
# *Epoch 36, model saved with Loss: 1.4285, Train F1: 0.8000, Val F1: 0.9667, Test F1: 0.8400
# tensor(16, device='cuda:0')
# Loss1:  0.319376677274704  Loss2:  tensor(0.7179, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3203, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.3575130701065063
# *Epoch 37, model saved with Loss: 1.3575, Train F1: 0.8500, Val F1: 0.9667, Test F1: 0.8200
# tensor(16, device='cuda:0')
# Loss1:  0.3306502401828766  Loss2:  tensor(0.6810, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3450, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.3566538095474243
# *Epoch 38, model saved with Loss: 1.3567, Train F1: 0.9000, Val F1: 0.9667, Test F1: 0.8200
# tensor(16, device='cuda:0')
# Loss1:  0.3099229335784912  Loss2:  tensor(0.6479, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3625, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.3203057050704956
# *Epoch 39, model saved with Loss: 1.3203, Train F1: 0.9000, Val F1: 0.9667, Test F1: 0.8200
# tensor(16, device='cuda:0')
# Loss1:  0.38187775015830994  Loss2:  tensor(0.6277, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.4150, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.4246429204940796
# *Epoch 40, model saved with Loss: 1.4246, Train F1: 0.8500, Val F1: 0.9667, Test F1: 0.8200
# tensor(16, device='cuda:0')
# Loss1:  0.4417579174041748  Loss2:  tensor(0.6374, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.4248, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.5039336681365967
# *Epoch 41, model saved with Loss: 1.5039, Train F1: 0.8000, Val F1: 0.9667, Test F1: 0.8400
# tensor(16, device='cuda:0')
# Loss1:  0.3759990334510803  Loss2:  tensor(0.6784, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3684, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.4227535724639893
# *Epoch 42, model saved with Loss: 1.4228, Train F1: 0.8000, Val F1: 0.9667, Test F1: 0.8200
# tensor(16, device='cuda:0')
# Loss1:  0.32102683186531067  Loss2:  tensor(0.7294, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3110, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.3614273071289062
# *Epoch 43, model saved with Loss: 1.3614, Train F1: 0.8000, Val F1: 0.9667, Test F1: 0.8200
# tensor(16, device='cuda:0')
# Loss1:  0.3382810056209564  Loss2:  tensor(0.7527, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2734, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.3643677234649658
# *Epoch 44, model saved with Loss: 1.3644, Train F1: 0.8000, Val F1: 0.9667, Test F1: 0.8200
# tensor(16, device='cuda:0')
# Loss1:  0.40121036767959595  Loss2:  tensor(0.7402, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3025, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.4439120292663574
# *Epoch 45, model saved with Loss: 1.4439, Train F1: 0.8000, Val F1: 0.9667, Test F1: 0.8400
# tensor(16, device='cuda:0')
# Loss1:  0.33299511671066284  Loss2:  tensor(0.7181, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2712, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.3222806453704834
# *Epoch 46, model saved with Loss: 1.3223, Train F1: 0.8000, Val F1: 0.9667, Test F1: 0.8400
# tensor(16, device='cuda:0')
# Loss1:  0.3612444996833801  Loss2:  tensor(0.6746, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3049, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.3407039642333984
# *Epoch 47, model saved with Loss: 1.3407, Train F1: 0.9000, Val F1: 0.9667, Test F1: 0.8400
# tensor(16, device='cuda:0')
# Loss1:  0.34283244609832764  Loss2:  tensor(0.6292, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3465, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.318488359451294
# *Epoch 48, model saved with Loss: 1.3185, Train F1: 0.9000, Val F1: 0.9667, Test F1: 0.8400
# tensor(16, device='cuda:0')
# Loss1:  0.33894655108451843  Loss2:  tensor(0.6059, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.4106, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.355474829673767
# *Epoch 49, model saved with Loss: 1.3555, Train F1: 0.9000, Val F1: 0.9667, Test F1: 0.8400
# tensor(16, device='cuda:0')
# Loss1:  0.2998789846897125  Loss2:  tensor(0.6035, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3847, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.2880935668945312
# *Epoch 50, model saved with Loss: 1.2881, Train F1: 0.9000, Val F1: 0.9667, Test F1: 0.8400
# tensor(16, device='cuda:0')
# Loss1:  0.3195172846317291  Loss2:  tensor(0.6159, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2668, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.2022565603256226
# *Epoch 51, model saved with Loss: 1.2023, Train F1: 0.9000, Val F1: 0.9667, Test F1: 0.8400
# tensor(16, device='cuda:0')
# Loss1:  0.3365846574306488  Loss2:  tensor(0.6180, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3415, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.296118974685669
# *Epoch 52, model saved with Loss: 1.2961, Train F1: 0.9000, Val F1: 0.9667, Test F1: 0.8400
# tensor(16, device='cuda:0')
# Loss1:  0.32251283526420593  Loss2:  tensor(0.6306, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3991, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.3522168397903442
# *Epoch 53, model saved with Loss: 1.3522, Train F1: 0.9000, Val F1: 0.9667, Test F1: 0.8600
# tensor(16, device='cuda:0')
# Loss1:  0.38359972834587097  Loss2:  tensor(0.6583, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3182, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.3601106405258179
# *Epoch 54, model saved with Loss: 1.3601, Train F1: 0.9000, Val F1: 0.9667, Test F1: 0.8400
# tensor(16, device='cuda:0')
# Loss1:  0.3521440625190735  Loss2:  tensor(0.6822, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2543, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.288650393486023
# *Epoch 55, model saved with Loss: 1.2887, Train F1: 0.9000, Val F1: 0.9667, Test F1: 0.8200
# tensor(16, device='cuda:0')
# Loss1:  0.2976435422897339  Loss2:  tensor(0.6764, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3076, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.2816365957260132
# tensor(16, device='cuda:0')
# Loss1:  0.3282652497291565  Loss2:  tensor(0.6432, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3109, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.2823017835617065
# tensor(16, device='cuda:0')
# Loss1:  0.2912892699241638  Loss2:  tensor(0.6080, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3500, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.2492728233337402
# *Epoch 58, model saved with Loss: 1.2493, Train F1: 0.9000, Val F1: 0.9667, Test F1: 0.8200
# tensor(16, device='cuda:0')
# Loss1:  0.40422430634498596  Loss2:  tensor(0.5792, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3821, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.3655143976211548
# *Epoch 59, model saved with Loss: 1.3655, Train F1: 0.9000, Val F1: 0.9667, Test F1: 0.8600
# tensor(16, device='cuda:0')
# Loss1:  0.2039082795381546  Loss2:  tensor(0.5954, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2986, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.0979418754577637
# *Epoch 60, model saved with Loss: 1.0979, Train F1: 0.9000, Val F1: 0.9667, Test F1: 0.8800
# tensor(16, device='cuda:0')
# Loss1:  0.3554559648036957  Loss2:  tensor(0.5841, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3456, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.2852040529251099
# *Epoch 61, model saved with Loss: 1.2852, Train F1: 0.9000, Val F1: 0.9667, Test F1: 0.8400
# tensor(16, device='cuda:0')
# Loss1:  0.3452839255332947  Loss2:  tensor(0.5913, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3290, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.2655830383300781
# *Epoch 62, model saved with Loss: 1.2656, Train F1: 0.9000, Val F1: 0.9667, Test F1: 0.8400
# tensor(16, device='cuda:0')
# Loss1:  0.3083268702030182  Loss2:  tensor(0.6082, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3518, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.2683509588241577
# *Epoch 63, model saved with Loss: 1.2684, Train F1: 0.9000, Val F1: 0.9667, Test F1: 0.8800
# tensor(16, device='cuda:0')
# Loss1:  0.27129119634628296  Loss2:  tensor(0.6196, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2967, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.1876106262207031
# tensor(16, device='cuda:0')
# Loss1:  0.3010883927345276  Loss2:  tensor(0.6074, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3380, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.2465033531188965
# tensor(16, device='cuda:0')
# Loss1:  0.26630645990371704  Loss2:  tensor(0.5892, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3424, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.1979072093963623
# tensor(16, device='cuda:0')
# Loss1:  0.2465856969356537  Loss2:  tensor(0.5743, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3216, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.1425271034240723
# tensor(16, device='cuda:0')
# Loss1:  0.22004885971546173  Loss2:  tensor(0.5620, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3157, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.0977411270141602
# *Epoch 68, model saved with Loss: 1.0977, Train F1: 0.9000, Val F1: 0.9667, Test F1: 0.8400
# tensor(16, device='cuda:0')
# Loss1:  0.2595813572406769  Loss2:  tensor(0.5438, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3950, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.1983616352081299
# *Epoch 69, model saved with Loss: 1.1984, Train F1: 0.9000, Val F1: 0.9667, Test F1: 0.8600
# tensor(16, device='cuda:0')
# Loss1:  0.3451439440250397  Loss2:  tensor(0.5520, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3614, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.2585413455963135
# *Epoch 70, model saved with Loss: 1.2585, Train F1: 0.9000, Val F1: 0.9667, Test F1: 0.8400
# tensor(16, device='cuda:0')
# Loss1:  0.3057365417480469  Loss2:  tensor(0.5880, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2922, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.1859439611434937
# *Epoch 71, model saved with Loss: 1.1859, Train F1: 0.9000, Val F1: 0.9667, Test F1: 0.8400
# tensor(16, device='cuda:0')
# Loss1:  0.21791262924671173  Loss2:  tensor(0.6057, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3162, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.1398135423660278
# tensor(16, device='cuda:0')
# Loss1:  0.24958519637584686  Loss2:  tensor(0.5898, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2710, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.1104060411453247
# tensor(16, device='cuda:0')
# Loss1:  0.1682378351688385  Loss2:  tensor(0.5460, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2905, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.0047261714935303
# tensor(16, device='cuda:0')
# Loss1:  0.3077714741230011  Loss2:  tensor(0.4836, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3924, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.1838181018829346
# tensor(16, device='cuda:0')
# Loss1:  0.3112143278121948  Loss2:  tensor(0.4696, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3598, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.1406221389770508
# tensor(16, device='cuda:0')
# Loss1:  0.2771405577659607  Loss2:  tensor(0.4914, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3800, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.1485357284545898
# tensor(16, device='cuda:0')
# Loss1:  0.2994871437549591  Loss2:  tensor(0.5457, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3017, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.1468850374221802
# tensor(16, device='cuda:0')
# Loss1:  0.2169792354106903  Loss2:  tensor(0.6014, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2700, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.0883549451828003
# tensor(16, device='cuda:0')
# Loss1:  0.22653000056743622  Loss2:  tensor(0.6186, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3050, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.1500864028930664
# *Epoch 80, model saved with Loss: 1.1501, Train F1: 0.9000, Val F1: 0.9667, Test F1: 0.8600
# tensor(16, device='cuda:0')
# Loss1:  0.2340390980243683  Loss2:  tensor(0.5951, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2863, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.1154191493988037
# *Epoch 81, model saved with Loss: 1.1154, Train F1: 0.9000, Val F1: 0.9667, Test F1: 0.8600
# tensor(16, device='cuda:0')
# Loss1:  0.28344470262527466  Loss2:  tensor(0.5346, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2968, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.1148467063903809
# tensor(16, device='cuda:0')
# Loss1:  0.35064274072647095  Loss2:  tensor(0.4860, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3650, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.2016371488571167
# tensor(16, device='cuda:0')
# Loss1:  0.40849924087524414  Loss2:  tensor(0.4873, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3588, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.2545814514160156
# tensor(16, device='cuda:0')
# Loss1:  0.20957450568675995  Loss2:  tensor(0.5481, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2612, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.0189018249511719
# tensor(16, device='cuda:0')
# Loss1:  0.3163136839866638  Loss2:  tensor(0.5818, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3516, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.249739170074463
# tensor(16, device='cuda:0')
# Loss1:  0.30743303894996643  Loss2:  tensor(0.6025, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2399, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.1498174667358398
# tensor(16, device='cuda:0')
# Loss1:  0.18528679013252258  Loss2:  tensor(0.6104, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2444, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.040050983428955
# tensor(16, device='cuda:0')
# Loss1:  0.271329790353775  Loss2:  tensor(0.5502, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2666, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.0881099700927734
# tensor(16, device='cuda:0')
# Loss1:  0.20738033950328827  Loss2:  tensor(0.4936, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3574, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.0583696365356445
# tensor(16, device='cuda:0')
# Loss1:  0.2734295725822449  Loss2:  tensor(0.4551, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3649, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.0933743715286255
# tensor(16, device='cuda:0')
# Loss1:  0.1812952607870102  Loss2:  tensor(0.4485, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3695, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.9992377161979675
# tensor(16, device='cuda:0')
# Loss1:  0.22766199707984924  Loss2:  tensor(0.4543, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3361, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.0180974006652832
# tensor(16, device='cuda:0')
# Loss1:  0.2254006415605545  Loss2:  tensor(0.4737, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2779, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.9769517183303833
# tensor(16, device='cuda:0')
# Loss1:  0.25239238142967224  Loss2:  tensor(0.5044, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3441, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.1008504629135132
# tensor(16, device='cuda:0')
# Loss1:  0.26018431782722473  Loss2:  tensor(0.5384, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2881, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.0866832733154297
# tensor(16, device='cuda:0')
# Loss1:  0.2212236374616623  Loss2:  tensor(0.5444, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2534, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.019099473953247
# tensor(16, device='cuda:0')
# Loss1:  0.21447663009166718  Loss2:  tensor(0.5169, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2544, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.9858012199401855
# tensor(16, device='cuda:0')
# Loss1:  0.18393860757350922  Loss2:  tensor(0.4567, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2933, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.9339443445205688
# tensor(16, device='cuda:0')
# Loss1:  0.21854475140571594  Loss2:  tensor(0.3997, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3733, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.9915969371795654
# Epoch 100, Loss: 0.9916, Train F1: 0.9000, Val F1: 0.9000, Test F1: 0.8200
# tensor(16, device='cuda:0')
# Loss1:  0.27928879857063293  Loss2:  tensor(0.3853, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.4191, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.083707332611084
# tensor(16, device='cuda:0')
# Loss1:  0.24677486717700958  Loss2:  tensor(0.4156, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.4104, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.0728431940078735
# tensor(16, device='cuda:0')
# Loss1:  0.2589062452316284  Loss2:  tensor(0.4943, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2792, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.0324922800064087
# tensor(16, device='cuda:0')
# Loss1:  0.14973632991313934  Loss2:  tensor(0.5586, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2076, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.9159851670265198
# tensor(16, device='cuda:0')
# Loss1:  0.33277732133865356  Loss2:  tensor(0.5377, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2137, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.0842009782791138
# tensor(16, device='cuda:0')
# Loss1:  0.2124287188053131  Loss2:  tensor(0.5053, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2677, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.9854148626327515
# tensor(16, device='cuda:0')
# Loss1:  0.2245548963546753  Loss2:  tensor(0.4530, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3265, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.0041117668151855
# tensor(16, device='cuda:0')
# Loss1:  0.14799800515174866  Loss2:  tensor(0.4321, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2907, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.8707953095436096
# tensor(16, device='cuda:0')
# Loss1:  0.28083544969558716  Loss2:  tensor(0.4107, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3845, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.075955867767334
# tensor(16, device='cuda:0')
# Loss1:  0.2312609851360321  Loss2:  tensor(0.4360, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3178, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.9850674867630005
# tensor(16, device='cuda:0')
# Loss1:  0.23891660571098328  Loss2:  tensor(0.4840, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2931, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.0160284042358398
# tensor(16, device='cuda:0')
# Loss1:  0.22489860653877258  Loss2:  tensor(0.5159, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2709, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.0116961002349854
# tensor(16, device='cuda:0')
# Loss1:  0.1988908350467682  Loss2:  tensor(0.5060, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2804, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.9852838516235352
# tensor(16, device='cuda:0')
# Loss1:  0.20592465996742249  Loss2:  tensor(0.4802, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2713, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.9574312567710876
# tensor(16, device='cuda:0')
# Loss1:  0.1836325228214264  Loss2:  tensor(0.4254, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3547, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.9637627005577087
# tensor(16, device='cuda:0')
# Loss1:  0.19221965968608856  Loss2:  tensor(0.3927, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3521, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.9369508028030396
# tensor(16, device='cuda:0')
# Loss1:  0.26255232095718384  Loss2:  tensor(0.3757, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3627, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.0009896755218506
# tensor(16, device='cuda:0')
# Loss1:  0.23621352016925812  Loss2:  tensor(0.4016, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3566, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.9944226741790771
# tensor(16, device='cuda:0')
# Loss1:  0.26908668875694275  Loss2:  tensor(0.4593, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2175, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.9459103345870972
# tensor(16, device='cuda:0')
# Loss1:  0.17854954302310944  Loss2:  tensor(0.5085, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2363, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.9233433604240417
# tensor(16, device='cuda:0')
# Loss1:  0.15189138054847717  Loss2:  tensor(0.5075, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2523, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.9117120504379272
# tensor(16, device='cuda:0')
# Loss1:  0.2137308120727539  Loss2:  tensor(0.4539, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2472, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.9148082137107849
# tensor(16, device='cuda:0')
# Loss1:  0.3006192147731781  Loss2:  tensor(0.3943, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2963, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.9912111163139343
# tensor(16, device='cuda:0')
# Loss1:  0.2918481230735779  Loss2:  tensor(0.3813, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3234, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.996559739112854
# tensor(16, device='cuda:0')
# Loss1:  0.19436894357204437  Loss2:  tensor(0.3970, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3083, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.8996832966804504
# tensor(16, device='cuda:0')
# Loss1:  0.13841716945171356  Loss2:  tensor(0.4339, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2410, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.8133378028869629
# tensor(16, device='cuda:0')
# Loss1:  0.2166881114244461  Loss2:  tensor(0.4469, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3100, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.9734989404678345
# tensor(16, device='cuda:0')
# Loss1:  0.11107586324214935  Loss2:  tensor(0.4683, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2626, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.8418869972229004
# tensor(16, device='cuda:0')
# Loss1:  0.17971405386924744  Loss2:  tensor(0.4496, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2497, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.8790465593338013
# tensor(16, device='cuda:0')
# Loss1:  0.1495995819568634  Loss2:  tensor(0.4103, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2683, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.8282127380371094
# tensor(16, device='cuda:0')
# Loss1:  0.2434695065021515  Loss2:  tensor(0.3711, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3584, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.9729881882667542
# tensor(16, device='cuda:0')
# Loss1:  0.1433996856212616  Loss2:  tensor(0.3632, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3786, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.8851715326309204
# tensor(16, device='cuda:0')
# Loss1:  0.20102417469024658  Loss2:  tensor(0.3704, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3654, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.9368395805358887
# tensor(16, device='cuda:0')
# Loss1:  0.16482001543045044  Loss2:  tensor(0.3764, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3258, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.8669784069061279
# tensor(16, device='cuda:0')
# Loss1:  0.1889914572238922  Loss2:  tensor(0.3888, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2949, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.8727329969406128
# tensor(16, device='cuda:0')
# Loss1:  0.19665594398975372  Loss2:  tensor(0.4111, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2011, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.8088492155075073
# tensor(16, device='cuda:0')
# Loss1:  0.20975258946418762  Loss2:  tensor(0.4213, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2265, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.8575762510299683
# tensor(16, device='cuda:0')
# Loss1:  0.12908923625946045  Loss2:  tensor(0.4100, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3002, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.839340090751648
# tensor(16, device='cuda:0')
# Loss1:  0.27238360047340393  Loss2:  tensor(0.3860, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2854, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.9437863826751709
# tensor(16, device='cuda:0')
# Loss1:  0.33304309844970703  Loss2:  tensor(0.3864, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2879, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  1.0073636770248413
# tensor(16, device='cuda:0')
# Loss1:  0.16745145618915558  Loss2:  tensor(0.4115, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3010, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.8799208402633667
# tensor(16, device='cuda:0')
# Loss1:  0.15180319547653198  Loss2:  tensor(0.4318, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3017, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.8852521777153015
# tensor(16, device='cuda:0')
# Loss1:  0.15016427636146545  Loss2:  tensor(0.4376, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2713, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.8590238094329834
# tensor(16, device='cuda:0')
# Loss1:  0.14066407084465027  Loss2:  tensor(0.4106, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2586, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.809808611869812
# tensor(16, device='cuda:0')
# Loss1:  0.22364142537117004  Loss2:  tensor(0.3543, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2354, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.8133476972579956
# tensor(16, device='cuda:0')
# Loss1:  0.1398986428976059  Loss2:  tensor(0.3050, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3633, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.8081479072570801
# tensor(16, device='cuda:0')
# Loss1:  0.1942043900489807  Loss2:  tensor(0.2926, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3561, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.8428850173950195
# tensor(16, device='cuda:0')
# Loss1:  0.17872896790504456  Loss2:  tensor(0.3230, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3608, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.8625754117965698
# tensor(16, device='cuda:0')
# Loss1:  0.18884602189064026  Loss2:  tensor(0.3931, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2882, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.8701010346412659
# tensor(16, device='cuda:0')
# Loss1:  0.18184569478034973  Loss2:  tensor(0.4570, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2276, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.866402804851532
# tensor(16, device='cuda:0')
# Loss1:  0.21068783104419708  Loss2:  tensor(0.4746, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2286, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.9139041900634766
# tensor(16, device='cuda:0')
# Loss1:  0.2053993195295334  Loss2:  tensor(0.4524, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2406, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.8983950614929199
# tensor(16, device='cuda:0')
# Loss1:  0.12396128475666046  Loss2:  tensor(0.4112, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2674, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.8025774955749512
# tensor(16, device='cuda:0')
# Loss1:  0.12640120089054108  Loss2:  tensor(0.3522, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2871, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7656689882278442
# tensor(16, device='cuda:0')
# Loss1:  0.1804574877023697  Loss2:  tensor(0.3011, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3471, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.8286947011947632
# tensor(16, device='cuda:0')
# Loss1:  0.16572900116443634  Loss2:  tensor(0.2930, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3430, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.801723837852478
# tensor(16, device='cuda:0')
# Loss1:  0.11498603969812393  Loss2:  tensor(0.3058, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3359, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7566884756088257
# tensor(16, device='cuda:0')
# Loss1:  0.14280331134796143  Loss2:  tensor(0.3374, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3509, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.8311392068862915
# tensor(16, device='cuda:0')
# Loss1:  0.2116169035434723  Loss2:  tensor(0.3947, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2384, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.8447412848472595
# tensor(16, device='cuda:0')
# Loss1:  0.17284244298934937  Loss2:  tensor(0.4330, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.1833, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7891272306442261
# tensor(16, device='cuda:0')
# Loss1:  0.20392374694347382  Loss2:  tensor(0.4112, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2338, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.8488883972167969
# tensor(16, device='cuda:0')
# Loss1:  0.20682771503925323  Loss2:  tensor(0.3666, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2488, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.822272539138794
# tensor(16, device='cuda:0')
# Loss1:  0.1507767289876938  Loss2:  tensor(0.3124, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3249, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7880874872207642
# tensor(16, device='cuda:0')
# Loss1:  0.23649676144123077  Loss2:  tensor(0.2820, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2911, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.8095702528953552
# tensor(16, device='cuda:0')
# Loss1:  0.15467968583106995  Loss2:  tensor(0.2858, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3208, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7613579034805298
# tensor(16, device='cuda:0')
# Loss1:  0.2620682418346405  Loss2:  tensor(0.3221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2598, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.8439249396324158
# tensor(16, device='cuda:0')
# Loss1:  0.1341807097196579  Loss2:  tensor(0.3972, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2035, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7349071502685547
# tensor(16, device='cuda:0')
# Loss1:  0.0939917117357254  Loss2:  tensor(0.4262, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2109, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7310709357261658
# tensor(16, device='cuda:0')
# Loss1:  0.11856943368911743  Loss2:  tensor(0.3917, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2820, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.792249858379364
# tensor(16, device='cuda:0')
# Loss1:  0.15107408165931702  Loss2:  tensor(0.3324, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2426, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7260575294494629
# tensor(16, device='cuda:0')
# Loss1:  0.2042386829853058  Loss2:  tensor(0.2832, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3805, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.8679059743881226
# ...
# Total loss:  0.7298551201820374
# tensor(16, device='cuda:0')
# Loss1:  0.12652096152305603  Loss2:  tensor(0.3347, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2796, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7407586574554443
# tensor(16, device='cuda:0')
# Loss1:  0.11118189990520477  Loss2:  tensor(0.2960, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3056, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7128315567970276
# tensor(16, device='cuda:0')
# Loss1:  0.20211565494537354  Loss2:  tensor(0.2769, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3422, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.821265697479248
# tensor(16, device='cuda:0')
# Loss1:  0.13547880947589874  Loss2:  tensor(0.2862, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2749, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.6965131163597107
# tensor(16, device='cuda:0')
# Loss1:  0.12900835275650024  Loss2:  tensor(0.2976, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3590, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7856447100639343
# tensor(16, device='cuda:0')
# Loss1:  0.16618621349334717  Loss2:  tensor(0.3348, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2368, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7378106117248535
# tensor(16, device='cuda:0')
# Loss1:  0.10953310877084732  Loss2:  tensor(0.3652, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.1980, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.6728063821792603
# tensor(16, device='cuda:0')
# Loss1:  0.12475623935461044  Loss2:  tensor(0.3542, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2726, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7515209913253784
# tensor(16, device='cuda:0')
# Loss1:  0.09774557501077652  Loss2:  tensor(0.3262, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2779, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7018571496009827
# tensor(16, device='cuda:0')
# Loss1:  0.10195060819387436  Loss2:  tensor(0.2855, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3484, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7357896566390991
# tensor(16, device='cuda:0')
# Loss1:  0.162116140127182  Loss2:  tensor(0.2643, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3576, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7839655876159668
# tensor(16, device='cuda:0')
# Loss1:  0.1962193250656128  Loss2:  tensor(0.2746, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2734, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7442772388458252
# tensor(16, device='cuda:0')
# Loss1:  0.139394611120224  Loss2:  tensor(0.3184, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3135, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7712731957435608
# tensor(16, device='cuda:0')
# Loss1:  0.08382562547922134  Loss2:  tensor(0.3623, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2988, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7449569702148438
# Epoch 200, Loss: 0.7450, Train F1: 1.0000, Val F1: 0.9333, Test F1: 0.7800
# tensor(16, device='cuda:0')
# Loss1:  0.11259511858224869  Loss2:  tensor(0.3640, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2417, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7183062434196472
# tensor(16, device='cuda:0')
# Loss1:  0.11003339290618896  Loss2:  tensor(0.3181, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2789, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7069768905639648
# tensor(16, device='cuda:0')
# Loss1:  0.11614938825368881  Loss2:  tensor(0.2690, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2501, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.6352203488349915
# tensor(16, device='cuda:0')
# Loss1:  0.07392793893814087  Loss2:  tensor(0.2358, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3499, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.6595866084098816
# tensor(16, device='cuda:0')
# Loss1:  0.08617658168077469  Loss2:  tensor(0.2272, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3631, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.6764578819274902
# tensor(16, device='cuda:0')
# Loss1:  0.2012234628200531  Loss2:  tensor(0.2483, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.4364, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.8859505653381348
# tensor(16, device='cuda:0')
# Loss1:  0.12364218384027481  Loss2:  tensor(0.3454, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2411, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7101823091506958
# tensor(16, device='cuda:0')
# Loss1:  0.15123674273490906  Loss2:  tensor(0.4281, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.1760, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7553192973136902
# tensor(16, device='cuda:0')
# Loss1:  0.1182345300912857  Loss2:  tensor(0.4287, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2055, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7523572444915771
# tensor(16, device='cuda:0')
# Loss1:  0.11160717159509659  Loss2:  tensor(0.3674, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2276, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7066224813461304
# tensor(16, device='cuda:0')
# Loss1:  0.15381786227226257  Loss2:  tensor(0.2866, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2993, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7396904826164246
# tensor(16, device='cuda:0')
# Loss1:  0.15143755078315735  Loss2:  tensor(0.2468, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2475, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.6457130312919617
# tensor(16, device='cuda:0')
# Loss1:  0.16410234570503235  Loss2:  tensor(0.2374, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3727, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7742298245429993
# tensor(16, device='cuda:0')
# Loss1:  0.14544570446014404  Loss2:  tensor(0.2666, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3842, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.79625403881073
# tensor(16, device='cuda:0')
# Loss1:  0.11160878837108612  Loss2:  tensor(0.3197, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2946, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.725997805595398
# tensor(16, device='cuda:0')
# Loss1:  0.08156745135784149  Loss2:  tensor(0.3785, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2336, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.6935765147209167
# tensor(16, device='cuda:0')
# Loss1:  0.06477086246013641  Loss2:  tensor(0.3806, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2120, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.6573041081428528
# tensor(16, device='cuda:0')
# Loss1:  0.14103412628173828  Loss2:  tensor(0.3111, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2238, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.675958514213562
# tensor(16, device='cuda:0')
# Loss1:  0.08778059482574463  Loss2:  tensor(0.2335, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.5187, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.8400179147720337
# tensor(16, device='cuda:0')
# Loss1:  0.15298575162887573  Loss2:  tensor(0.2108, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3905, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7542877793312073
# tensor(16, device='cuda:0')
# Loss1:  0.12870335578918457  Loss2:  tensor(0.2286, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.4018, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7591005563735962
# tensor(16, device='cuda:0')
# Loss1:  0.059427570551633835  Loss2:  tensor(0.2789, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.5604410171508789
# tensor(16, device='cuda:0')
# Loss1:  0.10681947320699692  Loss2:  tensor(0.3183, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2360, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.6611744165420532
# tensor(16, device='cuda:0')
# Loss1:  0.10627547651529312  Loss2:  tensor(0.3405, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2691, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7158488035202026
# tensor(16, device='cuda:0')
# Loss1:  0.15842363238334656  Loss2:  tensor(0.3309, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3013, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7906284332275391
# tensor(16, device='cuda:0')
# Loss1:  0.1301492601633072  Loss2:  tensor(0.3171, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2392, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.6865001916885376
# tensor(16, device='cuda:0')
# Loss1:  0.13394424319267273  Loss2:  tensor(0.2967, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2585, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.6891136169433594
# tensor(16, device='cuda:0')
# Loss1:  0.14373330771923065  Loss2:  tensor(0.2773, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3214, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7423843741416931
# tensor(16, device='cuda:0')
# Loss1:  0.12205840647220612  Loss2:  tensor(0.2756, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2375, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.6351374983787537
# tensor(16, device='cuda:0')
# Loss1:  0.1263734996318817  Loss2:  tensor(0.2737, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2867, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.68675696849823
# tensor(16, device='cuda:0')
# Loss1:  0.08541999012231827  Loss2:  tensor(0.2710, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2572, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.6136637926101685
# tensor(16, device='cuda:0')
# Loss1:  0.11997520923614502  Loss2:  tensor(0.2556, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2933, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.6689168810844421
# tensor(16, device='cuda:0')
# Loss1:  0.09683661162853241  Loss2:  tensor(0.2429, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3765, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7162523865699768
# tensor(16, device='cuda:0')
# Loss1:  0.14189346134662628  Loss2:  tensor(0.2347, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3078, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.6843703985214233
# tensor(16, device='cuda:0')
# Loss1:  0.15292100608348846  Loss2:  tensor(0.2559, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2775, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.6863504648208618
# tensor(16, device='cuda:0')
# Loss1:  0.11917012929916382  Loss2:  tensor(0.2931, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2078, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.6200675964355469
# tensor(16, device='cuda:0')
# Loss1:  0.1827206164598465  Loss2:  tensor(0.3110, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2240, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.717776358127594
# tensor(16, device='cuda:0')
# Loss1:  0.1539396345615387  Loss2:  tensor(0.3213, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2630, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7382190823554993
# tensor(16, device='cuda:0')
# Loss1:  0.10796427726745605  Loss2:  tensor(0.3104, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2300, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.6483989357948303
# tensor(16, device='cuda:0')
# Loss1:  0.1084412932395935  Loss2:  tensor(0.2863, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2637, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.6584720611572266
# tensor(16, device='cuda:0')
# Loss1:  0.11938577890396118  Loss2:  tensor(0.2740, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2338, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.6271443963050842
# tensor(16, device='cuda:0')
# Loss1:  0.08103599399328232  Loss2:  tensor(0.2527, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3153, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.6491093635559082
# tensor(16, device='cuda:0')
# Loss1:  0.16933944821357727  Loss2:  tensor(0.2390, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3153, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7236591577529907
# tensor(16, device='cuda:0')
# Loss1:  0.12299031019210815  Loss2:  tensor(0.2617, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3799, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.7646008729934692
# tensor(16, device='cuda:0')
# Loss1:  0.07335418462753296  Loss2:  tensor(0.3147, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2758, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.6639187335968018
# tensor(16, device='cuda:0')
# Loss1:  0.04730048030614853  Loss2:  tensor(0.3357, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2876, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.6706441640853882
# tensor(16, device='cuda:0')
# Loss1:  0.11359349638223648  Loss2:  tensor(0.3084, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2560, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.678071141242981
# tensor(16, device='cuda:0')
# Loss1:  0.09769470989704132  Loss2:  tensor(0.2779, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.2894, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.6649772524833679
# tensor(16, device='cuda:0')
# Loss1:  0.14335404336452484  Loss2:  tensor(0.2457, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)  Loss3:  tensor(0.3035, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Total loss:  0.6924988031387329
# Best Test F1 throughout: 0.8800
# Loading best model for final evaluation...: 0.9667
# Best Test F1 after loading saved model: 0.8600
# Mean Std of Test F1 Score: 0.8600 +/- 0.0000

# %%
# Plot the F1 scores of last run
plt.figure(figsize=(10, 6))
plt.plot(train_f1_scores, label='Train F1 Score')
plt.plot(val_f1_scores, label='Validation F1 Score')
plt.plot(test_f1_scores, label='Test F1 Score')
plt.xlabel('Epoch')
plt.ylabel('F1 Score')
plt.title('F1 Scores over Epochs')
plt.legend()
plt.show()

# %%
for batch in cluster_loader:
    print(batch.num_nodes)
    print(batch.edge_index.shape)
# Out:
# 100
# torch.Size([2, 596])

# %%
import networkx as nx
import matplotlib.pyplot as plt
import torch
import matplotlib.colors as mcolors
from torch_geometric.utils import to_networkx
from torch_geometric.data import Data

# %%
torch.where(data.train_mask == True)
# Out:
# (tensor([ 1,  9, 10, 15, 37, 41, 42, 45, 48, 50, 55, 56, 65, 70, 72, 73, 76, 78,
#          91, 92], device='cuda:0'),)

# %%
def count_edges_with_different_labels(data, sampled_edge_index):
    """
    Counts edges with different labels at endpoints in both the original and sampled graphs.
    
    Args:
        data: Data object containing the original graph information.
        sampled_edge_index: Edge index of the sampled subgraph.
    
    Returns:
        A dictionary with counts and percentages of edges with different labels.
    """
    # Original graph edges
    original_edges = data.edge_index
    num_original_edges = original_edges.size(1)
    
    # Count edges with different labels in the original graph
    different_label_edges_original = 0
    for i in range(num_original_edges):
        node1, node2 = original_edges[:, i]
        if data.y[node1].item() != data.y[node2].item():
            different_label_edges_original += 1
    
    # Sampled graph edges
    sampled_edges = sampled_edge_index
    num_sampled_edges = sampled_edges.size(1)

    # Count edges with different labels in the sampled graph
    different_label_edges_sampled = 0
    for i in range(num_sampled_edges):
        node1, node2 = sampled_edges[:, i]
        if data.y[node1].item() != data.y[node2].item():
            different_label_edges_sampled += 1

    # Calculate percentages
    percentage_original = (different_label_edges_original / num_original_edges) * 100 if num_original_edges > 0 else 0
    percentage_sampled = (different_label_edges_sampled / num_sampled_edges) * 100 if num_sampled_edges > 0 else 0

    # Prepare the result
    result = {
        "original_graph": {
            "different_label_edges": different_label_edges_original,
            "total_edges": num_original_edges,
            "percentage": percentage_original
        },
        "sampled_graph": {
            "different_label_edges": different_label_edges_sampled,
            "total_edges": num_sampled_edges,
            "percentage": percentage_sampled
        }
    }

    return result

# %%
def plot_full_graph_with_train_nodes(data, train_mask, ax=None):
    """
    Plots the full graph with training nodes highlighted and colored by their labels.
    Args:
        data: Data object containing edge_index, node labels, and other features.
        train_mask: Boolean tensor indicating training nodes.
        ax: Matplotlib axis on which to plot (for side-by-side plotting).
    """
    # Convert PyG data to NetworkX graph for visualization
    G = to_networkx(data)
    
    # Generate color map for each label
    unique_labels = torch.unique(data.y[train_mask]).tolist()
    color_map = {label: color for label, color in zip(unique_labels, mcolors.TABLEAU_COLORS)}

    # Set node colors based on whether they are a training node and their label
    node_colors = [
        color_map[data.y[i].item()] if train_mask[i].item() else 'gray' for i in range(data.num_nodes)
    ]
    
    pos = None
    
    if DATASET_NAME == 'moon':
        pos = {i: (data.x[i][0].item(), data.x[i][1].item()) for i in range(len(data.x))}
    elif pos is None:
        pos = nx.spring_layout(G, seed=42)

    # Plot the full graph with training nodes highlighted by label color
    nx.draw(G, pos, node_color=node_colors, ax=ax, with_labels=False, node_size=100, edge_color="lightblue")
    
    # Add label above each node showing the label value
    for node, p in pos.items():
        label = data.y[node].item()
        ax.text(p[0], p[1] + 0.05, str(label), fontsize=8, ha='center', va='center')
    
    ax.set_title("Full Graph with Training Nodes Highlighted by Label")
    ax.axis("off")
    
    return pos


def plot_sampled_subgraph(data, sampled_edge_index, train_mask, ax=None, pos=None):
    """
    Plots the sampled subgraph based on the edge probability model with training nodes highlighted by label.
    Args:
        data: Data object containing node information.
        sampled_edge_index: Edge index of the sampled subgraph.
        train_mask: Boolean tensor indicating training nodes.
        ax: Matplotlib axis on which to plot (for side-by-side plotting).
    """
    # Convert sampled edges to NetworkX graph
    G_sampled = to_networkx(Data(x = data.x, y = data.y, edge_index = sampled_edge_index))
    
    # Use same color map as the full graph
    unique_labels = torch.unique(data.y[train_mask]).tolist()
    color_map = {label: color for label, color in zip(unique_labels, mcolors.TABLEAU_COLORS)}

    # Use same layout as the full graph for consistent positioning
    if pos is None:
        pos = nx.spring_layout(G_sampled, seed=42)
    
    # Set node colors based on training status and label for nodes in the sampled graph
    node_colors = [
        color_map[data.y[i].item()] if train_mask[i].item() and i in G_sampled.nodes else 'gray'
        for i in G_sampled.nodes
    ]

    # Plot the sampled subgraph with node labels
    nx.draw(G_sampled, pos, node_color=node_colors, ax=ax, with_labels=False, node_size=100, edge_color="orange")
    
    # Add label above each node showing the label value
    for node, p in pos.items():
        label = data.y[node].item()
        ax.text(p[0], p[1] + 0.05, str(label), fontsize=8, ha='center', va='center')
    
    ax.set_title("Sampled Subgraph (Edge Probability Model) with Training Nodes Highlighted by Label")
    ax.axis("off")


def visualize_graphs_side_by_side(data, train_mask, sampled_edge_index, show=True):
    """
    Visualizes the full graph with training nodes and the sampled subgraph side by side, with training nodes colored by label.
    Args:
        data: Data object containing the full graph information.
        train_mask: Boolean tensor indicating training nodes.
        sampled_edge_index: Edge index of the sampled subgraph.
    """
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 7))
    
    # Plot full graph with training nodes highlighted by label
    pos1 = plot_full_graph_with_train_nodes(data, train_mask, ax=ax1)

    # Plot sampled subgraph with training nodes highlighted by label, using the same layout
    plot_sampled_subgraph(data, sampled_edge_index, train_mask, ax=ax2, pos=pos1)
    
    if show==False:
        plt.close()
    else:
        plt.show()
    
    return fig

# Example Usage:
# Assuming `train_mask` is a boolean mask tensor, and `sampled_edge_index` is the edge index after sampling
# visualize_graphs_side_by_side(data, train_mask=data.train_mask, sampled_edge_index=sampled_edge_index)

# %%
def visualize(istest=True, show=True):
    if use_metis == False:
        with torch.no_grad():
            edge_probs = model.edge_prob_mlp(data.x, data.edge_index).squeeze()
            sampled_edge_indices, sampled_edge_weight = gumbel_softmax_sampling(
                edge_probs,
                data.edge_index,
                q=sample_size, istest=istest)

            sampled_edge_index = data.edge_index[:, sampled_edge_indices]
            fig = visualize_graphs_side_by_side(data, train_mask=data.train_mask, sampled_edge_index=sampled_edge_index, show=show)

            # Example Usage
            # Assuming `data` is your original graph and `sampled_edge_index` is your sampled edge index
            result = count_edges_with_different_labels(data, sampled_edge_index)

            print("\% of heterophily:")

            # Print the results
            print(f"Original graph: {result['original_graph']['different_label_edges']} edges with different labels "
                  f"out of {result['original_graph']['total_edges']} total edges "
                  f"({result['original_graph']['percentage']:.2f}%).")

            print(f"Sampled graph: {result['sampled_graph']['different_label_edges']} edges with different labels "
                  f"out of {result['sampled_graph']['total_edges']} total edges "
                  f"({result['sampled_graph']['percentage']:.2f}%).")
            
            return fig
            
fig = visualize(False) #Sampled from the best
fig = visualize(True)  #Best Sparsifier
# Out:
# \% of heterophily:
# Original graph: 406 edges with different labels out of 596 total edges (68.12%).
# Sampled graph: 68 edges with different labels out of 119 total edges (57.14%).
# \% of heterophily:
# Original graph: 406 edges with different labels out of 596 total edges (68.12%).
# Sampled graph: 24 edges with different labels out of 119 total edges (20.17%).

# %%
# def sample_gumbel(shape, eps=1e-20):
#     """Sample from Gumbel(0, 1)"""
#     U = torch.rand(shape)
#     return -torch.log(-torch.log(U + eps) + eps)

# # Example usage
# shape = (10,)  # Sample 10 values
# gumbel_noise = sample_gumbel(shape)
# print(gumbel_noise)

# %% [markdown]
# ## Animate the Sparsification

# %%
def store_figures_during_test():
    figures = []
    for epoch in range(20):  # Assuming 100 epochs
        fig = visualize(False, False)
        figures.append(fig)
        plt.close(fig)
    return figures

# figures = store_figures_during_test()

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation

def create_animation_from_figures(figures):
    fig_anim, ax_anim = plt.subplots()

    def update_fig(i):
        ax_anim.clear()
        figures[i].canvas.draw()
        img_array = np.frombuffer(figures[i].canvas.tostring_rgb(), dtype=np.uint8)
        img_array = img_array.reshape(figures[i].canvas.get_width_height()[::-1] + (3,))
        ax_anim.imshow(img_array)
        ax_anim.axis('off')

    ani = animation.FuncAnimation(fig_anim, update_fig, frames=len(figures), interval=200, blit=False)

    from IPython.display import HTML
    return HTML(ani.to_jshtml())

# # Example Usage:
# # Assuming `figures` is a list of stored figure objects from `store_figures_during_training`.
# animation_html = create_animation_from_figures(figures)
# display(animation_html)

# %%
if figure_log:
    animation_html = create_animation_from_figures(train_figures)
    display(animation_html)
